# %% [markdown]
# **BEDS Pipeline execution example**
#
# Instructions:
# 1. Uncomment and install required libraries;
# 2. Upload your input file of choice (labeled or unlabeled dataset);
# 3. Upload the "reference" folder, containing the "correct_loss_reference.csv", "correct_hazard_reference.csv", and "correct_loss_reference.csv" files;
# 4. Select the input (labeled/unlabeled) type in the form below;
# 5. Run all code.

# %%
# !pip install datasets
# !pip install evaluate
# !pip install sentence-transformers==3.1.1
# !pip install transformers==4.45.2

# %%
import time
import pandas as pd
import numpy as np
from torch.nn import functional as F

import torch
from sklearn.model_selection import train_test_split
from transformers import AutoModelForSequenceClassification, AutoTokenizer

from sentence_transformers import SentenceTransformer

# %%
step1_labels = ['loss', 'hazard', 'constraint']
step2_labels = ['valid', 'invalid']
step3_labels = ['rewrite', 'not', 'condition', 'accident', 'valid']

# %%
def label_to_int(df, name, labels):
  for i in range(len(df[name])):
    df.loc[i,name] = labels.index(df.loc[i,name])

# %%
# @title Language Model Preset
model_preset = "ModernBERT" # @param ["BERT","DistilBERT","ModernBERT"]

# %%
# Define input file name here:
file_name = 'input_example labeled.csv'

# Uncomment 4 lines below if using Google Drive
# from google.colab import drive
# drive.mount('/content/drive')
# drive_path = '/content/drive/MyDrive/Colab Notebooks/'
# file_name = drive_path+file_name


# @title Select Input type and import data (with or without label)

# Unlabeled input allows the execution of the first step of the BEDS Pipeline, for a labeling error detection and a rough check of sentence ambiguity;
# Expected input: .csv dataset with a single column: ['sentence']
# Labeled input skips the first step, and assumes all sentences are correctly labeled.
# Expected input: .csv dataset with two columns: ['sentence', 'label'] #the label should be exactly 'loss', 'hazard', or 'constraint'
input_type = 'labeled' #@param ['labeled', 'unlabeled']
verbose = 'False' #@param ['True', 'False']


col_names = []
if input_type == 'unlabeled':
  col_names = ['sentence']
  df = pd.read_csv(file_name, names=col_names, index_col=False, delimiter=',', skiprows=1)#,header=None)
elif input_type == 'labeled':
  col_names = ['sentence', 'label']
  df = pd.read_csv(file_name, names=col_names, index_col=False, delimiter=',', skiprows=1)
  label_to_int(df, 'label', step1_labels)

df.head()
# Out:
#                                             sentence label
# 0  A collision between the ACROBOTER robotic plat...     2
# 1   A non‐patient is injured or killed by radiation.     0
# 2  A nonpatient is injured or killed in the proce...     0
# 3  A pair of controlled aircraft violates minimum...     1
# 4  A person or worker is standing/working under o...     1

# %%
def step1_print_label_diff(results,df):
  predictions = np.argmax(results.logits.cpu(), axis=-1)
  probabilities = F.softmax(results.logits.cpu(), dim=-1)

  for sentence, label, prediction, probability in zip(df['sentence'], df['label'], predictions, probabilities):

    if label != prediction.item():
      print('###########################################################')
      print('##### This sentence presented a classification error: #####')
    print('Sentence:        ', sentence)
    print('True label:      ', step1_labels[label])
    print('Predicted label: ', step1_labels[prediction.item()])
    print('Probabilities    ')
    print('Loss:            ', probability.tolist()[0])
    print('Hazard:          ', probability.tolist()[1])
    print('Constraint:      ', probability.tolist()[2])
    print('\n')

# %%
match model_preset:
  case 'BERT':
    model_name = "google-bert/bert-base-uncased"
  case 'DistilBERT':
    model_name = "distilbert/distilbert-base-uncased"
  case 'ModernBERT':
    model_name = "answerdotai/ModernBERT-base"

#model_name = "google-bert/bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/694 [00:00<?, ?B/s]

# %%
# Step 1

# Load models
path = 'andreyunic23/'
path_step1 = path+'beds_step1'
path_step1 = path_step1+'_'+model_preset
model_classif = AutoModelForSequenceClassification.from_pretrained(path_step1, num_labels=3)

x_test = df['sentence'].to_list()

start = time.perf_counter()

with torch.no_grad():
  encodings = tokenizer(x_test, truncation=True, padding='max_length', max_length=512,return_tensors="pt")
  results = model_classif(encodings['input_ids'], encodings['attention_mask'])
  predictions = np.argmax(results.logits.cpu(), axis=-1)

end = time.perf_counter()

print('Step 1 execution time:', end-start)
print('Sentence count:')
print(len(x_test))
print('Time per sentence:')
print((end-start)/len(x_test))

if input_type == 'unlabeled':
  # add labels to the unlabeled dataframe
  df['label'] = predictions

if input_type == 'labeled':
  # show the difference in prediction labels from the original labels
  step1_print_label_diff(results,df)
# Out:
# Step 1 execution time: 376.34751070899983
# Sentence count:
# 1084
# Time per sentence:
# 0.347184050469557
# Sentence:         A collision between the ACROBOTER robotic platform and an unknown object must be avoided at all times.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.8378674212726764e-05
# Hazard:           1.760292252583895e-05
# Constraint:       0.9999639987945557
#
#
# Sentence:         A non‐patient is injured or killed by radiation.
# True label:       loss
# Predicted label:  loss
# Probabilities
# Loss:             0.9999948740005493
# Hazard:           5.092243100079941e-06
# Constraint:       1.2680672512033198e-08
#
#
# Sentence:         A nonpatient is injured or killed in the process of MRI simulation.
# True label:       loss
# Predicted label:  loss
# Probabilities
# Loss:             0.9998987913131714
# Hazard:           0.00010110716539202258
# Constraint:       1.0197291544500331e-07
#
#
# Sentence:         A pair of controlled aircraft violates minimum separation standards.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             2.615945327022473e-08
# Hazard:           0.9999978542327881
# Constraint:       2.1506878056243295e-06
#
#
# Sentence:         A person or worker is standing/working under or passing through the excavators’ range cycle.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             1.7552691815581056e-06
# Hazard:           0.9999974966049194
# Constraint:       7.381010505014274e-07
#
#
# Sentence:         A storage method for using chemicals, such as FIFO (First-In, First-Out), should be adopted.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             6.362956355587812e-06
# Hazard:           8.246257493738085e-05
# Constraint:       0.9999111890792847
#
#
# Sentence:         A/C must maintain minimum safe altitude limits.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             3.702644235659136e-08
# Hazard:           1.8760393061256764e-07
# Constraint:       0.9999997615814209
#
#
# Sentence:         A/C must maintain minimum safe separation distance.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             6.562757448591583e-08
# Hazard:           1.3351844927456114e-06
# Constraint:       0.9999985694885254
#
#
# Sentence:         A/C not compliant with airworthiness requirements.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             3.416003437450854e-06
# Hazard:           0.9999759197235107
# Constraint:       2.061143641185481e-05
#
#
# Sentence:         Absence of warning when vehicle moves out of lane, resulting in a collision.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             3.5173412470612675e-05
# Hazard:           0.9999126195907593
# Constraint:       5.2166837122058496e-05
#
#
# Sentence:         ACC did not illuminate brake light to warn vehicle in the behind.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             3.8658509993183543e-07
# Hazard:           0.9999953508377075
# Constraint:       4.311325938033406e-06
#
#
# Sentence:         ACC did not maintain a safe distance from the object in the front, resultng in collision.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             7.797541184118018e-05
# Hazard:           0.9998539686203003
# Constraint:       6.80245939292945e-05
#
#
# Sentence:         ACC does not maintain a safe distance from the object in the front (resulting in a collision).
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             3.547733649611473e-05
# Hazard:           0.9999607801437378
# Constraint:       3.6746014302480035e-06
#
#
# Sentence:         ACC does not reduce throttle and apply the braking force to maintain safe distance as preset by driver when vehicle catches up with a slower preceding vehicle.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             4.03494510692326e-07
# Hazard:           0.9998928308486938
# Constraint:       0.00010679766273824498
#
#
# Sentence:         ACC estimates wrong values of distance and speed of vehicle ahead.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             1.3632267155117006e-06
# Hazard:           0.9999972581863403
# Constraint:       1.4068193650018657e-06
#
#
# Sentence:         ACC must not brake too abruptly.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.445225450424914e-07
# Hazard:           9.360145547532284e-09
# Constraint:       0.9999998807907104
#
#
# Sentence:         ACC must not violate separation requirements with object ahead.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             7.04036295928745e-08
# Hazard:           1.1052240722619899e-07
# Constraint:       0.9999997615814209
#
#
# Sentence:         ACC should not brake too abruptly.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             5.401668659033021e-07
# Hazard:           3.1654568033445685e-07
# Constraint:       0.9999991655349731
#
#
# Sentence:         ACC should not let the vehicle gets in contact with the object ahead.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.3577686079079285e-06
# Hazard:           1.2708434951491654e-05
# Constraint:       0.9999849796295166
#
#
# Sentence:         ACC slows down the vehicle too abruptly (and vehicle is rear-ended).
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             1.0258480870106723e-05
# Hazard:           0.9999885559082031
# Constraint:       1.2234821724632639e-06
#
#
# Sentence:         ACC slows down the vehicle too abruptly, and vehicle is rear-ended.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             1.1466127034509555e-05
# Hazard:           0.9999814033508301
# Constraint:       7.181095952546457e-06
#
#
# Sentence:         ACC violates the safe distance between ACC vehicle and vehicle in front.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             3.699472654261626e-05
# Hazard:           0.9999414682388306
# Constraint:       2.1627682144753635e-05
#
#
# Sentence:         ACS must not continue providing attitude maneuver commands too long after attitude has stabilized.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             8.320445443743552e-10
# Hazard:           7.311344774052486e-08
# Constraint:       0.9999998807907104
#
#
# Sentence:         ACS must not provide attitude maneuver commands in the same direction as rotation.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.1254701110251517e-08
# Hazard:           6.696718060084095e-07
# Constraint:       0.9999992847442627
#
#
# Sentence:         ACS must not provide attitude maneuver commands too early to achieve desired attitude.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             3.25725957317502e-09
# Hazard:           2.005111667813253e-07
# Constraint:       0.9999997615814209
#
#
# Sentence:         ACS must not provide attitude maneuver commands too late after ASTRO-H has rotated too far.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.1012044609515215e-07
# Hazard:           3.487839421723038e-05
# Constraint:       0.9999649524688721
#
#
# Sentence:         ACS must not provide attitude maneuver commands when ASTRO-H is not rotating.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             7.981112659649625e-09
# Hazard:           1.1666053296721657e-06
# Constraint:       0.9999988079071045
#
#
# Sentence:         ACS must not stop providing attitude commands too soon before attitude has stabilized.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.0501312042165978e-09
# Hazard:           1.7647080241545154e-08
# Constraint:       1.0
#
#
# Sentence:         ACS must provide attitude maneuver commands that are sufficient to slow ASTRO-H quickly.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.6815276282500236e-08
# Hazard:           3.73966213373933e-06
# Constraint:       0.9999961853027344
#
#
# Sentence:         ACS must provide attitude maneuver commands when ASTRO-H is rotating.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.2532892945671392e-08
# Hazard:           1.0374242265243083e-06
# Constraint:       0.999998927116394
#
#
# Sentence:         Actuator (Throttle, Spark, Fuel, etc.) Control shall be synchronized with axle torque request.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             8.101660000647826e-07
# Hazard:           0.00019462546333670616
# Constraint:       0.9998045563697815
#
#
# Sentence:         After rotation, the skid angle must be reduced to keep wings leveled.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             4.1621202484520836e-08
# Hazard:           4.485698923417658e-07
# Constraint:       0.9999995231628418
#
#
# Sentence:         Aircraft (including both manned and unmanned systems) in the air are damaged or destroyed.
# True label:       loss
# Predicted label:  loss
# Probabilities
# Loss:             0.9999939203262329
# Hazard:           5.43546912012971e-06
# Constraint:       6.454259278143581e-07
#
#
# Sentence:         Aircraft airframe integrity is degraded.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             1.1096599337179214e-05
# Hazard:           0.999948263168335
# Constraint:       4.062340303789824e-05
#
#
# Sentence:         Aircraft comes too close to airport infrastructure components during operations on the ground.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             1.3950355537417636e-07
# Hazard:           0.9999996423721313
# Constraint:       2.4141644416886265e-07
#
#
# Sentence:         Aircraft comes too close to service equipment components during operations on the ground.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             1.1933502719330136e-07
# Hazard:           0.9999990463256836
# Constraint:       8.487211857755028e-07
#
#
# Sentence:         Aircraft component is powered up when hazardous FLS is installed
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             5.014819635107415e-07
# Hazard:           0.999995231628418
# Constraint:       4.337467998993816e-06
#
#
# Sentence:         Aircraft component must not be powered up when hazardous FLS is installed.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             7.164716375740454e-09
# Hazard:           3.113619868599926e-07
# Constraint:       0.9999996423721313
#
#
# Sentence:         Aircraft crashes into terrain / ocean.
# True label:       loss
# Predicted label:  loss
# Probabilities
# Loss:             0.9999207258224487
# Hazard:           7.93071958469227e-05
# Constraint:       2.1719385401297586e-08
#
#
# Sentence:         Aircraft crashes.
# True label:       loss
# Predicted label:  loss
# Probabilities
# Loss:             0.9974572062492371
# Hazard:           0.002540203044191003
# Constraint:       2.6729455839813454e-06
#
#
# Sentence:         Aircraft does not stop before the runway end.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             2.832308837241726e-06
# Hazard:           0.9999947547912598
# Constraint:       2.3295624487218447e-06
#
#
# Sentence:         Aircraft enters a prohibited area.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             1.3015649358294468e-07
# Hazard:           0.9999638795852661
# Constraint:       3.59872319677379e-05
#
#
# Sentence:         Aircraft enters a runway with no clearance.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             3.0624715918747825e-07
# Hazard:           0.9998487234115601
# Constraint:       0.00015088554937392473
#
#
# Sentence:         Aircraft enters an unsafe atmospheric region.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             6.636791738401371e-08
# Hazard:           0.9999840259552002
# Constraint:       1.5873067241045646e-05
#
#
# Sentence:         Aircraft enters prohibited area.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             2.8887276926070626e-07
# Hazard:           0.9999839067459106
# Constraint:       1.5832032659091055e-05
#
#
# Sentence:         Aircraft enters prohibited area.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             2.8887276926070626e-07
# Hazard:           0.9999839067459106
# Constraint:       1.5832032659091055e-05
#
#
# Sentence:         Aircraft enters uncontrolled state.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             5.837515573148266e-07
# Hazard:           0.9999990463256836
# Constraint:       3.012887361819594e-07
#
#
# Sentence:         Aircraft enters uncontrolled state.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             5.837515573148266e-07
# Hazard:           0.9999990463256836
# Constraint:       3.012887361819594e-07
#
#
# Sentence:         Aircraft enters uncontrolled state.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             5.837515573148266e-07
# Hazard:           0.9999990463256836
# Constraint:       3.012887361819594e-07
#
#
# Sentence:         Aircraft enters unsafe atmospheric region.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             1.8638347398791666e-07
# Hazard:           0.9999980926513672
# Constraint:       1.6907594044823782e-06
#
#
# Sentence:         Aircraft enters unsafe atmospheric region.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             1.8638347398791666e-07
# Hazard:           0.9999980926513672
# Constraint:       1.6907594044823782e-06
#
#
# Sentence:         Aircraft enters unsafe attitude (excessive turbulence or pitch/roll/yaw that causes passenger injury but not necessarily aircraft loss).
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             4.553168764687143e-06
# Hazard:           0.9999897480010986
# Constraint:       5.743308975070249e-06
#
#
# Sentence:         Aircraft enters unsafe attitude.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             7.640996955160517e-07
# Hazard:           0.9999785423278809
# Constraint:       2.070056871161796e-05
#
#
# Sentence:         Aircraft enters unsafe attitude.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             7.640996955160517e-07
# Hazard:           0.9999785423278809
# Constraint:       2.070056871161796e-05
#
#
# Sentence:         Aircraft environment is harmful to human health.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             5.211641837377101e-05
# Hazard:           0.9999337196350098
# Constraint:       1.414627786289202e-05
#
#
# Sentence:         Aircraft flying off the route specified at flight plan.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             6.012887752149254e-06
# Hazard:           0.9999914169311523
# Constraint:       2.675010591701721e-06
#
#
# Sentence:         Aircraft is operated when hazardous FLS is installed.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             1.744168002915103e-05
# Hazard:           0.5525364279747009
# Constraint:       0.44744613766670227
#
#
# Sentence:         Aircraft loses its control or loses airframe integrity.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             2.0094914816581877e-06
# Hazard:           0.9999935626983643
# Constraint:       4.3530581024242565e-06
#
#
# Sentence:         Aircraft must be dispatched.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             5.4201851895641084e-08
# Hazard:           4.113645868386584e-09
# Constraint:       1.0
#
#
# Sentence:         Aircraft must maintain criteria for stable approaches.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             7.852651862094717e-09
# Hazard:           2.657227327063083e-08
# Constraint:       1.0
#
#
# Sentence:         Aircraft must maintain its control and maintain airframe integrity.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             4.320892976750201e-09
# Hazard:           1.6857214291121636e-08
# Constraint:       1.0
#
#
# Sentence:         Aircraft must maintain separation with ground or obstacles on ground.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             3.672830359846557e-07
# Hazard:           7.4154486355837435e-06
# Constraint:       0.9999922513961792
#
#
# Sentence:         Aircraft must maintain separation with other aircraft.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             9.469395934047498e-09
# Hazard:           5.553897963750387e-08
# Constraint:       0.9999998807907104
#
#
# Sentence:         Aircraft must not be operated when hazardous FLS is installed.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.493198009683283e-09
# Hazard:           2.2472846694654436e-08
# Constraint:       1.0
#
#
# Sentence:         Aircraft must not enter a runway without clearance.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             4.406644382726199e-09
# Hazard:           5.610196307515025e-09
# Constraint:       1.0
#
#
# Sentence:         Aircraft on ground must maintain separation with other objects and must not leave the paved area.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.4078212756961648e-09
# Hazard:           1.7524692452752788e-07
# Constraint:       0.9999998807907104
#
#
# Sentence:         Aircraft on the ground comes too close to other objects or leaves the paved area.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             7.429995889651764e-07
# Hazard:           0.9999841451644897
# Constraint:       1.510655965830665e-05
#
#
# Sentence:         Aircraft performs controlled maneuver into ground or into obstacles on ground.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             8.940580755734118e-07
# Hazard:           0.9999865293502808
# Constraint:       1.2568305464810692e-05
#
#
# Sentence:         Aircraft placed on trajectory or position that intersects with a physical obstruction (e.g., loss of separation, controlled flight into terrain).
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             6.553004823217634e-06
# Hazard:           0.9999905824661255
# Constraint:       2.8152853701612912e-06
#
#
# Sentence:         Aircraft placed on trajectory that intersects with dangerous atmospheric conditions (e.g., storms, volcanic ash).
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             2.6636651000444544e-06
# Hazard:           0.9999716281890869
# Constraint:       2.5795261535677128e-05
#
#
# Sentence:         Aircraft shall be capable of remaining airborn in a controlled manner throughout the operation.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.872461119489799e-08
# Hazard:           5.760585963798803e-07
# Constraint:       0.9999994039535522
#
#
# Sentence:         Aircraft shall not enter a controlled airspace without broadcasting their location through Mode C, ADS-B, or IFF.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             8.035879517365174e-08
# Hazard:           0.0007024072692729533
# Constraint:       0.9992974996566772
#
#
# Sentence:         Aircraft shall not enter a controlled airspace without verbal confirmation from the controller.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.2028509743799987e-08
# Hazard:           1.401593181071803e-06
# Constraint:       0.9999985694885254
#
#
# Sentence:         Aircraft should maintain a safe distance from obstacles and notify the operator when reaching the minimum distance.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.946702437611748e-09
# Hazard:           9.392068136548914e-07
# Constraint:       0.9999990463256836
#
#
# Sentence:         Aircraft veers to a runway side.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             9.499272891844157e-06
# Hazard:           0.9944739937782288
# Constraint:       0.005516470409929752
#
#
# Sentence:         Aircraft violate minimum separation standards in flight.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             9.55441350924957e-07
# Hazard:           0.9999915361404419
# Constraint:       7.466614533768734e-06
#
#
# Sentence:         Aircraft violate minimum separation with other aircraft.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             5.66466766827034e-08
# Hazard:           0.9999994039535522
# Constraint:       6.130965743977868e-07
#
#
# Sentence:         Aircraft violates criteria for stable approaches.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             4.567713745018409e-07
# Hazard:           0.9999829530715942
# Constraint:       1.6536649127374403e-05
#
#
# Sentence:         Aircraft violates minimum separation from airspace or other aircraft.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             5.456544158732868e-07
# Hazard:           0.9999960660934448
# Constraint:       3.3081935271184193e-06
#
#
# Sentence:         Aircraft violates the minimum separation from other aircrafts during operations on the ground.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             5.338999642390263e-08
# Hazard:           0.9999992847442627
# Constraint:       6.800742085033562e-07
#
#
# Sentence:         Aircraft violates the minimum separation from service vehicles during operations on the ground.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             8.177914878615411e-08
# Hazard:           0.999998927116394
# Constraint:       9.550767572363839e-07
#
#
# Sentence:         Airframe integrity is lost during operations on the ground.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             1.414011649103486e-06
# Hazard:           0.9999983310699463
# Constraint:       2.9230972131699673e-07
#
#
# Sentence:         Airframe integrity must not be lost during flight.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             5.699872573927678e-08
# Hazard:           1.8781491917252424e-08
# Constraint:       0.9999998807907104
#
#
# Sentence:         Airport infrastructure component integrity is lost during operations.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             1.069586005542078e-06
# Hazard:           0.9999986886978149
# Constraint:       2.1156414220513398e-07
#
#
# Sentence:         All inspection procedures must be coordinated between implementers.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.404903298725003e-08
# Hazard:           3.9203467139259374e-08
# Constraint:       0.9999998807907104
#
#
# Sentence:         All the safety/mission critical military aerospace designs and products shall be Certified to allow use or operation.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.9231290454845293e-07
# Hazard:           2.9545090001192875e-06
# Constraint:       0.9999967813491821
#
#
# Sentence:         An abnormal termination instruction must be given immediately if an abort is required.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.786035565804923e-06
# Hazard:           2.1748628569184802e-06
# Constraint:       0.9999949932098389
#
#
# Sentence:         An abnormal termination instruction must be given when continuing the ITP would be unsafe.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             6.287889959821769e-07
# Hazard:           9.380058827446192e-07
# Constraint:       0.9999984502792358
#
#
# Sentence:         An abnormal termination instruction must not be given when it is not required to maintain safety and would result in a loss of separation.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             4.343360160419252e-06
# Hazard:           1.0405366083432455e-05
# Constraint:       0.9999852180480957
#
#
# Sentence:         An emergency shall stop the train, Doors shall open in an emergency after the train has stopped.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.950376085664175e-07
# Hazard:           1.27139094274753e-06
# Constraint:       0.9999984502792358
#
#
# Sentence:         An incident during this mission directly causes another mission to fail to collect, return, and/or use the scientific data corresponding to its mission goals.
# True label:       loss
# Predicted label:  loss
# Probabilities
# Loss:             0.9999133348464966
# Hazard:           8.055719081312418e-05
# Constraint:       6.03458011028124e-06
#
#
# Sentence:         Approval must be given to the requesting aircraft only.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             7.338432794767868e-08
# Hazard:           2.655206401414034e-07
# Constraint:       0.9999996423721313
#
#
# Sentence:         Approval must not be given too early or too late (needs to be clarified as to the actual time limits).
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             6.430603605167562e-08
# Hazard:           3.3411900801638694e-08
# Constraint:       0.9999998807907104
#
#
# Sentence:         Approval of an ITP request must be given only when the ITP criteria are met.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.0274312007018125e-08
# Hazard:           1.204995498937933e-07
# Constraint:       0.9999998807907104
#
#
# Sentence:         Asset damage (ship, battery trailer).
# True label:       loss
# Predicted label:  loss
# Probabilities
# Loss:             0.999058187007904
# Hazard:           0.0009416912798769772
# Constraint:       8.896799386093335e-08
#
#
# Sentence:         ASTRO-H unable to collect scientific data.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             3.314439163659699e-05
# Hazard:           0.9999667406082153
# Constraint:       1.2389180881200446e-07
#
#
# Sentence:         ASTRO-H unable to communicate scientific data.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             0.00012233498273417354
# Hazard:           0.9998774528503418
# Constraint:       2.2592324455672497e-07
#
#
# Sentence:         At the launch rail, vehicle stages must be prevented from igniting before planned, even when subjected to commands or electric discharges.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.8283813574271335e-08
# Hazard:           4.193481345282635e-06
# Constraint:       0.9999958276748657
#
#
# Sentence:         Authorities do not award permits to the Project when required for start of related Project construction activities.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             4.516751914707129e-07
# Hazard:           0.9999574422836304
# Constraint:       4.2049716284964234e-05
#
#
# Sentence:         Autopilot does not react to other road crossing vehicles/obstacles.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             8.606469918959192e-07
# Hazard:           0.9999985694885254
# Constraint:       6.273838266679377e-07
#
#
# Sentence:         Autopilot must send objects to Autopilot HMI when required.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             7.587714634382792e-08
# Hazard:           3.9140709873208834e-07
# Constraint:       0.9999995231628418
#
#
# Sentence:         Autopilot must send road signs to Autopilot HMI when required.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             8.484460067847976e-08
# Hazard:           4.001826710009482e-07
# Constraint:       0.9999995231628418
#
#
# Sentence:         AV activates due to incorrect request during autonomous maneuver.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             5.0326150358159794e-08
# Hazard:           0.9999998807907104
# Constraint:       8.226373182651514e-08
#
#
# Sentence:         AV activates without request during autonomous maneuver.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             7.168932114609561e-08
# Hazard:           0.9999998807907104
# Constraint:       4.434850708889826e-08
#
#
# Sentence:         AV behavior is uncomfortable for the passengers.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             0.0005236517172306776
# Hazard:           0.9973498582839966
# Constraint:       0.0021265747491270304
#
#
# Sentence:         AV collision with vulnerable road user (VRU).
# True label:       loss
# Predicted label:  loss
# Probabilities
# Loss:             0.9998542070388794
# Hazard:           0.00014582002768293023
# Constraint:       3.605292064889909e-08
#
#
# Sentence:         AV does not maintain a safe distance from vulnerable road users (VRUs) or other stationary or moving objects in the surroundings.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             2.622778083605226e-06
# Hazard:           0.9999960660934448
# Constraint:       1.3047082347839023e-06
#
#
# Sentence:         AV does not maintain safe distance to another AV.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             1.0272291461888017e-07
# Hazard:           0.9999997615814209
# Constraint:       9.460228511670721e-08
#
#
# Sentence:         AV does not maintain safe distance to structure.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             5.214483849158569e-07
# Hazard:           0.9999992847442627
# Constraint:       2.8062322598998435e-07
#
#
# Sentence:         AV does not maintain safe distance to VRU.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             1.9824274488655647e-07
# Hazard:           0.9999995231628418
# Constraint:       2.6065578140332946e-07
#
#
# Sentence:         AV does not respond to requests during autonomous maneuver.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             2.495058879503631e-07
# Hazard:           0.9999996423721313
# Constraint:       1.103521896084203e-07
#
#
# Sentence:         AV gets damaged.
# True label:       loss
# Predicted label:  loss
# Probabilities
# Loss:             0.9999980926513672
# Hazard:           1.8485325199435465e-06
# Constraint:       4.7330011909707537e-08
#
#
# Sentence:         AV leaves designated path.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             0.0154119823127985
# Hazard:           0.9839528203010559
# Constraint:       0.0006351934280246496
#
#
# Sentence:         AV leaves the designated demo zone.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             8.591638902544219e-07
# Hazard:           0.9999885559082031
# Constraint:       1.0597665095701814e-05
#
#
# Sentence:         AV loses control.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             1.6071786603788496e-06
# Hazard:           0.9999921321868896
# Constraint:       6.306500381469959e-06
#
#
# Sentence:         AV must adhere to the allowed operating limits advised by the traffic rules and ODD limitations.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.868376564573282e-08
# Hazard:           3.6061484820493206e-07
# Constraint:       0.9999996423721313
#
#
# Sentence:         AV must adhere to the designated path.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.1252635800929056e-07
# Hazard:           1.5539281861265408e-08
# Constraint:       0.9999998807907104
#
#
# Sentence:         AV must maintain a safe distance from VRUs and other stationary and moving objects in the surroundings.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.7688276560411396e-08
# Hazard:           7.013061917859886e-07
# Constraint:       0.9999992847442627
#
#
# Sentence:         AV must never lose control.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.6543361880394514e-07
# Hazard:           6.484921044602743e-08
# Constraint:       0.9999997615814209
#
#
# Sentence:         AV must provide a comfortable experience to the passengers when driving or stationary.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.106013880620594e-06
# Hazard:           2.4599557946203277e-07
# Constraint:       0.999997615814209
#
#
# Sentence:         AV violates allowed operating conditions.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             4.518327045843762e-07
# Hazard:           0.9999799728393555
# Constraint:       1.960377448995132e-05
#
#
# Sentence:         Avoid operation beyond the permissible limits (emergency cases are excluded).
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.2314237096688885e-07
# Hazard:           2.8219942578289192e-06
# Constraint:       0.9999970197677612
#
#
# Sentence:         Avoiding the concurrence of flammable substances, oxidizer and ignition source.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.5975350581575185e-07
# Hazard:           0.00011842172534670681
# Constraint:       0.9998812675476074
#
#
# Sentence:         Avoiding the interaction of flammable substances, oxidizer and ignition source.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.907835383008205e-07
# Hazard:           0.0003987193340435624
# Constraint:       0.9996010661125183
#
#
# Sentence:         Blown tire procedure not followed.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             0.16542620956897736
# Hazard:           0.8345398902893066
# Constraint:       3.395100429770537e-05
#
#
# Sentence:         Brake light command must illuminate early within X-seconds before stopping vehicle.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             5.99059504224897e-08
# Hazard:           4.52278800366912e-06
# Constraint:       0.9999954700469971
#
#
# Sentence:         Brakes cannot be applied severely when aborting with strong crosswind.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             7.604648999404162e-08
# Hazard:           4.5360011426964775e-06
# Constraint:       0.9999953508377075
#
#
# Sentence:         Cabin parameters incompatible with human survival.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             7.707253644184675e-06
# Hazard:           0.9999821186065674
# Constraint:       1.0087322152685374e-05
#
#
# Sentence:         Catching fire inside the ship.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             3.424069291213527e-05
# Hazard:           0.9999572038650513
# Constraint:       8.540057024220005e-06
#
#
# Sentence:         Certification Authority personal, including Organization Designation Authorization (ODA), unqualified to the product in analyse or at the certification process.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             2.044591383310035e-05
# Hazard:           0.9999724626541138
# Constraint:       7.0355599746108055e-06
#
#
# Sentence:         Certification Process implemented is not adequate to identify critical flaws or loss scenarios.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             0.013009580783545971
# Hazard:           0.9868468642234802
# Constraint:       0.00014357440522871912
#
#
# Sentence:         Certification Process temporally interrupted due to budgetary constraints to the project.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             0.0001400216278852895
# Hazard:           0.9998282194137573
# Constraint:       3.169225965393707e-05
#
#
# Sentence:         Certification Tests not performed as scheduled.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             0.00011571911454666406
# Hazard:           0.9998728036880493
# Constraint:       1.1397205526009202e-05
#
#
# Sentence:         Chemical plant must not release toxic chemicals into the atmosphere.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             7.73189654523776e-08
# Hazard:           2.8597449386325025e-07
# Constraint:       0.9999996423721313
#
#
# Sentence:         Collateral Damage.
# True label:       loss
# Predicted label:  loss
# Probabilities
# Loss:             0.9999990463256836
# Hazard:           1.00460522389767e-06
# Constraint:       2.2059438720134494e-08
#
#
# Sentence:         Collision between the ACROBOTER robotic platform and an unknown object (both human or material).
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             0.03626541048288345
# Hazard:           0.963663637638092
# Constraint:       7.094565808074549e-05
#
#
# Sentence:         Collision of a manned and unmanned aircraft.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             0.0010211669141426682
# Hazard:           0.9989668130874634
# Constraint:       1.2057039384671953e-05
#
#
# Sentence:         Collision of an unmanned aircraft with a person on the ground.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             4.788631144947431e-07
# Hazard:           0.9999954700469971
# Constraint:       4.001362412964227e-06
#
#
# Sentence:         Collision of an unmanned aircraft with a structure on the ground.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             8.565320399611664e-07
# Hazard:           0.999995231628418
# Constraint:       3.972964350396069e-06
#
#
# Sentence:         Collision of two unmanned aircraft.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             1.6067566320998594e-05
# Hazard:           0.9999779462814331
# Constraint:       5.967266588413622e-06
#
#
# Sentence:         Collision with ISS.
# True label:       loss
# Predicted label:  loss
# Probabilities
# Loss:             0.999946117401123
# Hazard:           5.2042712923139334e-05
# Constraint:       1.7371161220580689e-06
#
#
# Sentence:         Collisions resulting in loss of life, damage or severe disturbance of daily operation.
# True label:       loss
# Predicted label:  loss
# Probabilities
# Loss:             0.9998340606689453
# Hazard:           0.0001650210760999471
# Constraint:       7.881364467721141e-07
#
#
# Sentence:         Commands for dosage exceeding the patient's tolerance are sent to the pump.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             5.668667654390447e-05
# Hazard:           0.79413241147995
# Constraint:       0.20581084489822388
#
#
# Sentence:         Commitments or obligations are not in line with USCG financial policy.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             0.0019935728050768375
# Hazard:           0.9980059266090393
# Constraint:       5.1163328862458e-07
#
#
# Sentence:         Commitments or obligations are recorded in excess of funding limitations.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             1.9553965103114024e-05
# Hazard:           0.9999793767929077
# Constraint:       1.0234587080049096e-06
#
#
# Sentence:         Company doesn’t complete the certification processes.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             9.733991464599967e-05
# Hazard:           0.9998974800109863
# Constraint:       5.172512373974314e-06
#
#
# Sentence:         Company reputation.
# True label:       loss
# Predicted label:  loss
# Probabilities
# Loss:             0.9998613595962524
# Hazard:           0.00013327764463610947
# Constraint:       5.368374786485219e-06
#
#
# Sentence:         Company takes actions inconsistent with stated values.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             3.828832632279955e-06
# Hazard:           0.9999955892562866
# Constraint:       6.167753099362017e-07
#
#
# Sentence:         Computer must not close water valve before catalyst valve closes.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.1708200275961644e-07
# Hazard:           1.2774872004683857e-07
# Constraint:       0.9999997615814209
#
#
# Sentence:         Computer must not close water valve while catalyst valve open.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.7882870767825807e-07
# Hazard:           3.1339988026957144e-07
# Constraint:       0.9999994039535522
#
#
# Sentence:         Computer must not open catalyst valve when water valve not open.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             6.95570747666352e-07
# Hazard:           7.345500989686116e-07
# Constraint:       0.9999985694885254
#
#
# Sentence:         Computer must open water valve whenever catalyst valve is open.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.425055273784892e-07
# Hazard:           3.5012638477383007e-07
# Constraint:       0.9999995231628418
#
#
# Sentence:         Computer must open water valve within X seconds of catalyst valve open.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             3.4668141779548023e-07
# Hazard:           3.260361609136453e-06
# Constraint:       0.9999964237213135
#
#
# Sentence:         Consumer (rider) PII exposed to unauthorized individuals.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             6.332946668408113e-06
# Hazard:           0.999993085861206
# Constraint:       5.395132802732405e-07
#
#
# Sentence:         Contaminated Enviroment.
# True label:       loss
# Predicted label:  loss
# Probabilities
# Loss:             0.9999635219573975
# Hazard:           3.6351950257085264e-05
# Constraint:       1.1452085146856916e-07
#
#
# Sentence:         Contamination of Outer Planet Moon with biological agents of Earth origin on mission hardware.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             5.1680003707588185e-06
# Hazard:           0.9999480247497559
# Constraint:       4.684811574406922e-05
#
#
# Sentence:         Control system shall control the actuator (Throttle, Spark, Fuel, etc.) correctly in response to axle torque request.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             5.113483325658308e-07
# Hazard:           6.348243186948821e-05
# Constraint:       0.9999359846115112
#
#
# Sentence:         Controlled Flight Into Terrain (CFIT).
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             4.269505006959662e-05
# Hazard:           0.9999165534973145
# Constraint:       4.073353193234652e-05
#
#
# Sentence:         Controlled Flight into Terrain.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             6.329612915578764e-06
# Hazard:           0.9999758005142212
# Constraint:       1.7892176401801407e-05
#
#
# Sentence:         Controlled flight of aircraft into terrain.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             3.8575231542381516e-07
# Hazard:           0.9999951124191284
# Constraint:       4.485677436605329e-06
#
#
# Sentence:         Controlled maneuver into ground.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             1.1861060329465545e-06
# Hazard:           0.9999281167984009
# Constraint:       7.069228740874678e-05
#
#
# Sentence:         Controller shall allow time for passengers to exit & enter before attempting to close the door.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             3.368041134876876e-08
# Hazard:           1.0764557600850821e-06
# Constraint:       0.999998927116394
#
#
# Sentence:         Controller shall not close Door while a passenger is in the doorway.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.3102113882723643e-07
# Hazard:           2.8849731279478874e-06
# Constraint:       0.9999970197677612
#
#
# Sentence:         Controller shall not open Door while train is moving, only when stopped.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             6.942363484085945e-08
# Hazard:           4.4631005380324495e-07
# Constraint:       0.9999995231628418
#
#
# Sentence:         Controller shall open Door in an emergency.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             7.221065345675015e-08
# Hazard:           2.4214463678617903e-07
# Constraint:       0.9999996423721313
#
#
# Sentence:         Controller shall open Door when Train is stopped in Station.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.0831862482518773e-06
# Hazard:           1.9864241949107964e-06
# Constraint:       0.9999969005584717
#
#
# Sentence:         Controller shall report the state of the Door to the next-higher level of control.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             5.08848131630657e-07
# Hazard:           7.717228072579019e-06
# Constraint:       0.999991774559021
#
#
# Sentence:         Controllers shall confirm that an aircraft has exited the zone via both voice communications and radar confirmation.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.6789859219888967e-08
# Hazard:           4.452422672329703e-06
# Constraint:       0.9999954700469971
#
#
# Sentence:         Controllers shall confirm that the small arms range is inactive.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             5.058306218330699e-09
# Hazard:           1.938434195380978e-07
# Constraint:       0.9999997615814209
#
#
# Sentence:         Controllers shall confirm that there are no rocket tests ongoing.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             6.45425686229828e-08
# Hazard:           1.7270509999889327e-07
# Constraint:       0.9999997615814209
#
#
# Sentence:         Controllers shall monitor radar returns of aircraft that are ascending/descending to ensure minimum separation requirements.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             3.285773431116468e-08
# Hazard:           1.856117887655273e-05
# Constraint:       0.9999814033508301
#
#
# Sentence:         Controllers shall not approve requests for access to zones other than those that they are controlling.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.9965275654953984e-08
# Hazard:           2.237447006336879e-06
# Constraint:       0.9999977350234985
#
#
# Sentence:         correct patient results must be reported to the Audiologist.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             8.589089702581987e-06
# Hazard:           5.88901116316265e-07
# Constraint:       0.9999908208847046
#
#
# ...
# Constraint:       8.489211609230551e-07
#
#
# Sentence:         Workers are exposed to hazardous energy.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             1.4293423191702459e-05
# Hazard:           0.999980092048645
# Constraint:       5.549457910092315e-06
#
#
# Sentence:         Workers are killed or injured on the job.
# True label:       loss
# Predicted label:  loss
# Probabilities
# Loss:             0.999997615814209
# Hazard:           2.264490376546746e-06
# Constraint:       7.556835868172129e-08
#
#
# Sentence:         Workers shall not be exposed to hazardous energy.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.1481520207089488e-07
# Hazard:           1.4117775890554185e-06
# Constraint:       0.9999983310699463
#
#
# Sentence:         Workflow is subject to unexpected stress, delays in starting treatments.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             7.13881172487163e-06
# Hazard:           0.9999865293502808
# Constraint:       6.3625502662034705e-06
#
#
# Sentence:         Workplace environment is not suitable for human health.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             8.689921742188744e-06
# Hazard:           0.9999814033508301
# Constraint:       9.880987818178255e-06
#
#
# Sentence:         Workplace methane levels are not suitable (too high).
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             5.827314089401625e-05
# Hazard:           0.9999358654022217
# Constraint:       5.874964244867442e-06
#
#
# Sentence:         Workplace oxygen levels are not suitable (too low).
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             3.19760620186571e-05
# Hazard:           0.9999246597290039
# Constraint:       4.337751306593418e-05
#
#
# Sentence:         Workplace ventilation integrity is lost.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             0.006558709777891636
# Hazard:           0.9934293627738953
# Constraint:       1.1929708307434339e-05
#
#
# Sentence:         Wrong dose, location, or patient.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             0.16589824855327606
# Hazard:           0.8332746028900146
# Constraint:       0.0008271452388726175
#
#
# Sentence:         WRONG DOSE: Dose delivered to patient is wrong in either amount, location, or timing.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             0.0008973327348940074
# Hazard:           0.9987398982048035
# Constraint:       0.0003628158010542393
#
#
# Sentence:         Wrong radiation delivered.
# True label:       hazard
# Predicted label:  hazard
# Probabilities
# Loss:             0.00022383994655683637
# Hazard:           0.9997748732566833
# Constraint:       1.3404695664576138e-06
#
#
# Sentence:         Yawing at brakes release must be counteracted quickly.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.1913034114741095e-07
# Hazard:           3.854061560559785e-06
# Constraint:       0.9999960660934448
#
#
# Sentence:         Must keep the system safe.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             7.67229657583357e-09
# Hazard:           3.115668789632764e-08
# Constraint:       1.0
#
#
# Sentence:         Security must be active.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.7352267889236828e-07
# Hazard:           2.356912220946583e-09
# Constraint:       0.9999998807907104
#
#
# Sentence:         Must have minimum mission critical safety systems functional for landing.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             3.478007570834052e-08
# Hazard:           6.258664342340126e-08
# Constraint:       0.9999998807907104
#
#
# Sentence:         Aircraft must fly.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.9136464263501693e-07
# Hazard:           8.440988352731438e-09
# Constraint:       0.9999996423721313
#
#
# Sentence:         Must have all systems functional when driving.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             9.534190326121461e-08
# Hazard:           2.2601327032134577e-08
# Constraint:       0.9999998807907104
#
#
# Sentence:         Must comply to all regulations.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.460451753449888e-07
# Hazard:           8.082890303739987e-07
# Constraint:       0.999998927116394
#
#
# Sentence:         Must calculate all processes in time.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             4.2801281097126775e-07
# Hazard:           2.0913698506319633e-07
# Constraint:       0.9999994039535522
#
#
# Sentence:         No relevant function shall be lost during flight.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             4.176960999302537e-07
# Hazard:           3.6929952784703346e-07
# Constraint:       0.9999991655349731
#
#
# Sentence:         Must fly through a safe area.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.439029659877633e-07
# Hazard:           8.532309720976627e-07
# Constraint:       0.9999990463256836
#
#
# Sentence:         System must be functional.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             5.850197339896113e-07
# Hazard:           4.027251421234723e-09
# Constraint:       0.9999994039535522
#
#
# Sentence:         Passanger must be alive.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             4.6275872023215925e-07
# Hazard:           6.897998172661346e-09
# Constraint:       0.9999995231628418
#
#
# Sentence:         Verifying the system conditions is a must.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.2681734062880423e-07
# Hazard:           8.684470458319993e-07
# Constraint:       0.9999990463256836
#
#
# Sentence:         An inspection must be done in the system.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.7917398054123623e-07
# Hazard:           6.957278486652285e-08
# Constraint:       0.9999997615814209
#
#
# Sentence:         Must have minimum number of passangers in flight.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             3.3253161291213473e-07
# Hazard:           9.65995582191681e-07
# Constraint:       0.9999986886978149
#
#
# Sentence:         Must have all systems functional for flight.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             4.827077759728127e-08
# Hazard:           2.909267138306859e-08
# Constraint:       0.9999998807907104
#
#
# Sentence:         No component shall be active when vehicle is turned off.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             5.449712148219987e-07
# Hazard:           2.1519358597288374e-06
# Constraint:       0.9999972581863403
#
#
# Sentence:         Must have cabin pressurization system active.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.5271575648512226e-07
# Hazard:           4.217158220853889e-06
# Constraint:       0.9999955892562866
#
#
# Sentence:         Should allow multiple users in software.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             6.350349849526538e-06
# Hazard:           2.4723691240069456e-05
# Constraint:       0.9999688863754272
#
#
# Sentence:         Must have all necessary weather information for flight.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.772801283550507e-08
# Hazard:           5.184114115763805e-08
# Constraint:       0.9999998807907104
#
#
# Sentence:         Must detect all system threats.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.5144590409809098e-08
# Hazard:           5.8445088768621645e-08
# Constraint:       0.9999998807907104
#
#
# Sentence:         Should an accident occur, the airbags are activated.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             4.29330157203367e-06
# Hazard:           2.311070784344338e-05
# Constraint:       0.9999725818634033
#
#
# Sentence:         Must maintain integrity of mission critical components.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.7407421043790237e-07
# Hazard:           3.946439051105699e-07
# Constraint:       0.9999992847442627
#
#
# Sentence:         Must be able to operate the system.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             4.3965425788883294e-07
# Hazard:           2.1007770101277856e-07
# Constraint:       0.9999994039535522
#
#
# Sentence:         Drune must be dispatched.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             4.087657714535453e-07
# Hazard:           1.9406375173502965e-08
# Constraint:       0.9999995231628418
#
#
# Sentence:         Avoid hazardous state.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             0.0001956353517016396
# Hazard:           0.016312994062900543
# Constraint:       0.9834913611412048
#
#
# Sentence:         Comply to all regulations.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.425495949864853e-06
# Hazard:           0.00020618356938939542
# Constraint:       0.9997914433479309
#
#
# Sentence:         Aircraft flies safely.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             3.249056317145005e-05
# Hazard:           2.7123047402710654e-05
# Constraint:       0.9999403953552246
#
#
# Sentence:         Avoid machine overload.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             0.00034450922976247966
# Hazard:           0.009974073618650436
# Constraint:       0.9896814227104187
#
#
# Sentence:         Verify if all components are working.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             5.336532922228798e-05
# Hazard:           6.584415132238064e-06
# Constraint:       0.999940037727356
#
#
# Sentence:         When encountering a dangerous situation, vehicle performs emergency maneuver.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.5589372398826526e-07
# Hazard:           8.236634312197566e-05
# Constraint:       0.9999173879623413
#
#
# Sentence:         Avoiding the contact of toxic substances.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.7312691852566786e-05
# Hazard:           0.31586790084838867
# Constraint:       0.6841148138046265
#
#
# Sentence:         Contact ATC when in emergency.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             5.068762675364269e-06
# Hazard:           4.880943015450612e-05
# Constraint:       0.999946117401123
#
#
# Sentence:         Aircraft keeps a safe altitude.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             8.983546706531342e-08
# Hazard:           5.14607609147788e-06
# Constraint:       0.9999947547912598
#
#
# Sentence:         Maintenance of the highway only when highway is blocked.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.6261681341566145e-05
# Hazard:           0.0024922818411141634
# Constraint:       0.9974815249443054
#
#
# Sentence:         Verify if the door is properly closed.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             9.713820873002987e-06
# Hazard:           9.333983325632289e-05
# Constraint:       0.9998968839645386
#
#
# Sentence:         During a trip to the destination, if there are people inside vehicle, remind to fasten the seatbelt.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.6818901713122614e-05
# Hazard:           0.0002869045129045844
# Constraint:       0.9996962547302246
#
#
# Sentence:         When the ground is clear, the pilot contacts ATC for permission, and performs landing.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.9983031052106526e-07
# Hazard:           4.326207090343814e-06
# Constraint:       0.9999954700469971
#
#
# Sentence:         Extension of landing gear only approaching ground.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             3.9293595932576864e-07
# Hazard:           0.00041218847036361694
# Constraint:       0.9995874762535095
#
#
# Sentence:         User is allowed to override commands in case of emergency.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             3.262344307586318e-06
# Hazard:           4.269742203177884e-05
# Constraint:       0.9999539852142334
#
#
# Sentence:         Avoid sudden braking when moving.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             3.394485020180582e-06
# Hazard:           3.0437471650657244e-05
# Constraint:       0.9999661445617676
#
#
# Sentence:         Ensure the vehicle has enough fuel before departing.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             3.216740651623695e-06
# Hazard:           0.00015267072012647986
# Constraint:       0.9998440742492676
#
#
# Sentence:         Always make sure to check if equipment is working as intended.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             2.9185130756559374e-07
# Hazard:           1.1788671372414683e-06
# Constraint:       0.9999985694885254
#
#
# Sentence:         Verify if the landing gear is retracted after takeoff.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             4.568308668240206e-06
# Hazard:           9.541747567709535e-05
# Constraint:       0.9998999834060669
#
#
# Sentence:         Verify the equipment state before performing maintenance.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.8484564634491107e-07
# Hazard:           1.3282424333738163e-06
# Constraint:       0.9999984502792358
#
#
# Sentence:         Changing lanes only when lane is empty.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.1790077223849948e-05
# Hazard:           0.0001035579844028689
# Constraint:       0.9998846054077148
#
#
# Sentence:         Avoid flight in altitude below permitted limit.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.1826331501652021e-05
# Hazard:           0.008241026662290096
# Constraint:       0.9917471408843994
#
#
# Sentence:         System is capable of defending threats.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.9690261979121715e-05
# Hazard:           0.0001711360237095505
# Constraint:       0.999809205532074
#
#
# Sentence:         Verify if the runway is empty.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             1.8808739696396515e-05
# Hazard:           1.0333631507819518e-05
# Constraint:       0.9999709129333496
#
#
# Sentence:         Sudden braking olny in emergency situations.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             4.2815460687961604e-07
# Hazard:           0.00013725952885579318
# Constraint:       0.9998623132705688
#
#
# Sentence:         Vehicle overtaking only when road is empty.
# True label:       constraint
# Predicted label:  constraint
# Probabilities
# Loss:             7.46011801311397e-06
# Hazard:           7.894531881902367e-05
# Constraint:       0.9999135732650757

# %%
def organize_step2_predictions(results, list_sentences):
  list_valid = []
  list_invalid = []
  predictions = np.argmax(results.logits.cpu(), axis=-1)
  probabilities = F.softmax(results.logits.cpu(), dim=-1)

  for sentence, prediction, probability in zip(list_sentences, predictions, probabilities):
    print('Sentence:        ', sentence)
    #print('Predicted label: ', prediction.item())
    print('Probabilities    ')
    print('Valid:           ', probability.tolist()[0])
    print('Invalid:         ', probability.tolist()[1])
    print('\n')

    if prediction == 0:
      list_valid.append(sentence)
    else:
      list_invalid.append(sentence)

  return list_valid, list_invalid

# %%
# Step 2: Sentence validity detection

# Separate dataframe sentences into lists of Losses, Hazards, and Constraints
list_loss = df[df['label'] == 0]['sentence'].to_list()
list_hazard = df[df['label'] == 1]['sentence'].to_list()
list_constraint = df[df['label'] == 2]['sentence'].to_list()

# Load models

list_valid_loss = []
list_invalid_loss = []
list_valid_hazard = []
list_invalid_hazard = []
list_valid_constraint = []
list_invalid_constraint = []

# Checks if list is not empty
if list_loss:
  path_step2_loss = path+'beds_step2_loss'
  path_step2_loss = path_step2_loss+'_'+model_preset
  model_step2_loss = AutoModelForSequenceClassification.from_pretrained(path_step2_loss, num_labels=2)

  start = time.perf_counter()
  with torch.no_grad():
    encodings = tokenizer(list_loss, truncation=True, padding='max_length', max_length=512,return_tensors="pt")
    results = model_step2_loss(encodings['input_ids'], encodings['attention_mask'])
    #predictions = np.argmax(results.logits.cpu(), axis=-1)
  end = time.perf_counter()
  print('Step 2 (loss) execution time:', end-start)
  print('Sentence count:')
  print(len(list_loss))
  print('Time per sentence:')
  print((end-start)/len(list_loss))
  list_valid_loss, list_invalid_loss = organize_step2_predictions(results, list_loss) # Returns only the sentences, used in step 3

if list_hazard:
  path_step2_hazard = path+'beds_step2_hazard'
  path_step2_hazard = path_step2_hazard+'_'+model_preset
  model_step2_hazard = AutoModelForSequenceClassification.from_pretrained(path_step2_hazard, num_labels=2)

  start = time.perf_counter()
  with torch.no_grad():
    encodings = tokenizer(list_hazard, truncation=True, padding='max_length', max_length=512,return_tensors="pt")
    results = model_step2_hazard(encodings['input_ids'], encodings['attention_mask'])
    #predictions = np.argmax(results.logits.cpu(), axis=-1)
  end = time.perf_counter()
  print('Step 2 (hazard) execution time:', end-start)
  print('Sentence count:')
  print(len(list_hazard))
  print('Time per sentence:')
  print((end-start)/len(list_hazard))
  list_valid_hazard, list_invalid_hazard = organize_step2_predictions(results, list_hazard) # Returns only the sentences, used in step 3

if list_constraint:
  path_step2_constraint = path+'beds_step2_constraint'
  path_step2_constraint = path_step2_constraint+'_'+model_preset
  model_step2_constraint = AutoModelForSequenceClassification.from_pretrained(path_step2_constraint, num_labels=2)

  start = time.perf_counter()
  with torch.no_grad():
    encodings = tokenizer(list_constraint, truncation=True, padding='max_length', max_length=512,return_tensors="pt")
    results = model_step2_constraint(encodings['input_ids'], encodings['attention_mask'])
    #predictions = np.argmax(results.logits.cpu(), axis=-1)
  end = time.perf_counter()
  print('Step 2 (constraint) execution time:', end-start)
  print('Sentence count:')
  print(len(list_constraint))
  print('Time per sentence:')
  print((end-start)/len(list_constraint))
  list_valid_constraint, list_invalid_constraint = organize_step2_predictions(results, list_constraint) # Returns only the sentences, used in step 3
# Out:
# Step 2 (loss) execution time: 109.59834000800038
# Sentence count:
# 291
# Time per sentence:
# 0.376626597965637
# Sentence:         A non‐patient is injured or killed by radiation.
# Probabilities
# Valid:            0.0031007714569568634
# Invalid:          0.9968992471694946
#
#
# Sentence:         A nonpatient is injured or killed in the process of MRI simulation.
# Probabilities
# Valid:            0.0013928395928815007
# Invalid:          0.9986072182655334
#
#
# Sentence:         Aircraft (including both manned and unmanned systems) in the air are damaged or destroyed.
# Probabilities
# Valid:            0.9998015761375427
# Invalid:          0.0001984951231861487
#
#
# Sentence:         Aircraft crashes into terrain / ocean.
# Probabilities
# Valid:            4.3393438318162225e-06
# Invalid:          0.9999957084655762
#
#
# Sentence:         Aircraft crashes.
# Probabilities
# Valid:            0.00018562533659860492
# Invalid:          0.9998144507408142
#
#
# Sentence:         An incident during this mission directly causes another mission to fail to collect, return, and/or use the scientific data corresponding to its mission goals.
# Probabilities
# Valid:            0.0003234941395930946
# Invalid:          0.9996764659881592
#
#
# Sentence:         Asset damage (ship, battery trailer).
# Probabilities
# Valid:            6.904356996528804e-05
# Invalid:          0.9999309778213501
#
#
# Sentence:         AV collision with vulnerable road user (VRU).
# Probabilities
# Valid:            0.00028411755920387805
# Invalid:          0.9997158646583557
#
#
# Sentence:         AV gets damaged.
# Probabilities
# Valid:            0.9996538162231445
# Invalid:          0.0003462143358774483
#
#
# Sentence:         Collateral Damage.
# Probabilities
# Valid:            0.00023953082563821226
# Invalid:          0.9997604489326477
#
#
# Sentence:         Collision with ISS.
# Probabilities
# Valid:            8.52817356644664e-06
# Invalid:          0.9999914169311523
#
#
# Sentence:         Collisions resulting in loss of life, damage or severe disturbance of daily operation.
# Probabilities
# Valid:            0.00011849100701510906
# Invalid:          0.9998815059661865
#
#
# Sentence:         Company reputation.
# Probabilities
# Valid:            5.4668616940034553e-05
# Invalid:          0.9999452829360962
#
#
# Sentence:         Contaminated Enviroment.
# Probabilities
# Valid:            0.5253534317016602
# Invalid:          0.47464656829833984
#
#
# Sentence:         Damage and/or interruption of operations of other systems (Supporting infrastructure, other satellites, all other equipment).
# Probabilities
# Valid:            0.9998955726623535
# Invalid:          0.00010445529915159568
#
#
# Sentence:         Damage of property (internal or external company).
# Probabilities
# Valid:            0.9999480247497559
# Invalid:          5.198229700908996e-05
#
#
# Sentence:         Damage or loss of equipment.
# Probabilities
# Valid:            0.9999983310699463
# Invalid:          1.6219038343479042e-06
#
#
# Sentence:         Damage or loss of equipment.
# Probabilities
# Valid:            0.9999983310699463
# Invalid:          1.6219038343479042e-06
#
#
# Sentence:         Damage or loss of equipment.
# Probabilities
# Valid:            0.9999983310699463
# Invalid:          1.6219038343479042e-06
#
#
# Sentence:         Damage to airport infra-structure and/or proximities.
# Probabilities
# Valid:            0.9999829530715942
# Invalid:          1.706375951471273e-05
#
#
# Sentence:         Damage to equipment or infrastructure.
# Probabilities
# Valid:            0.9999812841415405
# Invalid:          1.8713302779360674e-05
#
#
# Sentence:         damage to equipment.
# Probabilities
# Valid:            0.9999758005142212
# Invalid:          2.4238863261416554e-05
#
#
# Sentence:         Damage to equipment.
# Probabilities
# Valid:            0.9999924898147583
# Invalid:          7.523985004809219e-06
#
#
# Sentence:         Damage to equipment.
# Probabilities
# Valid:            0.9999924898147583
# Invalid:          7.523985004809219e-06
#
#
# Sentence:         Damage to or loss of aircraft.
# Probabilities
# Valid:            0.999980092048645
# Invalid:          1.9870891264872625e-05
#
#
# Sentence:         Damage to patient or staff satisfaction, or hospital reputation.
# Probabilities
# Valid:            0.9999221563339233
# Invalid:          7.789250230416656e-05
#
#
# Sentence:         Damage to SSRMS.
# Probabilities
# Valid:            0.9999837875366211
# Invalid:          1.6174217307707295e-05
#
#
# Sentence:         Damage to the aircraft or objects outside the aircraft.
# Probabilities
# Valid:            0.9999085664749146
# Invalid:          9.140879410551861e-05
#
#
# Sentence:         Damage to the aircraft.
# Probabilities
# Valid:            0.9999618530273438
# Invalid:          3.8129277527332306e-05
#
#
# Sentence:         Damage to the Laboratorial Facility or the laboratory equipment.
# Probabilities
# Valid:            0.9998936653137207
# Invalid:          0.0001062895025825128
#
#
# Sentence:         Damage to the ship or objects outside the ship.
# Probabilities
# Valid:            0.9999396800994873
# Invalid:          6.035254045855254e-05
#
#
# Sentence:         Damage to the vehicle or objects outside the vehicle.
# Probabilities
# Valid:            0.9999697208404541
# Invalid:          3.02397947962163e-05
#
#
# Sentence:         Damage to the vehicle.
# Probabilities
# Valid:            0.9999661445617676
# Invalid:          3.39109574269969e-05
#
#
# Sentence:         Damage to valuable SGC components.
# Probabilities
# Valid:            0.9999890327453613
# Invalid:          1.097300810215529e-05
#
#
# Sentence:         Death or Human injury.
# Probabilities
# Valid:            0.9999558925628662
# Invalid:          4.4092499592807144e-05
#
#
# Sentence:         Death or injury of patient or non-patient not due to radiation.
# Probabilities
# Valid:            0.0003198939375579357
# Invalid:          0.9996801614761353
#
#
# Sentence:         Death or injury to persons.
# Probabilities
# Valid:            0.9999932050704956
# Invalid:          6.7580272116174456e-06
#
#
# Sentence:         Death or injury.
# Probabilities
# Valid:            0.9997565150260925
# Invalid:          0.00024347090220544487
#
#
# Sentence:         Death or serious injury to rider or operator.
# Probabilities
# Valid:            0.9997047781944275
# Invalid:          0.00029524718411266804
#
#
# Sentence:         Death, illness, or injury due to exposure to toxic chemicals.
# Probabilities
# Valid:            0.0007311419467441738
# Invalid:          0.9992688298225403
#
#
# Sentence:         Death, injury, or property damage resulting from a collision with a person, vehicle, object, or terrain.
# Probabilities
# Valid:            0.00011056898802053183
# Invalid:          0.9998893737792969
#
#
# Sentence:         Disruption on processing or transport.
# Probabilities
# Valid:            0.9999269247055054
# Invalid:          7.301221194211394e-05
#
#
# Sentence:         Doors close on passenger in doorway.
# Probabilities
# Valid:            0.0012072508689016104
# Invalid:          0.9987927675247192
#
#
# Sentence:         During a rejected takeoff the aircraft departs runway.
# Probabilities
# Valid:            2.103667429764755e-05
# Invalid:          0.9999790191650391
#
#
# Sentence:         Economic loss.
# Probabilities
# Valid:            0.9999992847442627
# Invalid:          6.744132861058461e-07
#
#
# Sentence:         Enviromental losses.
# Probabilities
# Valid:            0.9998353719711304
# Invalid:          0.00016461731866002083
#
#
# Sentence:         Environment contaminated.
# Probabilities
# Valid:            4.060502760694362e-05
# Invalid:          0.9999593496322632
#
#
# Sentence:         Environmental Damage.
# Probabilities
# Valid:            0.9775441884994507
# Invalid:          0.022455837577581406
#
#
# Sentence:         Environmental loss (release).
# Probabilities
# Valid:            0.9999955892562866
# Invalid:          4.363607786217472e-06
#
#
# Sentence:         Environmental loss.
# Probabilities
# Valid:            0.9999990463256836
# Invalid:          9.959178441931726e-07
#
#
# Sentence:         Environmental loss/pollution.
# Probabilities
# Valid:            0.9997984766960144
# Invalid:          0.00020156055688858032
#
#
# Sentence:         Environmental losses.
# Probabilities
# Valid:            0.9999920129776001
# Invalid:          8.00314410298597e-06
#
#
# Sentence:         Environmental losses.
# Probabilities
# Valid:            0.9999920129776001
# Invalid:          8.00314410298597e-06
#
#
# Sentence:         Environmental: oil and fuel pollution, debris in nature.
# Probabilities
# Valid:            0.7845088243484497
# Invalid:          0.21549111604690552
#
#
# Sentence:         Equipment damage (economic loss).
# Probabilities
# Valid:            0.9999996423721313
# Invalid:          3.115612798865186e-07
#
#
# Sentence:         Equipment Damage.
# Probabilities
# Valid:            0.9997052550315857
# Invalid:          0.0002947347529698163
#
#
# Sentence:         Erroneous arrival of product.
# Probabilities
# Valid:            0.00010106775152962655
# Invalid:          0.9998989105224609
#
#
# Sentence:         Erroneous payment to supplier.
# Probabilities
# Valid:            0.0026126536540687084
# Invalid:          0.9973873496055603
#
#
# Sentence:         Facility or equipment damage.
# Probabilities
# Valid:            0.9964116215705872
# Invalid:          0.0035883800592273474
#
#
# Sentence:         Fatalities or injury to persons.
# Probabilities
# Valid:            0.999985933303833
# Invalid:          1.4114996702119242e-05
#
#
# Sentence:         Fatalities.
# Probabilities
# Valid:            6.293581827776507e-05
# Invalid:          0.9999370574951172
#
#
# Sentence:         Financial loss or loss of hospital reputation.
# Probabilities
# Valid:            0.9999998807907104
# Invalid:          1.2906576785098878e-07
#
#
# Sentence:         Financial loss or loss of hospital reputation.
# Probabilities
# Valid:            0.9999998807907104
# Invalid:          1.2906576785098878e-07
#
#
# Sentence:         Financial loss.
# Probabilities
# Valid:            0.9999971389770508
# Invalid:          2.8387189558998216e-06
#
#
# Sentence:         Financial losses.
# Probabilities
# Valid:            0.9999788999557495
# Invalid:          2.1135267161298543e-05
#
#
# Sentence:         Human injury or loss of life.
# Probabilities
# Valid:            0.9999902248382568
# Invalid:          9.774194040801376e-06
#
#
# Sentence:         Human life, injury, motion sickness, fright.
# Probabilities
# Valid:            0.999995231628418
# Invalid:          4.767066457134206e-06
#
#
# Sentence:         Human serious injury or loss of life.
# Probabilities
# Valid:            0.9999935626983643
# Invalid:          6.4102896430995315e-06
#
#
# Sentence:         Humans and/or human assets off of the earth are killed/damaged.
# Probabilities
# Valid:            0.9999496936798096
# Invalid:          5.025401696912013e-05
#
#
# Sentence:         Humans and/or human assets on earth are killed/damaged.
# Probabilities
# Valid:            0.9999216794967651
# Invalid:          7.83440045779571e-05
#
#
# Sentence:         Humans injured or killed (On earth, in air, in space).
# Probabilities
# Valid:            0.8017648458480835
# Invalid:          0.1982351541519165
#
#
# Sentence:         Inability to complete the mission.
# Probabilities
# Valid:            2.6597923351801e-05
# Invalid:          0.9999734163284302
#
#
# Sentence:         Indirect monetary losses.
# Probabilities
# Valid:            0.9999916553497314
# Invalid:          8.345291462319437e-06
#
#
# Sentence:         Ineffective treatment.
# Probabilities
# Valid:            8.128381159622222e-05
# Invalid:          0.9999186992645264
#
#
# Sentence:         Injury of passenger and crew.
# Probabilities
# Valid:            0.7739147543907166
# Invalid:          0.22608530521392822
#
#
# Sentence:         Injury or Death.
# Probabilities
# Valid:            0.00021619992912746966
# Invalid:          0.9997838139533997
#
#
# Sentence:         injury or loss of life.
# Probabilities
# Valid:            0.9999964237213135
# Invalid:          3.602855940698646e-06
#
#
# Sentence:         Injury or loss of life.
# Probabilities
# Valid:            0.999610960483551
# Invalid:          0.000389010994695127
#
#
# Sentence:         Injury or property damage occurring within the vehicle, without a collision.
# Probabilities
# Valid:            0.9999197721481323
# Invalid:          8.016945503186435e-05
#
#
# Sentence:         Injury, loss of life, damage of aircraft or property.
# Probabilities
# Valid:            0.00039814517367631197
# Invalid:          0.9996019005775452
#
#
# Sentence:         Level 1 SMS audit findings for non/compliance.
# Probabilities
# Valid:            0.0010158447548747063
# Invalid:          0.998984158039093
#
#
# Sentence:         Loss due to rescheduling.
# Probabilities
# Valid:            0.00012493836402427405
# Invalid:          0.9998750686645508
#
#
# Sentence:         Loss of A/C;
# Probabilities
# Valid:            0.999967098236084
# Invalid:          3.295730130048469e-05
#
#
# Sentence:         Loss of Acme Intellectual Property.
# Probabilities
# Valid:            0.9999943971633911
# Invalid:          5.61521574127255e-06
#
#
# Sentence:         Loss of aircraft.
# Probabilities
# Valid:            0.9996034502983093
# Invalid:          0.0003965370124205947
#
#
# Sentence:         Loss of classified information.
# Probabilities
# Valid:            0.9998605251312256
# Invalid:          0.00013944633246865124
#
#
# Sentence:         Loss of client satisfaction.
# Probabilities
# Valid:            0.9999997615814209
# Invalid:          2.7235910238232464e-07
#
#
# Sentence:         Loss of company reputation.
# Probabilities
# Valid:            0.9999966621398926
# Invalid:          3.2915477277128957e-06
#
#
# Sentence:         Loss of confidence in aircraft systems.
# Probabilities
# Valid:            0.999992847442627
# Invalid:          7.154593731684145e-06
#
#
# Sentence:         Loss of confidence in the safety of drinking water supplied to the public.
# Probabilities
# Valid:            0.9999252557754517
# Invalid:          7.473382720490918e-05
#
#
# Sentence:         Loss of consumer (rider) PII.
# Probabilities
# Valid:            0.9999903440475464
# Invalid:          9.643247722124215e-06
#
#
# Sentence:         Loss of control in the air.
# Probabilities
# Valid:            9.229386341758072e-05
# Invalid:          0.9999077320098877
#
#
# Sentence:         Loss of control on ground.
# Probabilities
# Valid:            0.00032028972054831684
# Invalid:          0.999679684638977
#
#
# Sentence:         Loss of credibility in the air transportation industry.
# Probabilities
# Valid:            0.9999915361404419
# Invalid:          8.440545570920222e-06
#
#
# Sentence:         Loss of Critical Protected Data.
# Probabilities
# Valid:            0.9999955892562866
# Invalid:          4.397144039103296e-06
#
#
# Sentence:         Loss of customer preference/ brand loyalty.
# Probabilities
# Valid:            0.9999972581863403
# Invalid:          2.702874780879938e-06
#
#
# Sentence:         Loss of customer satisfaction with automated parking, without injury or property damage.
# Probabilities
# Valid:            0.9999924898147583
# Invalid:          7.46429395803716e-06
#
#
# Sentence:         Loss of customer satisfaction.
# Probabilities
# Valid:            0.9999990463256836
# Invalid:          9.333903676633781e-07
#
#
# Sentence:         Loss of customer satisfaction.
# Probabilities
# Valid:            0.9999990463256836
# Invalid:          9.333903676633781e-07
#
#
# Sentence:         Loss of customer satisfaction.
# Probabilities
# Valid:            0.9999990463256836
# Invalid:          9.333903676633781e-07
#
#
# Sentence:         Loss of customers.
# Probabilities
# Valid:            0.9999970197677612
# Invalid:          2.958019649668131e-06
#
#
# Sentence:         Loss of data quality.
# Probabilities
# Valid:            0.9999138116836548
# Invalid:          8.615027763880789e-05
#
#
# Sentence:         Loss of driver comfort.
# Probabilities
# Valid:            0.9999692440032959
# Invalid:          3.069630838581361e-05
#
#
# Sentence:         Loss of economic stability (e.g. closure of business / increases in unemployment, decrease in purchasing power).
# Probabilities
# Valid:            0.999945878982544
# Invalid:          5.4079628171166405e-05
#
#
# Sentence:         Loss of electrical power generation.
# Probabilities
# Valid:            0.9999707937240601
# Invalid:          2.923231659224257e-05
#
#
# Sentence:         Loss of environmental integrity.
# Probabilities
# Valid:            0.9999980926513672
# Invalid:          1.9557530777092325e-06
#
#
# Sentence:         Loss of equipment.
# Probabilities
# Valid:            0.9999985694885254
# Invalid:          1.4395802736544283e-06
#
#
# Sentence:         Loss of finances.
# Probabilities
# Valid:            0.9999995231628418
# Invalid:          5.122448101246846e-07
#
#
# Sentence:         Loss of flight test productivity.
# Probabilities
# Valid:            0.9999727010726929
# Invalid:          2.7272524675936438e-05
#
#
# Sentence:         Loss of functioning democratic society (e.g. loss of freedom, human right .etc.).
# Probabilities
# Valid:            0.9999985694885254
# Invalid:          1.4341496807901422e-06
#
#
# Sentence:         Loss of Generation.
# Probabilities
# Valid:            0.999954342842102
# Invalid:          4.5616194256581366e-05
#
#
# Sentence:         Loss of generation.
# Probabilities
# Valid:            0.9999843835830688
# Invalid:          1.5606459783157334e-05
#
#
# Sentence:         Loss of grid equipment (capacitors, lines, et.c).
# Probabilities
# Valid:            0.9999567270278931
# Invalid:          4.324701149016619e-05
#
#
# Sentence:         Loss of ground support operation.
# Probabilities
# Valid:            0.9998762607574463
# Invalid:          0.00012372730998322368
#
#
# Sentence:         Loss of HTV mission.
# Probabilities
# Valid:            0.9999755620956421
# Invalid:          2.4413686332991347e-05
#
#
# Sentence:         Loss of human life - human injury.
# Probabilities
# Valid:            0.9999977350234985
# Invalid:          2.2565509425476193e-06
#
#
# Sentence:         Loss of human life / damage to health and wellbeing (e.g. long term concerns with COVID).
# Probabilities
# Valid:            0.9998569488525391
# Invalid:          0.0001430384727427736
#
#
# Sentence:         Loss of human life or human injury of laboratory-related personnel.
# Probabilities
# Valid:            0.9999376535415649
# Invalid:          6.232078885659575e-05
#
#
# Sentence:         Loss of human life or human injury of personnel external to the laboratory facilities.
# Probabilities
# Valid:            0.9999467134475708
# Invalid:          5.33338388777338e-05
#
#
# Sentence:         Loss of human life or injured people.
# Probabilities
# Valid:            0.9999889135360718
# Invalid:          1.1074626854679082e-05
#
#
# Sentence:         Loss of human life or injury.
# Probabilities
# Valid:            0.9999986886978149
# Invalid:          1.2627947398868855e-06
#
#
# Sentence:         Loss of Human Life, Human Injury, Properties Damage or Environmental Losses.
# Probabilities
# Valid:            0.9999951124191284
# Invalid:          4.848314347327687e-06
#
#
# Sentence:         Loss of human life/injury.
# Probabilities
# Valid:            0.9999979734420776
# Invalid:          2.077722456306219e-06
#
#
# Sentence:         Loss of human live or severe human injury or property damage.
# Probabilities
# Valid:            0.9999967813491821
# Invalid:          3.1681749987910734e-06
#
#
# Sentence:         Loss of integrity of communication.
# Probabilities
# Valid:            0.0006115185678936541
# Invalid:          0.9993884563446045
#
#
# Sentence:         Loss of Intellectual Property.
# Probabilities
# Valid:            0.9999958276748657
# Invalid:          4.211941813991871e-06
#
#
# Sentence:         Loss of Life / Injury (suffocation, eye/ear irritation etc.).
# Probabilities
# Valid:            0.9999949932098389
# Invalid:          5.000999408366624e-06
#
#
# Sentence:         Loss of life and injury.
# Probabilities
# Valid:            0.9999990463256836
# Invalid:          1.009350171443657e-06
#
#
# Sentence:         Loss of life or injury to patient or personnel.
# Probabilities
# Valid:            0.9999821186065674
# Invalid:          1.7918810044648126e-05
#
#
# Sentence:         Loss of life or injury to people.
# Probabilities
# Valid:            0.9999991655349731
# Invalid:          8.848649599713099e-07
#
#
# Sentence:         Loss of life or injury to people.
# Probabilities
# Valid:            0.9999991655349731
# Invalid:          8.848649599713099e-07
#
#
# Sentence:         Loss of life or injury to people.
# Probabilities
# Valid:            0.9999991655349731
# Invalid:          8.848649599713099e-07
#
#
# Sentence:         Loss of life or injury to people.
# Probabilities
# Valid:            0.9999991655349731
# Invalid:          8.848649599713099e-07
#
#
# Sentence:         Loss of life or injury to personnel.
# Probabilities
# Valid:            0.9999986886978149
# Invalid:          1.3329531611816492e-06
#
#
# Sentence:         Loss of life or injury to persons.
# Probabilities
# Valid:            0.9999996423721313
# Invalid:          3.451729071457521e-07
#
#
# Sentence:         Loss of life or injury.
# Probabilities
# Valid:            0.9999983310699463
# Invalid:          1.6287611970255966e-06
#
#
# Sentence:         Loss of life or injury/health.
# Probabilities
# Valid:            0.9999974966049194
# Invalid:          2.461606754877721e-06
#
#
# Sentence:         Loss of life or serious injury to patient.
# Probabilities
# Valid:            0.999998927116394
# Invalid:          1.1278511919954326e-06
#
#
# Sentence:         Loss of life or serious injury to patient.
# Probabilities
# Valid:            0.999998927116394
# Invalid:          1.1278511919954326e-06
#
#
# Sentence:         Loss of life or serious injury to people.
# Probabilities
# Valid:            0.9999992847442627
# Invalid:          6.996721708674158e-07
#
#
# Sentence:         Loss of life or serious injury to people.
# Probabilities
# Valid:            0.9999992847442627
# Invalid:          6.996721708674158e-07
#
#
# Sentence:         Loss of life or serious injury to people.
# Probabilities
# Valid:            0.9999992847442627
# Invalid:          6.996721708674158e-07
#
#
# Sentence:         Loss of life, injury or health compromise.
# Probabilities
# Valid:            0.9999819993972778
# Invalid:          1.799518577172421e-05
#
#
# Sentence:         Loss of life/injury.
# Probabilities
# Valid:            0.9999922513961792
# Invalid:          7.744038157397881e-06
#
#
# Sentence:         Loss of life/serious injury.
# Probabilities
# Valid:            0.999984860420227
# Invalid:          1.5148104466788936e-05
#
#
# Sentence:         Loss of manufacturing/production capability (loss of continued production ability: robot, facility, etc.).
# Probabilities
# Valid:            0.999523401260376
# Invalid:          0.00047664743033237755
#
#
# Sentence:         Loss of mission (or performance degradation).
# Probabilities
# Valid:            0.9998838901519775
# Invalid:          0.00011610198271228
#
#
# Sentence:         Loss of mission (transportation).
# Probabilities
# Valid:            0.9999581575393677
# Invalid:          4.188872844679281e-05
#
#
# Sentence:         Loss of mission.
# Probabilities
# Valid:            0.9999884366989136
# Invalid:          1.1529090443218593e-05
#
#
# Sentence:         Loss of mission.
# Probabilities
# Valid:            0.9999884366989136
# Invalid:          1.1529090443218593e-05
#
#
# Sentence:         Loss of Mission.
# Probabilities
# Valid:            0.9999972581863403
# Invalid:          2.6945876925310586e-06
#
#
# Sentence:         Loss of mission.
# Probabilities
# Valid:            0.9999884366989136
# Invalid:          1.1529090443218593e-05
#
#
# Sentence:         Loss of mission.
# Probabilities
# Valid:            0.9999884366989136
# Invalid:          1.1529090443218593e-05
#
#
# Sentence:         Loss of or damage to aircraft.
# Probabilities
# Valid:            0.9999986886978149
# Invalid:          1.2831579851990682e-06
#
#
# Sentence:         Loss of or damage to aircraft.
# Probabilities
# Valid:            0.9999986886978149
# Invalid:          1.2831579851990682e-06
#
#
# Sentence:         Loss of or damage to infrastructure components.
# Probabilities
# Valid:            0.9999998807907104
# Invalid:          1.0497115709995342e-07
#
#
# Sentence:         Loss of or damage to service vehicle/equipment.
# Probabilities
# Valid:            0.9999972581863403
# Invalid:          2.6879940833168803e-06
#
#
# Sentence:         Loss of or damage to the aircraft or  equipment on the aircraft.
# Probabilities
# Valid:            0.999991774559021
# Invalid:          8.274972969957162e-06
#
#
# Sentence:         Loss of or damage to UAV aircraft.
# Probabilities
# Valid:            0.9999099969863892
# Invalid:          9.000291902339086e-05
#
#
# Sentence:         Loss of personal identifiable information (PII).
# Probabilities
# Valid:            0.9999630451202393
# Invalid:          3.697915599332191e-05
#
#
# Sentence:         Loss of produced energetic material.
# Probabilities
# Valid:            0.9999750852584839
# Invalid:          2.4897328330553137e-05
#
#
# Sentence:         Loss of product certification.
# Probabilities
# Valid:            0.9999964237213135
# Invalid:          3.6062901926925406e-06
#
#
# Sentence:         Loss of production.
# Probabilities
# Valid:            0.999992847442627
# Invalid:          7.107512828952167e-06
#
#
# Sentence:         Loss of protected patient or proprietary hospital information.
# Probabilities
# Valid:            0.9999301433563232
# Invalid:          6.987723463680595e-05
#
#
# Sentence:         Loss of protected patient or proprietary hospital information.
# Probabilities
# Valid:            0.9999301433563232
# Invalid:          6.987723463680595e-05
#
#
# Sentence:         Loss of reputation (OEM and/or supplier).
# Probabilities
# Valid:            0.999932050704956
# Invalid:          6.791044143028557e-05
#
#
# Sentence:         Loss of reputation or trust in laboratory data ecosystem.
# Probabilities
# Valid:            0.9999765157699585
# Invalid:          2.348792986595072e-05
#
#
# Sentence:         Loss of reputation.
# Probabilities
# Valid:            0.9999973773956299
# Invalid:          2.6768586849357234e-06
#
#
# Sentence:         Loss of Reputation.
# Probabilities
# Valid:            0.9997151494026184
# Invalid:          0.0002847778960131109
#
#
# Sentence:         Loss of reputation.
# Probabilities
# Valid:            0.9999973773956299
# Invalid:          2.6768586849357234e-06
#
#
# Sentence:         Loss of ship's structural integrity/watertightness.
# Probabilities
# Valid:            0.0007048531551845372
# Invalid:          0.9992951154708862
#
#
# Sentence:         Loss of stability of the ship.
# Probabilities
# Valid:            0.9998651742935181
# Invalid:          0.00013483647489920259
#
#
# Sentence:         Loss of the well.
# Probabilities
# Valid:            0.9999994039535522
# Invalid:          6.138735670901951e-07
#
#
# Sentence:         Loss of time (inefficient operation).
# Probabilities
# Valid:            0.9999885559082031
# Invalid:          1.1392373380658682e-05
#
#
# Sentence:         Loss of transportation.
# Probabilities
# Valid:            0.9999933242797852
# Invalid:          6.645422672590939e-06
#
#
# Sentence:         Loss of/damage to plant.
# Probabilities
# Valid:            0.9999986886978149
# Invalid:          1.3561732430389384e-06
#
#
# Sentence:         Loss or damage of product.
# Probabilities
# Valid:            0.9999995231628418
# Invalid:          5.207433559917263e-07
#
#
# Sentence:         Loss or damage of production equipment.
# Probabilities
# Valid:            0.9999912977218628
# Invalid:          8.754540431255009e-06
#
#
# Sentence:         Loss or damage to aircraft.
# Probabilities
# Valid:            0.9999920129776001
# Invalid:          7.974838808877394e-06
#
#
# Sentence:         Loss or Damage to components / products.
# Probabilities
# Valid:            0.9999940395355225
# Invalid:          5.909517767577199e-06
#
#
# Sentence:         Loss or damage to ego vehicle.
# Probabilities
# Valid:            0.9999971389770508
# Invalid:          2.8774147722288035e-06
#
#
# Sentence:         Loss or damage to public or private properties.
# Probabilities
# Valid:            0.999995231628418
# Invalid:          4.7087705752346665e-06
#
#
# Sentence:         Loss or damage to test environments.
# Probabilities
# Valid:            0.9999908208847046
# Invalid:          9.131502338277642e-06
#
#
# Sentence:         Loss or damage to the vehicle.
# Probabilities
# Valid:            0.9999986886978149
# Invalid:          1.2766546433340409e-06
#
#
# Sentence:         Loss or disclosure of sensitive information.
# Probabilities
# Valid:            0.9999513626098633
# Invalid:          4.862676723860204e-05
#
#
# Sentence:         Loss or major damage to aircraft.
# Probabilities
# Valid:            0.999964714050293
# Invalid:          3.527915760059841e-05
#
#
# Sentence:         Loss or significant damage to the aircraft.
# Probabilities
# Valid:            0.9999964237213135
# Invalid:          3.621703172029811e-06
#
#
# Sentence:         Loss to non-patient quality of life (esp. personnel).
# Probabilities
# Valid:            0.9999935626983643
# Invalid:          6.433912403736031e-06
#
#
# Sentence:         Loss/damage to aircraft and its equipment.
# Probabilities
# Valid:            0.9998468160629272
# Invalid:          0.0001531262241769582
#
#
# Sentence:         Lost Generation.
# Probabilities
# Valid:            5.563235390582122e-05
# Invalid:          0.9999443292617798
#
#
# Sentence:         Material or financial.
# Probabilities
# Valid:            8.745543891564012e-05
# Invalid:          0.9999125003814697
#
#
# Sentence:         Mission delay.
# Probabilities
# Valid:            0.0001843634236138314
# Invalid:          0.9998156428337097
#
#
# Sentence:         Mission Interruption or delay.
# Probabilities
# Valid:            0.0014893797924742103
# Invalid:          0.9985106587409973
#
#
# Sentence:         Mission loss (Unable to perform mission to design standards) (LOM).
# Probabilities
# Valid:            0.9997631907463074
# Invalid:          0.0002368440618738532
#
#
# Sentence:         Mission loss or degradation.
# Probabilities
# Valid:            0.9931695461273193
# Invalid:          0.0068303984589874744
#
#
# Sentence:         Mission Non-Compliance.
# Probabilities
# Valid:            0.999890923500061
# Invalid:          0.00010905195085797459
#
#
# Sentence:         Monetary losses.
# Probabilities
# Valid:            0.9999687671661377
# Invalid:          3.1175259209703654e-05
#
#
# Sentence:         Multiple fatalities.
# Probabilities
# Valid:            0.1234065368771553
# Invalid:          0.8765934109687805
#
#
# Sentence:         Non-patient injured or killed by radiation.
# Probabilities
# Valid:            4.2660893086576834e-05
# Invalid:          0.9999573230743408
#
#
# Sentence:         Non-patient injured or killed due to radiation.
# Probabilities
# Valid:            1.1805059330072254e-05
# Invalid:          0.9999881982803345
#
#
# Sentence:         One or more fatalities or significant injuries.
# Probabilities
# Valid:            0.999816358089447
# Invalid:          0.00018361570255365223
#
#
# Sentence:         Operating Unit cannot meet operational requirements or commitments.
# Probabilities
# Valid:            0.0002927299647126347
# Invalid:          0.9997072815895081
#
#
# Sentence:         Organisms of Earth origin are mistaken for organisms indigenous to any of the moons of the outer planet in future missions to study the outer planet's moon.
# Probabilities
# Valid:            0.00046142199425958097
# Invalid:          0.9995386600494385
#
#
# Sentence:         Organisms on any of the moons of the outer planet (if they exist) are killed or mutated by biological agents of Earth Origin.
# Probabilities
# Valid:            0.0004427113162819296
# Invalid:          0.9995573163032532
#
#
# Sentence:         Passenger falls out of moving train.
# Probabilities
# Valid:            3.6994111724197865e-05
# Invalid:          0.9999630451202393
#
#
# Sentence:         Passenger steps off stopped train not at platform.
# Probabilities
# Valid:            0.00014440408267546445
# Invalid:          0.9998555183410645
#
#
# Sentence:         Passengers not able to escape train during emergency.
# Probabilities
# Valid:            0.9998841285705566
# Invalid:          0.00011583734885789454
#
#
# Sentence:         Patient injured or killed due to radiation.
# Probabilities
# Valid:            1.0660470252332743e-05
# Invalid:          0.99998939037323
#
#
# Sentence:         Patient injured or killed from radiation exposure.
# Probabilities
# Valid:            1.760196937539149e-05
# Invalid:          0.9999823570251465
#
#
# Sentence:         Patient injured or killed from radiation exposure.
# Probabilities
# Valid:            1.760196937539149e-05
# Invalid:          0.9999823570251465
#
#
# Sentence:         Patient injured or killed from radiation exposure.
# Probabilities
# Valid:            1.760196937539149e-05
# Invalid:          0.9999823570251465
#
#
# Sentence:         Patient injury or death.
# Probabilities
# Valid:            0.9883829951286316
# Invalid:          0.011617067269980907
#
#
# Sentence:         Patient is killed or seriously injured.
# Probabilities
# Valid:            0.9999791383743286
# Invalid:          2.084690822812263e-05
#
#
# Sentence:         patient is killed or seriously injured.
# Probabilities
# Valid:            0.9999837875366211
# Invalid:          1.616985355212819e-05
#
#
# Sentence:         Patient suffers physical, non-radiological injury.
# Probabilities
# Valid:            0.9998204112052917
# Invalid:          0.0001795930293155834
#
#
# Sentence:         Patient suffers radiological injury due to over-radiation.
# Probabilities
# Valid:            0.00018427835311740637
# Invalid:          0.9998157620429993
#
#
# Sentence:         Patient’s cancer advances due to under-radiation.
# Probabilities
# Valid:            6.226221739780158e-05
# Invalid:          0.9999377727508545
#
#
# Sentence:         Patient’s pain is not relieved.
# Probabilities
# Valid:            0.9998774528503418
# Invalid:          0.0001225278538186103
#
#
# Sentence:         Patient’s pain is not relieved.
# Probabilities
# Valid:            0.9998774528503418
# Invalid:          0.0001225278538186103
#
#
# Sentence:         Payment loss.
# Probabilities
# Valid:            0.9999551773071289
# Invalid:          4.4820408220402896e-05
#
#
# Sentence:         People die or get injured from road crashes.
# Probabilities
# Valid:            0.0004495881439652294
# Invalid:          0.9995504021644592
#
#
# Sentence:         People exposed to chemicals.
# Probabilities
# Valid:            0.030835885554552078
# Invalid:          0.9691641330718994
#
#
# Sentence:         People injured or killed.
# Probabilities
# Valid:            0.9998045563697815
# Invalid:          0.00019545988470781595
#
#
# Sentence:         People physically injured (e.g. explosion).
# Probabilities
# Valid:            0.9964569211006165
# Invalid:          0.003543008118867874
#
#
# Sentence:         Personnel on the ground are injured or killed.
# Probabilities
# Valid:            0.8997241854667664
# Invalid:          0.10027585923671722
#
#
# Sentence:         Physical damage to patient or non‐patient during treatment (not from radiation).
# Probabilities
# Valid:            0.0005084077129140496
# Invalid:          0.9994915723800659
#
#
# Sentence:         Physical injury to patient or non-patient during treatment.
# Probabilities
# Valid:            0.03990680351853371
# Invalid:          0.9600932002067566
#
#
# Sentence:         Physical injury to patient or staff during treatment (not from RT).
# Probabilities
# Valid:            0.0001794179406715557
# Invalid:          0.9998206496238708
#
#
# Sentence:         Poor safety performance.
# Probabilities
# Valid:            7.93919462012127e-05
# Invalid:          0.9999206066131592
#
#
# Sentence:         Power shortages.
# Probabilities
# Valid:            4.393568815430626e-05
# Invalid:          0.9999560117721558
#
#
# Sentence:         Product integrity compromised.
# Probabilities
# Valid:            5.894949572393671e-05
# Invalid:          0.9999409914016724
#
#
# Sentence:         Product loss.
# Probabilities
# Valid:            0.9999618530273438
# Invalid:          3.808984547504224e-05
#
#
# Sentence:         Production loss.
# Probabilities
# Valid:            0.9999576807022095
# Invalid:          4.235734377289191e-05
#
#
# Sentence:         Property damage from road crashes.
# Probabilities
# Valid:            0.17046940326690674
# Invalid:          0.8295305967330933
#
#
# Sentence:         Radiation Exposure.
# Probabilities
# Valid:            0.00023790165141690522
# Invalid:          0.9997621178627014
#
#
# Sentence:         Ready For Operation Target Date not achieved.
# Probabilities
# Valid:            0.00048251269618049264
# Invalid:          0.9995174407958984
#
#
# Sentence:         Reduced gas production.
# Probabilities
# Valid:            0.9995337724685669
# Invalid:          0.00046623926027677953
#
#
# Sentence:         Rework and project schedule timeline losses.
# Probabilities
# Valid:            1.581275137141347e-05
# Invalid:          0.9999841451644897
#
#
# Sentence:         Scheduled work is not completed on time.
# Probabilities
# Valid:            0.004323148168623447
# Invalid:          0.9956768155097961
#
#
# Sentence:         Scientific mission is not performed (mission loss).
# Probabilities
# Valid:            0.9261649250984192
# Invalid:          0.07383512705564499
#
#
# Sentence:         Serious injury or fatality to personnel.
# Probabilities
# Valid:            0.999708354473114
# Invalid:          0.00029166103922761977
#
#
# Sentence:         Significant damage to other people's property.
# Probabilities
# Valid:            0.9999700784683228
# Invalid:          2.9887471100664698e-05
#
#
# Sentence:         Significant Damage to Smart Coaster.
# Probabilities
# Valid:            0.9997655749320984
# Invalid:          0.0002344157110201195
#
#
# Sentence:         Significant damage to the port system infrastructure.
# Probabilities
# Valid:            0.9999690055847168
# Invalid:          3.1004310585558414e-05
#
#
# Sentence:         Significant devaluation of Acme stock.
# Probabilities
# Valid:            0.9997759461402893
# Invalid:          0.0002241042093373835
#
#
# Sentence:         Significant environmental release (possibly only minor for this application).
# Probabilities
# Valid:            0.00012562192569021136
# Invalid:          0.9998743534088135
#
#
# Sentence:         Significant loss of revenue.
# Probabilities
# Valid:            0.9999994039535522
# Invalid:          5.607406592389452e-07
#
#
# Sentence:         Spacecraft lost.
# Probabilities
# Valid:            0.9993035793304443
# Invalid:          0.0006963761989027262
#
#
# Sentence:         Staff injured or killed from radiation exposure.
# Probabilities
# Valid:            0.00022530763817485422
# Invalid:          0.9997747540473938
#
#
# Sentence:         Staff suffers injury (radiological or physical).
# Probabilities
# Valid:            0.9998869895935059
# Invalid:          0.0001129611991927959
#
#
# Sentence:         Stain to reputation.
# Probabilities
# Valid:            0.9998879432678223
# Invalid:          0.00011204407928744331
#
#
# Sentence:         Structures on the ground are damaged or destroyed.
# Probabilities
# Valid:            0.9999493360519409
# Invalid:          5.067167148808949e-05
#
#
# Sentence:         Systems or equipment are damaged.
# Probabilities
# Valid:            0.9999639987945557
# Invalid:          3.5983732232125476e-05
#
#
# Sentence:         Testing or flight operations are unable to be conducted.
# Probabilities
# Valid:            0.0003121054032817483
# Invalid:          0.999687910079956
#
#
# Sentence:         The ACC vehicle crashes with a vehicle in front when the ACC system is in active mode (Forward Collision vehicle to vehicle).
# Probabilities
# Valid:            0.00011068840103689581
# Invalid:          0.9998892545700073
#
#
# Sentence:         The patient is injured or killed from subsequent treatment due to inaccurate MRI simulation.
# Probabilities
# Valid:            4.727271880256012e-05
# Invalid:          0.9999526739120483
#
#
# Sentence:         The patient is injured or killed in the process of MRI simulation.
# Probabilities
# Valid:            0.00043775021913461387
# Invalid:          0.9995622038841248
#
#
# Sentence:         The scientific data corresponding to the mission goals are not collected.
# Probabilities
# Valid:            0.0001614336943021044
# Invalid:          0.9998385906219482
#
#
# Sentence:         The scientific data is rendered unusable (e.g., deleted, corrupted, not returned at required time) before it can be fully investigated.
# Probabilities
# Valid:            0.0006709900335408747
# Invalid:          0.9993290901184082
#
#
# Sentence:         The train derails.
# Probabilities
# Valid:            0.001426579081453383
# Invalid:          0.9985734224319458
#
#
# Sentence:         The train hits obstacles that violated the limit.
# Probabilities
# Valid:            2.7356923965271562e-05
# Invalid:          0.9999727010726929
#
#
# Sentence:         The train hits personnel.
# Probabilities
# Valid:            7.778671715641394e-05
# Invalid:          0.9999221563339233
#
#
# Sentence:         The train squeezes at switch.
# Probabilities
# Valid:            6.776375357731013e-06
# Invalid:          0.9999932050704956
#
#
# Sentence:         The vehicle behind crashes the ACC vehicle when the ACC system detects an object in the vehicle path (Backward Collision vehicle to vehicle).
# Probabilities
# Valid:            8.404202526435256e-05
# Invalid:          0.9999159574508667
#
#
# Sentence:         Two aircraft collide.
# Probabilities
# Valid:            3.426149851293303e-05
# Invalid:          0.9999657869338989
#
#
# Sentence:         Two or more vehicles collide.
# Probabilities
# Valid:            0.00011467654258012772
# Invalid:          0.9998853206634521
#
#
# Sentence:         Two or more vehicles collide.
# Probabilities
# Valid:            0.00011467654258012772
# Invalid:          0.9998853206634521
#
#
# Sentence:         Two or more vehicles collide.
# Probabilities
# Valid:            0.00011467654258012772
# Invalid:          0.9998853206634521
#
#
# Sentence:         Two or more Vehicles Collide.
# Probabilities
# Valid:            0.000330273323925212
# Invalid:          0.9996697902679443
#
#
# Sentence:         Two or more vehicles collide.
# Probabilities
# Valid:            0.00011467654258012772
# Invalid:          0.9998853206634521
#
#
# Sentence:         Unable to Complete Mission.
# Probabilities
# Valid:            1.4669652045995463e-05
# Invalid:          0.9999853372573853
#
#
# Sentence:         Unplanned damage or disruption of the satellite (LOV).
# Probabilities
# Valid:            0.9998526573181152
# Invalid:          0.00014737289166077971
#
#
# Sentence:         Vehicle collides with a moving body.
# Probabilities
# Valid:            1.2050237273797393e-05
# Invalid:          0.9999879598617554
#
#
# Sentence:         Vehicle collides with a non-moving body.
# Probabilities
# Valid:            1.8204975276603363e-05
# Invalid:          0.9999817609786987
#
#
# Sentence:         Vehicle collides with non-fixed obstacle.
# Probabilities
# Valid:            1.8393464415566996e-05
# Invalid:          0.9999816417694092
#
#
# Sentence:         Vehicle collides with non-fixed obstacle.
# Probabilities
# Valid:            1.8393464415566996e-05
# Invalid:          0.9999816417694092
#
#
# Sentence:         Vehicle collides with non-fixed obstacle.
# Probabilities
# Valid:            1.8393464415566996e-05
# Invalid:          0.9999816417694092
#
#
# Sentence:         Vehicle Collides with Pedestrian(s).
# Probabilities
# Valid:            1.1822398846561555e-05
# Invalid:          0.9999881982803345
#
#
# Sentence:         Vehicle crashes into terrain.
# Probabilities
# Valid:            8.630840966361575e-06
# Invalid:          0.9999914169311523
#
#
# Sentence:         Vehicle crashes into terrain.
# Probabilities
# Valid:            8.630840966361575e-06
# Invalid:          0.9999914169311523
#
#
# Sentence:         Vehicle crashes into terrain.
# Probabilities
# Valid:            8.630840966361575e-06
# Invalid:          0.9999914169311523
#
#
# Sentence:         Vehicle crashes when Autopilot is active.
# Probabilities
# Valid:            3.232147355447523e-05
# Invalid:          0.9999676942825317
#
#
# Sentence:         Vehicle is damaged (economic loss).
# Probabilities
# Valid:            0.999983549118042
# Invalid:          1.6474859876325354e-05
#
#
# Sentence:         Vehicle Occupant Injury.
# Probabilities
# Valid:            0.9999328851699829
# Invalid:          6.715075141983107e-05
#
#
# Sentence:         Vehicle occupants are injured during operation.
# Probabilities
# Valid:            9.058185969479382e-05
# Invalid:          0.9999094009399414
#
#
# Sentence:         vehicle occupants are injured while ACC is engaged.
# Probabilities
# Valid:            2.2699785404256545e-05
# Invalid:          0.9999773502349854
#
#
# Sentence:         Vehicle occupants are injured while ACC is engaged.
# Probabilities
# Valid:            4.1276431147707626e-05
# Invalid:          0.9999587535858154
#
#
# Sentence:         Vehicle occupants injured without vehicle collision.
# Probabilities
# Valid:            5.861154568265192e-05
# Invalid:          0.999941349029541
#
#
# Sentence:         Vehicle occupants injured without vehicle collision.
# Probabilities
# Valid:            5.861154568265192e-05
# Invalid:          0.999941349029541
#
#
# Sentence:         Vehicle occupants injured without vehicle collision.
# Probabilities
# Valid:            5.861154568265192e-05
# Invalid:          0.999941349029541
#
#
# Sentence:         Workers are killed or injured on the job.
# Probabilities
# Valid:            0.8941235542297363
# Invalid:          0.10587652027606964
#
#
# Step 2 (hazard) execution time: 150.77666047799994
# Sentence count:
# 424
# Time per sentence:
# 0.3556053313160376
# Sentence:         A pair of controlled aircraft violates minimum separation standards.
# Probabilities
# Valid:            0.9999955892562866
# Invalid:          4.37528797192499e-06
#
#
# Sentence:         A person or worker is standing/working under or passing through the excavators’ range cycle.
# Probabilities
# Valid:            0.0005174356629140675
# Invalid:          0.9994825124740601
#
#
# Sentence:         A/C not compliant with airworthiness requirements.
# Probabilities
# Valid:            0.9997952580451965
# Invalid:          0.00020473245240282267
#
#
# Sentence:         Absence of warning when vehicle moves out of lane, resulting in a collision.
# Probabilities
# Valid:            0.00020044799020979553
# Invalid:          0.9997995495796204
#
#
# Sentence:         ACC did not illuminate brake light to warn vehicle in the behind.
# Probabilities
# Valid:            0.9999288320541382
# Invalid:          7.116054621292278e-05
#
#
# Sentence:         ACC did not maintain a safe distance from the object in the front, resultng in collision.
# Probabilities
# Valid:            0.0016304532764479518
# Invalid:          0.9983695149421692
#
#
# Sentence:         ACC does not maintain a safe distance from the object in the front (resulting in a collision).
# Probabilities
# Valid:            0.9997720122337341
# Invalid:          0.0002279409090988338
#
#
# Sentence:         ACC does not reduce throttle and apply the braking force to maintain safe distance as preset by driver when vehicle catches up with a slower preceding vehicle.
# Probabilities
# Valid:            0.00030850214534439147
# Invalid:          0.9996914863586426
#
#
# Sentence:         ACC estimates wrong values of distance and speed of vehicle ahead.
# Probabilities
# Valid:            0.9999803304672241
# Invalid:          1.9696562958415598e-05
#
#
# Sentence:         ACC slows down the vehicle too abruptly (and vehicle is rear-ended).
# Probabilities
# Valid:            0.9999895095825195
# Invalid:          1.0489702617633156e-05
#
#
# Sentence:         ACC slows down the vehicle too abruptly, and vehicle is rear-ended.
# Probabilities
# Valid:            0.9999316930770874
# Invalid:          6.833887891843915e-05
#
#
# Sentence:         ACC violates the safe distance between ACC vehicle and vehicle in front.
# ...
# Invalid:          5.13140439579729e-05
#
#
# Sentence:         The vehicle should keep adequate distance and height against the people and properties on the ground.
# Probabilities
# Valid:            0.9999929666519165
# Invalid:          7.001020094321575e-06
#
#
# Sentence:         There must be no person between train doors and PSDs when the train start.
# Probabilities
# Valid:            0.9999943971633911
# Invalid:          5.5844652706582565e-06
#
#
# Sentence:         There shall never be smoke inside the cabin.
# Probabilities
# Valid:            0.999998927116394
# Invalid:          1.0670778465282638e-06
#
#
# Sentence:         There shall never be uncontrolled fire on board.
# Probabilities
# Valid:            0.9999996423721313
# Invalid:          3.172270055529225e-07
#
#
# Sentence:         Toxic chemicals must be contained within plant equipment.
# Probabilities
# Valid:            0.9999990463256836
# Invalid:          9.533450793242082e-07
#
#
# Sentence:         Toxic chemicals must not be released.
# Probabilities
# Valid:            0.9999946355819702
# Invalid:          5.403918748925207e-06
#
#
# Sentence:         Toxic plant chemicals must not be released into the atmosphere.
# Probabilities
# Valid:            0.9999997615814209
# Invalid:          2.36226085803537e-07
#
#
# Sentence:         Train must not move with doors open.
# Probabilities
# Valid:            0.9999995231628418
# Invalid:          5.24852623584593e-07
#
#
# Sentence:         Train must run within limited speed.
# Probabilities
# Valid:            0.9999994039535522
# Invalid:          6.366203137986304e-07
#
#
# Sentence:         UAS operations shall not induce or contribute to a controlled flight into terrain maneuver.
# Probabilities
# Valid:            0.9999996423721313
# Invalid:          3.5699088130058954e-07
#
#
# Sentence:         UAS operations shall not induce or contribute to loss of aircraft controlled flight.
# Probabilities
# Valid:            0.9999971389770508
# Invalid:          2.8505824047897477e-06
#
#
# Sentence:         UAS operations shall not lead to a loss of minimum separation requirements.
# Probabilities
# Valid:            0.9999994039535522
# Invalid:          5.929151711825398e-07
#
#
# Sentence:         UAS operations shall, when possible, be conducted well away from the boundaries of the airspace.
# Probabilities
# Valid:            0.9999446868896484
# Invalid:          5.5264332331717014e-05
#
#
# Sentence:         UAS operator shall immediately inform the controller if the UAV position becomes unclear.
# Probabilities
# Valid:            0.9999995231628418
# Invalid:          5.304664796312863e-07
#
#
# Sentence:         UAS operator shall immediately inform the controller in the event of a UAV malfunction.
# Probabilities
# Valid:            0.9999972581863403
# Invalid:          2.7040764507546555e-06
#
#
# Sentence:         UAS operator shall immediately notify the losing controller if the UAV is incapable of exiting the old airspace.
# Probabilities
# Valid:            0.9999992847442627
# Invalid:          6.793915758862568e-07
#
#
# Sentence:         UAS operator shall read back airspace clearance to controller.
# Probabilities
# Valid:            0.9999994039535522
# Invalid:          6.41934718714765e-07
#
#
# Sentence:         Unauthorized individuals must not access the port system infrastructure.
# Probabilities
# Valid:            0.9999395608901978
# Invalid:          6.043991379556246e-05
#
#
# Sentence:         Vehicle must brake when vehicle detected slowed or stopped object (at a few X-meters within the preset value of the safety distance) in its path.
# Probabilities
# Valid:            0.9999938011169434
# Invalid:          6.179055162647273e-06
#
#
# Sentence:         Vehicle must illuminate the brake light to warn vehicle in the back.
# Probabilities
# Valid:            0.9999929666519165
# Invalid:          7.017650659690844e-06
#
#
# Sentence:         Vehicle must maintain safe distance from nearby objects.
# Probabilities
# Valid:            0.9999992847442627
# Invalid:          6.567880745933508e-07
#
#
# Sentence:         Vehicle must maintain safe distance from nearby vehicles.
# Probabilities
# Valid:            0.9999979734420776
# Invalid:          2.0017462247778894e-06
#
#
# Sentence:         Vehicle must maintain safe distance from terrain and other obstacles.
# Probabilities
# Valid:            0.9999996423721313
# Invalid:          3.9576795529683295e-07
#
#
# Sentence:         Vehicle must not expose occupants to harmful effects and/or health hazards.
# Probabilities
# Valid:            0.9999998807907104
# Invalid:          1.574517938252029e-07
#
#
# Sentence:         Vehicle must not leave the roadway.
# Probabilities
# Valid:            0.9999982118606567
# Invalid:          1.7664881397649879e-06
#
#
# Sentence:         Vehicle must not violate minimum safety distance to objects, road users, vehicles, etc.
# Probabilities
# Valid:            0.999998927116394
# Invalid:          1.1283364074188285e-06
#
#
# Sentence:         Vehicle stages and interfaces must be designed so that, in the event of an unintended ignition, they do not result in the vehicle explosion.
# Probabilities
# Valid:            0.9999736547470093
# Invalid:          2.63428646576358e-05
#
#
# Sentence:         Vehicles must always maintain safe distances from each other.
# Probabilities
# Valid:            0.9999994039535522
# Invalid:          6.518155828416639e-07
#
#
# Sentence:         Vehicles must always maintain safe distances from each other.
# Probabilities
# Valid:            0.9999994039535522
# Invalid:          6.518155828416639e-07
#
#
# Sentence:         Verify if the channels are actuated.
# Probabilities
# Valid:            2.8226438075762417e-07
# Invalid:          0.9999997615814209
#
#
# Sentence:         Verify the conformity of the products to respective certified design.
# Probabilities
# Valid:            1.9741250412153022e-07
# Invalid:          0.9999997615814209
#
#
# Sentence:         When a track section is occupied by a train, the TCC transmits control parameters representing track occupancy to other trains and issues warning signals (red) to the signal device in front of this section.
# Probabilities
# Valid:            0.0002791518345475197
# Invalid:          0.9997208714485168
#
#
# Sentence:         When performing an abort, the flight crew must follow regional contingency procedures.
# Probabilities
# Valid:            0.9999995231628418
# Invalid:          4.4779667973671167e-07
#
#
# Sentence:         When spin zones are in use, the controller shall not consider the area clear or safe.
# Probabilities
# Valid:            0.9999879598617554
# Invalid:          1.2092833458154928e-05
#
#
# Sentence:         When the aircraft is on the ground during takeoff or landing, and fuel flow is stuck high, when the pilot moves Throttle (TLA) to the idle, then automatically command an engine shutdown.
# Probabilities
# Valid:            3.35125696437899e-05
# Invalid:          0.9999665021896362
#
#
# Sentence:         When the bursting of a tire at high speed is suspected and the pilot decides to continue, the landing gear must not be retracted.
# Probabilities
# Valid:            0.9999904632568359
# Invalid:          9.556996701576281e-06
#
#
# Sentence:         When the Train is stopped and not in a station and no emergency exists the Controller shall not open the door.
# Probabilities
# Valid:            0.9999357461929321
# Invalid:          6.429513450711966e-05
#
#
# Sentence:         When two aircraft are on a collision course, TCAS must always provide an RA to avoid the collision.
# Probabilities
# Valid:            0.9999833106994629
# Invalid:          1.6743651940487325e-05
#
#
# Sentence:         Wing safety shall ensure that the UAV software is updated with new airspace boundaries when they are changed.
# Probabilities
# Valid:            0.9999996423721313
# Invalid:          3.230444463042659e-07
#
#
# Sentence:         Workers shall not be exposed to hazardous energy.
# Probabilities
# Valid:            0.9999998807907104
# Invalid:          1.2880963140560198e-07
#
#
# Sentence:         Yawing at brakes release must be counteracted quickly.
# Probabilities
# Valid:            0.9999990463256836
# Invalid:          9.821902722251252e-07
#
#
# Sentence:         Must keep the system safe.
# Probabilities
# Valid:            3.665610620373627e-06
# Invalid:          0.9999963045120239
#
#
# Sentence:         Security must be active.
# Probabilities
# Valid:            3.233182951589697e-06
# Invalid:          0.9999967813491821
#
#
# Sentence:         Must have minimum mission critical safety systems functional for landing.
# Probabilities
# Valid:            3.2754653602751205e-06
# Invalid:          0.9999967813491821
#
#
# Sentence:         Aircraft must fly.
# Probabilities
# Valid:            1.7092793314077426e-06
# Invalid:          0.9999983310699463
#
#
# Sentence:         Must have all systems functional when driving.
# Probabilities
# Valid:            1.9023487141112128e-07
# Invalid:          0.9999997615814209
#
#
# Sentence:         Must comply to all regulations.
# Probabilities
# Valid:            8.715776402823394e-07
# Invalid:          0.9999991655349731
#
#
# Sentence:         Must calculate all processes in time.
# Probabilities
# Valid:            3.985594076993948e-08
# Invalid:          1.0
#
#
# Sentence:         No relevant function shall be lost during flight.
# Probabilities
# Valid:            1.7257619902011356e-06
# Invalid:          0.9999983310699463
#
#
# Sentence:         Must fly through a safe area.
# Probabilities
# Valid:            0.0009446987533010542
# Invalid:          0.9990553259849548
#
#
# Sentence:         System must be functional.
# Probabilities
# Valid:            2.35234961110109e-06
# Invalid:          0.999997615814209
#
#
# Sentence:         Passanger must be alive.
# Probabilities
# Valid:            2.2042500859242864e-05
# Invalid:          0.9999779462814331
#
#
# Sentence:         Verifying the system conditions is a must.
# Probabilities
# Valid:            2.6999714464182034e-06
# Invalid:          0.9999972581863403
#
#
# Sentence:         An inspection must be done in the system.
# Probabilities
# Valid:            2.539460638217861e-06
# Invalid:          0.9999974966049194
#
#
# Sentence:         Must have minimum number of passangers in flight.
# Probabilities
# Valid:            0.00015913783863652498
# Invalid:          0.9998408555984497
#
#
# Sentence:         Must have all systems functional for flight.
# Probabilities
# Valid:            3.665638530492288e-07
# Invalid:          0.9999996423721313
#
#
# Sentence:         No component shall be active when vehicle is turned off.
# Probabilities
# Valid:            0.00021764649136457592
# Invalid:          0.999782383441925
#
#
# Sentence:         Must have cabin pressurization system active.
# Probabilities
# Valid:            1.2970048146598856e-07
# Invalid:          0.9999998807907104
#
#
# Sentence:         Should allow multiple users in software.
# Probabilities
# Valid:            0.00404642429202795
# Invalid:          0.9959535598754883
#
#
# Sentence:         Must have all necessary weather information for flight.
# Probabilities
# Valid:            1.0749753300842713e-06
# Invalid:          0.999998927116394
#
#
# Sentence:         Must detect all system threats.
# Probabilities
# Valid:            8.785785894360743e-07
# Invalid:          0.9999991655349731
#
#
# Sentence:         Should an accident occur, the airbags are activated.
# Probabilities
# Valid:            9.884856262942776e-05
# Invalid:          0.9999011754989624
#
#
# Sentence:         Must maintain integrity of mission critical components.
# Probabilities
# Valid:            2.4301828034367645e-06
# Invalid:          0.999997615814209
#
#
# Sentence:         Must be able to operate the system.
# Probabilities
# Valid:            8.449691222267575e-07
# Invalid:          0.9999991655349731
#
#
# Sentence:         Drune must be dispatched.
# Probabilities
# Valid:            5.5135028560471255e-06
# Invalid:          0.9999945163726807
#
#
# Sentence:         Avoid hazardous state.
# Probabilities
# Valid:            2.2627427043175885e-08
# Invalid:          1.0
#
#
# Sentence:         Comply to all regulations.
# Probabilities
# Valid:            3.214957189356937e-08
# Invalid:          1.0
#
#
# Sentence:         Aircraft flies safely.
# Probabilities
# Valid:            3.642266790393478e-07
# Invalid:          0.9999996423721313
#
#
# Sentence:         Avoid machine overload.
# Probabilities
# Valid:            5.889458254415558e-09
# Invalid:          1.0
#
#
# Sentence:         Verify if all components are working.
# Probabilities
# Valid:            1.1577741432233779e-08
# Invalid:          1.0
#
#
# Sentence:         When encountering a dangerous situation, vehicle performs emergency maneuver.
# Probabilities
# Valid:            2.6205261747236364e-06
# Invalid:          0.9999973773956299
#
#
# Sentence:         Avoiding the contact of toxic substances.
# Probabilities
# Valid:            1.6438464172097156e-06
# Invalid:          0.9999983310699463
#
#
# Sentence:         Contact ATC when in emergency.
# Probabilities
# Valid:            2.2129895569378277e-06
# Invalid:          0.9999977350234985
#
#
# Sentence:         Aircraft keeps a safe altitude.
# Probabilities
# Valid:            0.00013398223381955177
# Invalid:          0.9998660087585449
#
#
# Sentence:         Maintenance of the highway only when highway is blocked.
# Probabilities
# Valid:            3.469329215022299e-07
# Invalid:          0.9999996423721313
#
#
# Sentence:         Verify if the door is properly closed.
# Probabilities
# Valid:            6.695984211546602e-08
# Invalid:          0.9999998807907104
#
#
# Sentence:         During a trip to the destination, if there are people inside vehicle, remind to fasten the seatbelt.
# Probabilities
# Valid:            5.811415394418873e-05
# Invalid:          0.9999418258666992
#
#
# Sentence:         When the ground is clear, the pilot contacts ATC for permission, and performs landing.
# Probabilities
# Valid:            0.3715061843395233
# Invalid:          0.6284937858581543
#
#
# Sentence:         Extension of landing gear only approaching ground.
# Probabilities
# Valid:            6.534892804666015e-07
# Invalid:          0.9999994039535522
#
#
# Sentence:         User is allowed to override commands in case of emergency.
# Probabilities
# Valid:            1.905624003484263e-06
# Invalid:          0.9999980926513672
#
#
# Sentence:         Avoid sudden braking when moving.
# Probabilities
# Valid:            1.002526328619524e-08
# Invalid:          1.0
#
#
# Sentence:         Ensure the vehicle has enough fuel before departing.
# Probabilities
# Valid:            4.301966782804811e-06
# Invalid:          0.9999957084655762
#
#
# Sentence:         Always make sure to check if equipment is working as intended.
# Probabilities
# Valid:            9.733902697917074e-05
# Invalid:          0.999902606010437
#
#
# Sentence:         Verify if the landing gear is retracted after takeoff.
# Probabilities
# Valid:            1.584020719747059e-05
# Invalid:          0.9999841451644897
#
#
# Sentence:         Verify the equipment state before performing maintenance.
# Probabilities
# Valid:            4.028093059105231e-08
# Invalid:          1.0
#
#
# Sentence:         Changing lanes only when lane is empty.
# Probabilities
# Valid:            8.733707659303036e-07
# Invalid:          0.9999991655349731
#
#
# Sentence:         Avoid flight in altitude below permitted limit.
# Probabilities
# Valid:            2.0823314628160006e-07
# Invalid:          0.9999997615814209
#
#
# Sentence:         System is capable of defending threats.
# Probabilities
# Valid:            6.331802978820633e-06
# Invalid:          0.9999936819076538
#
#
# Sentence:         Verify if the runway is empty.
# Probabilities
# Valid:            3.0686388985401436e-09
# Invalid:          1.0
#
#
# Sentence:         Sudden braking olny in emergency situations.
# Probabilities
# Valid:            2.2675209265798912e-08
# Invalid:          1.0
#
#
# Sentence:         Vehicle overtaking only when road is empty.
# Probabilities
# Valid:            3.221304325506935e-07
# Invalid:          0.9999996423721313

# %%
def organize_step3_predictions(results, list_sentences):
  predictions = np.argmax(results.logits.cpu(), axis=-1)
  probabilities = F.softmax(results.logits.cpu(), dim=-1)

  list_dict = []
  dict_faults = {}
  for prediction, sentence, probability in zip(predictions, list_sentences, probabilities):
    dict_faults = {'sentence': sentence, 'faults': step3_labels[prediction], 'probabilities': probability}
    list_dict.append(dict_faults)

  return list_dict

# %%
# Step 3: Fault type detection

dict_faults_loss = {}
dict_faults_hazard = {}
dict_faults_constraint = {}

# the inputs of this step are the lists generated in the step 2 ('list_invalid_loss', 'list_invalid_hazard', and 'list_invalid_constraint')

if list_invalid_loss:
  path_step3_loss = path+'beds_step3_loss'
  path_step3_loss = path_step3_loss+'_'+model_preset
  model_step3_loss = AutoModelForSequenceClassification.from_pretrained(path_step3_loss, num_labels=4)

  start = time.perf_counter()
  with torch.no_grad():
    encodings = tokenizer(list_invalid_loss, truncation=True, padding='max_length', max_length=512,return_tensors="pt")
    results = model_step3_loss(encodings['input_ids'], encodings['attention_mask'])
  end = time.perf_counter()
  print('Step 3 (loss) execution time:', end-start)
  print('Sentence count:')
  print(len(list_invalid_loss))
  print('Time per sentence:')
  print((end-start)/len(list_invalid_loss))
  list_dict_faults_loss = organize_step3_predictions(results, list_invalid_loss)


if list_invalid_hazard:
  path_step3_hazard = path+'beds_step3_hazard'
  path_step3_hazard = path_step3_hazard+'_'+model_preset
  model_step3_hazard = AutoModelForSequenceClassification.from_pretrained(path_step3_hazard, num_labels=4)

  start = time.perf_counter()
  with torch.no_grad():
    encodings = tokenizer(list_invalid_hazard, truncation=True, padding='max_length', max_length=512,return_tensors="pt")
    results = model_step3_hazard(encodings['input_ids'], encodings['attention_mask'])
  end = time.perf_counter()
  print('Step 3 (hazard) execution time:', end-start)
  print('Sentence count:')
  print(len(list_invalid_hazard))
  print('Time per sentence:')
  print((end-start)/len(list_invalid_hazard))
  list_dict_faults_hazard = organize_step3_predictions(results, list_invalid_hazard)


if list_invalid_constraint:
  path_step3_constraint = path+'beds_step3_constraint'
  path_step3_constraint = path_step3_constraint+'_'+model_preset
  model_step3_constraint = AutoModelForSequenceClassification.from_pretrained(path_step3_constraint, num_labels=2)

  start = time.perf_counter()
  with torch.no_grad():
    encodings = tokenizer(list_invalid_constraint, truncation=True, padding='max_length', max_length=512,return_tensors="pt")
    results = model_step3_constraint(encodings['input_ids'], encodings['attention_mask'])
  end = time.perf_counter()
  print('Step 3 (constraint) execution time:', end-start)
  print('Sentence count:')
  print(len(list_invalid_constraint))
  print('Time per sentence:')
  print((end-start)/len(list_invalid_constraint))
  list_dict_faults_constraint = organize_step3_predictions(results, list_invalid_constraint)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/598M [00:00<?, ?B/s]
# Step 3 (loss) execution time: 35.342216219999955
# Sentence count:
# 97
# Time per sentence:
# 0.364352744536082
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/598M [00:00<?, ?B/s]
# Step 3 (hazard) execution time: 47.05074782700012
# Sentence count:
# 131
# Time per sentence:
# 0.35916601394656583
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/598M [00:00<?, ?B/s]
# Step 3 (constraint) execution time: 24.380317520000062
# Sentence count:
# 68
# Time per sentence:
# 0.3585340811764715

# %%
def print_dict_faults(list_dict_faults):
  for dict_faults in list_dict_faults:
    print('Sentence:            ', dict_faults['sentence'])
    print('Fault type detected: ', dict_faults['faults'])
    print('Probabilities')

    for i in range(len(dict_faults['probabilities'])):
      probability = dict_faults['probabilities'][i]
      faults = step3_labels[i]
      print(faults, ': ', probability.item())
    print('\n')

if verbose == 'True':
  print('########### LOSS')
  print_dict_faults(list_dict_faults_loss)
  print('########### HAZARD')
  print_dict_faults(list_dict_faults_hazard)
  print('########### CONSTRAINT')
  print_dict_faults(list_dict_faults_constraint)

# %%
def format_reference(df):
  references = []
  for sentence in df:
    references.append([sentence,sentence])
  return references

def check_similarity(list_invalid, list_valid, model):
  list_similar = []
  embeddings = model.encode(list_valid)
  for sentence in list_invalid:
    if verbose == 'True':
      print(sentence)
      print("suggestions:")
    sentence = model.encode(sentence)
    similarity = model.similarity(sentence, embeddings)
    sim_pair = []

    for sim, valid in zip(similarity[0].tolist(), list_valid):
      sim_pair.append([sim, valid[0]])

    sim_pair.sort(key=lambda x: x[0])
    sim_pair.reverse()
    list_aux = []
    for sim, valid in sim_pair[:5]:
      if verbose == 'True':
        print("{:.4f} \t\t {}".format(sim, valid))
      list_aux.append([sim, valid])
    list_similar.append([sentence, list_aux])
    if verbose == 'True':
      print("\n")
  return list_similar

# %%
# Step 4: Sentence suggestion

# the inputs of this step are the lists generated in the step 2 ('list_invalid_loss', 'list_invalid_hazard', and 'list_invalid_constraint')

model_step4 = SentenceTransformer(path+'beds_step4')

reference_path = "reference/"#/content/drive/MyDrive/Colab Notebooks/reference

list_similar_loss = []
list_similar_hazard = []
list_similar_constraint = []

if list_invalid_loss:
  valid_loss_df = pd.read_csv(reference_path+'valid_loss_reference.csv').squeeze().tolist()
  reference_valid_loss = format_reference(valid_loss_df)
  print("LOSS #####################################")
  list_similar_loss = check_similarity(list_invalid_loss, reference_valid_loss, model_step4)
  print("\n")


if list_invalid_hazard:
  valid_hazard_df = pd.read_csv(reference_path+'valid_hazard_reference.csv').squeeze().tolist()
  reference_valid_hazard = format_reference(valid_hazard_df)
  print("HAZARD #####################################")
  list_similar_hazard = check_similarity(list_invalid_hazard, reference_valid_hazard, model_step4)
  print("\n")


if list_invalid_constraint:
  valid_constraint_df = pd.read_csv(reference_path+'valid_constraint_reference.csv').squeeze().tolist()
  examples_valid_constraint = format_reference(valid_constraint_df)
  print("CONSTRAINT #####################################")
  list_similar_constraint = check_similarity(list_invalid_constraint, examples_valid_constraint, model_step4)
# Out:
# LOSS #####################################
#
#
# HAZARD #####################################
#
#
# CONSTRAINT #####################################

# %%
def print_invalid(list_dict_faults, list_similar):

  for faults, similar in zip(list_dict_faults, list_similar):
    print('Sentence:            ', faults['sentence'])
    print('Fault type detected: ', faults['faults'])
    print('Probabilities:')
    for probability, name in zip(faults['probabilities'], step3_labels):
      print("{:.4f} \t\t {}".format(probability.item(), name))
    print('Similar Valid Sentences:')
    for sim, valid in similar[1]:
      print("{:.4f} \t\t {}".format(sim, valid))
    print('\n')

# %%
# print Loss results

print('########### LOSS')
print('Vaid Sentences:')
print(list_valid_loss)
print('\n')
print('Invalid Sentences:')
print_invalid(list_dict_faults_loss, list_similar_loss)
# Out:
# ########### LOSS
# Vaid Sentences:
# ['Aircraft (including both manned and unmanned systems) in the air are damaged or destroyed.', 'AV gets damaged.', 'Contaminated Enviroment.', 'Damage and/or interruption of operations of other systems (Supporting infrastructure, other satellites, all other equipment).', 'Damage of property (internal or external company).', 'Damage or loss of equipment.', 'Damage or loss of equipment.', 'Damage or loss of equipment.', 'Damage to airport infra-structure and/or proximities.', 'Damage to equipment or infrastructure.', 'damage to equipment.', 'Damage to equipment.', 'Damage to equipment.', 'Damage to or loss of aircraft.', 'Damage to patient or staff satisfaction, or hospital reputation.', 'Damage to SSRMS.', 'Damage to the aircraft or objects outside the aircraft.', 'Damage to the aircraft.', 'Damage to the Laboratorial Facility or the laboratory equipment.', 'Damage to the ship or objects outside the ship.', 'Damage to the vehicle or objects outside the vehicle.', 'Damage to the vehicle.', 'Damage to valuable SGC components.', 'Death or Human injury.', 'Death or injury to persons.', 'Death or injury.', 'Death or serious injury to rider or operator.', 'Disruption on processing or transport.', 'Economic loss.', 'Enviromental losses.', 'Environmental Damage.', 'Environmental loss (release).', 'Environmental loss.', 'Environmental loss/pollution.', 'Environmental losses.', 'Environmental losses.', 'Environmental: oil and fuel pollution, debris in nature.', 'Equipment damage (economic loss).', 'Equipment Damage.', 'Facility or equipment damage.', 'Fatalities or injury to persons.', 'Financial loss or loss of hospital reputation.', 'Financial loss or loss of hospital reputation.', 'Financial loss.', 'Financial losses.', 'Human injury or loss of life.', 'Human life, injury, motion sickness, fright.', 'Human serious injury or loss of life.', 'Humans and/or human assets off of the earth are killed/damaged.', 'Humans and/or human assets on earth are killed/damaged.', 'Humans injured or killed (On earth, in air, in space).', 'Indirect monetary losses.', 'Injury of passenger and crew.', 'injury or loss of life.', 'Injury or loss of life.', 'Injury or property damage occurring within the vehicle, without a collision.', 'Loss of A/C;', 'Loss of Acme Intellectual Property.', 'Loss of aircraft.', 'Loss of classified information.', 'Loss of client satisfaction.', 'Loss of company reputation.', 'Loss of confidence in aircraft systems.', 'Loss of confidence in the safety of drinking water supplied to the public.', 'Loss of consumer (rider) PII.', 'Loss of credibility in the air transportation industry.', 'Loss of Critical Protected Data.', 'Loss of customer preference/ brand loyalty.', 'Loss of customer satisfaction with automated parking, without injury or property damage.', 'Loss of customer satisfaction.', 'Loss of customer satisfaction.', 'Loss of customer satisfaction.', 'Loss of customers.', 'Loss of data quality.', 'Loss of driver comfort.', 'Loss of economic stability (e.g. closure of business / increases in unemployment, decrease in purchasing power).', 'Loss of electrical power generation.', 'Loss of environmental integrity.', 'Loss of equipment.', 'Loss of finances.', 'Loss of flight test productivity.', 'Loss of functioning democratic society (e.g. loss of freedom, human right .etc.).', 'Loss of Generation.', 'Loss of generation.', 'Loss of grid equipment (capacitors, lines, et.c).', 'Loss of ground support operation.', 'Loss of HTV mission.', 'Loss of human life - human injury.', 'Loss of human life / damage to health and wellbeing (e.g. long term concerns with COVID).', 'Loss of human life or human injury of laboratory-related personnel.', 'Loss of human life or human injury of personnel external to the laboratory facilities.', 'Loss of human life or injured people.', 'Loss of human life or injury.', 'Loss of Human Life, Human Injury, Properties Damage or Environmental Losses.', 'Loss of human life/injury.', 'Loss of human live or se ...
#
#
# Invalid Sentences:
# Sentence:             A non‐patient is injured or killed by radiation.
# Fault type detected:  condition
# Probabilities:
# 0.0000 		 rewrite
# 0.0000 		 not
# 1.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.5170 		 Patient suffers physical, non-radiological injury.
# 0.2832 		 Mission Non-Compliance.
# 0.2776 		 Patient’s pain is not relieved.
# 0.2402 		 Loss to non-patient quality of life (esp. personnel).
# 0.2252 		 Patient is killed or seriously injured.
#
#
# Sentence:             A nonpatient is injured or killed in the process of MRI simulation.
# Fault type detected:  condition
# Probabilities:
# 0.0000 		 rewrite
# 0.0001 		 not
# 0.9999 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.4072 		 Patient suffers physical, non-radiological injury.
# 0.3573 		 Loss to non-patient quality of life (esp. personnel).
# 0.3185 		 Mission Non-Compliance.
# 0.2063 		 Disruption on processing or transport.
# 0.1938 		 Loss of mission (or performance degradation).
#
#
# Sentence:             Aircraft crashes into terrain / ocean.
# Fault type detected:  accident
# Probabilities:
# 0.0070 		 rewrite
# 0.0025 		 not
# 0.0002 		 condition
# 0.9903 		 accident
# Similar Valid Sentences:
# 0.2101 		 Environmental: oil and fuel pollution, debris in nature.
# 0.1968 		 Loss or damage to aircraft.
# 0.1941 		 Loss of or damage to aircraft.
# 0.1878 		 Loss of or damage to the aircraft or  equipment on the aircraft.
# 0.1861 		 Damage to or loss of aircraft.
#
#
# Sentence:             Aircraft crashes.
# Fault type detected:  accident
# Probabilities:
# 0.0004 		 rewrite
# 0.0014 		 not
# 0.0001 		 condition
# 0.9982 		 accident
# Similar Valid Sentences:
# 0.5131 		 Loss of aircraft.
# 0.4581 		 Loss or damage to aircraft.
# 0.4579 		 Damage to or loss of aircraft.
# 0.4344 		 Loss of or damage to aircraft.
# 0.4297 		 Damage to the aircraft.
#
#
# Sentence:             An incident during this mission directly causes another mission to fail to collect, return, and/or use the scientific data corresponding to its mission goals.
# Fault type detected:  not
# Probabilities:
# 0.0005 		 rewrite
# 0.9987 		 not
# 0.0006 		 condition
# 0.0002 		 accident
# Similar Valid Sentences:
# 0.4358 		 Scientific mission is not performed (mission loss).
# 0.3930 		 Mission loss or degradation.
# 0.3071 		 Loss of mission (or performance degradation).
# 0.3011 		 Loss of Mission.
# 0.3011 		 Loss of mission.
#
#
# Sentence:             Asset damage (ship, battery trailer).
# Fault type detected:  rewrite
# Probabilities:
# 0.9990 		 rewrite
# 0.0003 		 not
# 0.0001 		 condition
# 0.0007 		 accident
# Similar Valid Sentences:
# 0.3372 		 Equipment Damage.
# 0.3316 		 Loss of or damage to service vehicle/equipment.
# 0.3127 		 Facility or equipment damage.
# 0.2949 		 Damage to the ship or objects outside the ship.
# 0.2940 		 Equipment damage (economic loss).
#
#
# Sentence:             AV collision with vulnerable road user (VRU).
# Fault type detected:  accident
# Probabilities:
# 0.0004 		 rewrite
# 0.0002 		 not
# 0.0001 		 condition
# 0.9993 		 accident
# Similar Valid Sentences:
# 0.3391 		 AV gets damaged.
# 0.2796 		 Loss of or damage to UAV aircraft.
# 0.1978 		 Vehicle Occupant Injury.
# 0.1914 		 Loss of human life or injured people.
# 0.1906 		 Loss of human life/injury.
#
#
# Sentence:             Collateral Damage.
# Fault type detected:  not
# Probabilities:
# 0.0002 		 rewrite
# 0.9996 		 not
# 0.0000 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.3622 		 Equipment Damage.
# 0.3605 		 Environmental Damage.
# 0.2896 		 Indirect monetary losses.
# 0.2844 		 Facility or equipment damage.
# 0.2560 		 Damage to SSRMS.
#
#
# Sentence:             Collision with ISS.
# Fault type detected:  accident
# Probabilities:
# 0.0001 		 rewrite
# 0.0005 		 not
# 0.0001 		 condition
# 0.9994 		 accident
# Similar Valid Sentences:
# 0.1371 		 Humans injured or killed (On earth, in air, in space).
# 0.1171 		 Mission Non-Compliance.
# 0.1163 		 Loss of life, injury or health compromise.
# 0.0991 		 Loss of reputation (OEM and/or supplier).
# 0.0986 		 Damage and/or interruption of operations of other systems (Supporting infrastructure, other satellites, all other equipment).
#
#
# Sentence:             Collisions resulting in loss of life, damage or severe disturbance of daily operation.
# Fault type detected:  rewrite
# Probabilities:
# 0.9988 		 rewrite
# 0.0006 		 not
# 0.0004 		 condition
# 0.0002 		 accident
# Similar Valid Sentences:
# 0.5164 		 Loss of life/serious injury.
# 0.4357 		 Human serious injury or loss of life.
# 0.4277 		 Injury or loss of life.
# 0.4277 		 injury or loss of life.
# 0.4159 		 Loss of life or injury.
#
#
# Sentence:             Company reputation.
# Fault type detected:  rewrite
# Probabilities:
# 0.9993 		 rewrite
# 0.0006 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.8694 		 Loss of company reputation.
# 0.4720 		 Loss of Reputation.
# 0.4720 		 Loss of reputation.
# 0.4304 		 Stain to reputation.
# 0.3337 		 Damage to patient or staff satisfaction, or hospital reputation.
#
#
# Sentence:             Death or injury of patient or non-patient not due to radiation.
# Fault type detected:  condition
# Probabilities:
# 0.0003 		 rewrite
# 0.0000 		 not
# 0.9996 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.5168 		 Patient suffers physical, non-radiological injury.
# 0.3980 		 Loss to non-patient quality of life (esp. personnel).
# 0.3399 		 Patient’s pain is not relieved.
# 0.3356 		 Patient injury or death.
# 0.2821 		 Mission Non-Compliance.
#
#
# Sentence:             Death, illness, or injury due to exposure to toxic chemicals.
# Fault type detected:  condition
# Probabilities:
# 0.0014 		 rewrite
# 0.0002 		 not
# 0.9984 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.4769 		 People exposed to chemicals.
# 0.3781 		 Loss or Damage to components / products.
# 0.3490 		 Environmental loss/pollution.
# 0.3381 		 Death or injury.
# 0.3236 		 Loss or damage to the vehicle.
#
#
# Sentence:             Death, injury, or property damage resulting from a collision with a person, vehicle, object, or terrain.
# Fault type detected:  rewrite
# Probabilities:
# 0.9978 		 rewrite
# 0.0001 		 not
# 0.0016 		 condition
# 0.0005 		 accident
# Similar Valid Sentences:
# 0.4020 		 Death or injury to persons.
# 0.3787 		 Fatalities or injury to persons.
# 0.3565 		 Death or injury.
# 0.3423 		 Injury or property damage occurring within the vehicle, without a collision.
# 0.3366 		 Damage to the vehicle or objects outside the vehicle.
#
#
# Sentence:             Doors close on passenger in doorway.
# Fault type detected:  accident
# Probabilities:
# 0.0002 		 rewrite
# 0.0009 		 not
# 0.0001 		 condition
# 0.9988 		 accident
# Similar Valid Sentences:
# 0.2988 		 Injury of passenger and crew.
# 0.2563 		 Humans injured or killed (On earth, in air, in space).
# 0.2145 		 Disruption on processing or transport.
# 0.1706 		 Loss of driver comfort.
# 0.1644 		 Injury or property damage occurring within the vehicle, without a collision.
#
#
# Sentence:             During a rejected takeoff the aircraft departs runway.
# Fault type detected:  not
# Probabilities:
# 0.0006 		 rewrite
# 0.9983 		 not
# 0.0001 		 condition
# 0.0011 		 accident
# Similar Valid Sentences:
# 0.2087 		 Damage to the aircraft or objects outside the aircraft.
# 0.1688 		 Loss of aircraft.
# 0.1526 		 Environmental loss (release).
# 0.1320 		 Damage to the aircraft.
# 0.1232 		 Damage to airport infra-structure and/or proximities.
#
#
# Sentence:             Environment contaminated.
# Fault type detected:  not
# Probabilities:
# 0.0000 		 rewrite
# 0.9999 		 not
# 0.0001 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.6363 		 Environmental Damage.
# 0.5408 		 Environmental loss.
# 0.5210 		 Loss of environmental integrity.
# 0.5115 		 Environmental loss/pollution.
# 0.5001 		 Environmental losses.
#
#
# Sentence:             Erroneous arrival of product.
# Fault type detected:  not
# Probabilities:
# 0.0001 		 rewrite
# 0.9999 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.5453 		 Loss or damage of product.
# 0.5029 		 Product loss.
# 0.4349 		 Loss of product certification.
# 0.3372 		 Loss of production.
# 0.3258 		 Loss or damage of production equipment.
#
#
# Sentence:             Erroneous payment to supplier.
# Fault type detected:  not
# Probabilities:
# 0.0000 		 rewrite
# 0.9999 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2981 		 Loss of reputation (OEM and/or supplier).
# 0.2926 		 Payment loss.
# 0.2826 		 Damage to equipment.
# 0.2826 		 damage to equipment.
# 0.2805 		 Equipment damage (economic loss).
#
#
# Sentence:             Fatalities.
# Fault type detected:  rewrite
# Probabilities:
# 0.9993 		 rewrite
# 0.0005 		 not
# 0.0001 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.4669 		 Fatalities or injury to persons.
# 0.4532 		 Death or injury.
# 0.4195 		 One or more fatalities or significant injuries.
# 0.3082 		 Death or injury to persons.
# 0.3059 		 Patient injury or death.
#
#
# Sentence:             Inability to complete the mission.
# Fault type detected:  rewrite
# Probabilities:
# 0.9997 		 rewrite
# 0.0002 		 not
# 0.0000 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.4408 		 Loss of Mission.
# 0.4408 		 Loss of mission.
# 0.3501 		 Mission loss or degradation.
# 0.3262 		 Mission loss (Unable to perform mission to design standards) (LOM).
# 0.3135 		 Loss of mission (transportation).
#
#
# Sentence:             Ineffective treatment.
# Fault type detected:  not
# Probabilities:
# 0.0004 		 rewrite
# 0.9995 		 not
# 0.0001 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.1658 		 Equipment Damage.
# 0.1569 		 Environmental Damage.
# 0.1548 		 Loss of Intellectual Property.
# 0.1507 		 Indirect monetary losses.
# 0.1393 		 Facility or equipment damage.
#
#
# Sentence:             Injury or Death.
# Fault type detected:  rewrite
# Probabilities:
# 0.9997 		 rewrite
# 0.0000 		 not
# 0.0002 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.8687 		 Death or injury.
# 0.6742 		 Patient injury or death.
# 0.5370 		 Death or Human injury.
# 0.3932 		 Injury or loss of life.
# 0.3932 		 injury or loss of life.
#
#
# Sentence:             Injury, loss of life, damage of aircraft or property.
# Fault type detected:  rewrite
# Probabilities:
# 0.9997 		 rewrite
# 0.0001 		 not
# 0.0002 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.6472 		 injury or loss of life.
# 0.6472 		 Injury or loss of life.
# 0.6426 		 Loss of life or injury.
# 0.6292 		 Loss of life and injury.
# 0.6287 		 Loss of life/injury.
#
#
# Sentence:             Level 1 SMS audit findings for non/compliance.
# Fault type detected:  not
# Probabilities:
# 0.0025 		 rewrite
# 0.9932 		 not
# 0.0036 		 condition
# 0.0006 		 accident
# Similar Valid Sentences:
# 0.4638 		 Mission Non-Compliance.
# 0.2517 		 Loss to non-patient quality of life (esp. personnel).
# 0.1922 		 Mission loss (Unable to perform mission to design standards) (LOM).
# 0.1785 		 Loss of customer satisfaction.
# 0.1696 		 Loss of client satisfaction.
#
#
# Sentence:             Loss due to rescheduling.
# Fault type detected:  condition
# Probabilities:
# 0.0003 		 rewrite
# 0.0002 		 not
# 0.9994 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.1982 		 Damage to SSRMS.
# 0.1570 		 Indirect monetary losses.
# 0.1539 		 Damage to equipment.
# 0.1539 		 damage to equipment.
# 0.1493 		 Stain to reputation.
#
#
# Sentence:             Loss of control in the air.
# Fault type detected:  not
# Probabilities:
# 0.0001 		 rewrite
# 0.9997 		 not
# 0.0001 		 condition
# 0.0002 		 accident
# Similar Valid Sentences:
# 0.3185 		 Loss of confidence in aircraft systems.
# 0.2703 		 Loss of credibility in the air transportation industry.
# 0.2623 		 Humans injured or killed (On earth, in air, in space).
# 0.2172 		 Loss of aircraft.
# 0.2102 		 Loss of customer satisfaction.
#
#
# Sentence:             Loss of control on ground.
# Fault type detected:  not
# Probabilities:
# 0.0006 		 rewrite
# 0.9964 		 not
# 0.0004 		 condition
# 0.0026 		 accident
# Similar Valid Sentences:
# 0.4433 		 Loss of ground support operation.
# 0.3136 		 Structures on the ground are damaged or destroyed.
# 0.2627 		 Personnel on the ground are injured or killed.
# 0.2052 		 Loss of product certification.
# 0.1973 		 Loss of customer satisfaction.
#
#
# Sentence:             Loss of integrity of communication.
# Fault type detected:  not
# Probabilities:
# 0.0000 		 rewrite
# 1.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.4880 		 Loss of Intellectual Property.
# 0.4217 		 Loss of environmental integrity.
# 0.4161 		 Loss or disclosure of sensitive information.
# 0.3916 		 Loss of classified information.
# 0.3767 		 Loss of transportation.
#
#
# Sentence:             Loss of ship's structural integrity/watertightness.
# Fault type detected:  not
# Probabilities:
# 0.0448 		 rewrite
# 0.9385 		 not
# 0.0036 		 condition
# 0.0130 		 accident
# Similar Valid Sentences:
# 0.3494 		 Loss of confidence in the safety of drinking water supplied to the public.
# 0.2848 		 Loss of environmental integrity.
# 0.2678 		 Loss of data quality.
# 0.2611 		 Damage to the ship or objects outside the ship.
# 0.2192 		 Significant damage to the port system infrastructure.
#
#
# Sentence:             Lost Generation.
# Fault type detected:  rewrite
# Probabilities:
# 0.9996 		 rewrite
# 0.0004 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.6026 		 Loss of generation.
# 0.6026 		 Loss of Generation.
# 0.3469 		 Reduced gas production.
# 0.3037 		 Loss of produced energetic material.
# 0.2455 		 Spacecraft lost.
#
#
# Sentence:             Material or financial.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.5922 		 Financial loss.
# 0.5855 		 Financial losses.
# 0.4931 		 Loss of finances.
# 0.3418 		 Monetary losses.
# 0.3400 		 Financial loss or loss of hospital reputation.
#
#
# Sentence:             Mission delay.
# Fault type detected:  not
# Probabilities:
# 0.0002 		 rewrite
# 0.9998 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.5103 		 Loss of Mission.
# 0.5103 		 Loss of mission.
# 0.4682 		 Mission loss or degradation.
# 0.3623 		 Loss of mission (or performance degradation).
# 0.3575 		 Loss of mission (transportation).
#
#
# Sentence:             Mission Interruption or delay.
# Fault type detected:  not
# Probabilities:
# 0.0001 		 rewrite
# 0.9999 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.4589 		 Mission loss or degradation.
# 0.4426 		 Loss of Mission.
# 0.4426 		 Loss of mission.
# 0.3398 		 Mission Non-Compliance.
# 0.3258 		 Loss of mission (transportation).
#
#
# Sentence:             Multiple fatalities.
# Fault type detected:  rewrite
# Probabilities:
# 0.9994 		 rewrite
# 0.0004 		 not
# 0.0001 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.5140 		 One or more fatalities or significant injuries.
# 0.3526 		 Fatalities or injury to persons.
# 0.2637 		 Monetary losses.
# 0.2404 		 Indirect monetary losses.
# 0.2310 		 Damage and/or interruption of operations of other systems (Supporting infrastructure, other satellites, all other equipment).
#
#
# Sentence:             Non-patient injured or killed by radiation.
# Fault type detected:  condition
# Probabilities:
# 0.0000 		 rewrite
# 0.0000 		 not
# 1.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.6157 		 Patient suffers physical, non-radiological injury.
# 0.3896 		 Mission Non-Compliance.
# 0.3627 		 Loss to non-patient quality of life (esp. personnel).
# 0.2533 		 Staff suffers injury (radiological or physical).
# 0.2319 		 Patient injury or death.
#
#
# Sentence:             Non-patient injured or killed due to radiation.
# Fault type detected:  condition
# Probabilities:
# 0.0000 		 rewrite
# 0.0000 		 not
# 1.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.6034 		 Patient suffers physical, non-radiological injury.
# 0.4209 		 Loss to non-patient quality of life (esp. personnel).
# 0.3962 		 Mission Non-Compliance.
# 0.2224 		 Staff suffers injury (radiological or physical).
# 0.2194 		 Patient injury or death.
#
#
# Sentence:             Operating Unit cannot meet operational requirements or commitments.
# Fault type detected:  not
# Probabilities:
# 0.0006 		 rewrite
# 0.9993 		 not
# 0.0001 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2463 		 Loss of reputation (OEM and/or supplier).
# 0.1925 		 Vehicle Occupant Injury.
# 0.1728 		 Mission Non-Compliance.
# 0.1554 		 Mission loss (Unable to perform mission to design standards) (LOM).
# 0.1435 		 Loss of human life or human injury of laboratory-related personnel.
#
#
# Sentence:             Organisms of Earth origin are mistaken for organisms indigenous to any of the moons of the outer planet in future missions to study the outer planet's moon.
# Fault type detected:  not
# Probabilities:
# 0.0097 		 rewrite
# 0.6712 		 not
# 0.1206 		 condition
# 0.1985 		 accident
# Similar Valid Sentences:
# 0.3115 		 Loss of environmental integrity.
# 0.2761 		 Damage and/or interruption of operations of other systems (Supporting infrastructure, other satellites, all other equipment).
# 0.2439 		 Humans and/or human assets off of the earth are killed/damaged.
# 0.2413 		 Damage to the aircraft or objects outside the aircraft.
# 0.2310 		 Damage to the vehicle or objects outside the vehicle.
#
#
# Sentence:             Organisms on any of the moons of the outer planet (if they exist) are killed or mutated by biological agents of Earth Origin.
# Fault type detected:  not
# Probabilities:
# 0.0070 		 rewrite
# 0.4693 		 not
# 0.1798 		 condition
# 0.3439 		 accident
# Similar Valid Sentences:
# 0.3634 		 Humans and/or human assets off of the earth are killed/damaged.
# 0.3378 		 Humans and/or human assets on earth are killed/damaged.
# 0.2920 		 Humans injured or killed (On earth, in air, in space).
# 0.2356 		 Loss of environmental integrity.
# 0.2317 		 Damage of property (internal or external company).
#
#
# Sentence:             Passenger falls out of moving train.
# Fault type detected:  accident
# Probabilities:
# 0.0010 		 rewrite
# 0.0004 		 not
# 0.0009 		 condition
# 0.9977 		 accident
# Similar Valid Sentences:
# 0.3459 		 Passengers not able to escape train during emergency.
# 0.2991 		 Injury of passenger and crew.
# 0.2694 		 Loss of transportation.
# 0.1948 		 Loss of mission (transportation).
# 0.1887 		 Loss of consumer (rider) PII.
#
#
# Sentence:             Passenger steps off stopped train not at platform.
# Fault type detected:  accident
# Probabilities:
# 0.0002 		 rewrite
# 0.0001 		 not
# 0.0001 		 condition
# 0.9996 		 accident
# Similar Valid Sentences:
# 0.4358 		 Passengers not able to escape train during emergency.
# 0.1967 		 Personnel on the ground are injured or killed.
# 0.1747 		 Humans and/or human assets off of the earth are killed/damaged.
# 0.1714 		 Injury of passenger and crew.
# 0.1640 		 Structures on the ground are damaged or destroyed.
#
#
# Sentence:             Patient injured or killed due to radiation.
# Fault type detected:  condition
# Probabilities:
# 0.0000 		 rewrite
# 0.0000 		 not
# 1.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.3887 		 Patient injury or death.
# 0.3381 		 Patient is killed or seriously injured.
# 0.3381 		 patient is killed or seriously injured.
# 0.2924 		 People injured or killed.
# 0.2843 		 Staff suffers injury (radiological or physical).
#
#
# Sentence:             Patient injured or killed from radiation exposure.
# Fault type detected:  condition
# Probabilities:
# 0.0000 		 rewrite
# 0.0000 		 not
# 1.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.3002 		 Patient injury or death.
# 0.2793 		 Patient is killed or seriously injured.
# 0.2793 		 patient is killed or seriously injured.
# 0.2490 		 People injured or killed.
# 0.2488 		 Humans and/or human assets off of the earth are killed/damaged.
#
#
# Sentence:             Patient injured or killed from radiation exposure.
# Fault type detected:  condition
# Probabilities:
# 0.0000 		 rewrite
# 0.0000 		 not
# 1.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.3002 		 Patient injury or death.
# 0.2793 		 Patient is killed or seriously injured.
# 0.2793 		 patient is killed or seriously injured.
# 0.2490 		 People injured or killed.
# 0.2488 		 Humans and/or human assets off of the earth are killed/damaged.
#
#
# Sentence:             Patient injured or killed from radiation exposure.
# Fault type detected:  condition
# Probabilities:
# 0.0000 		 rewrite
# 0.0000 		 not
# 1.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.3002 		 Patient injury or death.
# 0.2793 		 Patient is killed or seriously injured.
# 0.2793 		 patient is killed or seriously injured.
# 0.2490 		 People injured or killed.
# 0.2488 		 Humans and/or human assets off of the earth are killed/damaged.
#
#
# Sentence:             Patient suffers radiological injury due to over-radiation.
# Fault type detected:  condition
# Probabilities:
# 0.0000 		 rewrite
# 0.0003 		 not
# 0.9996 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.4179 		 Patient suffers physical, non-radiological injury.
# 0.3502 		 Staff suffers injury (radiological or physical).
# 0.1686 		 patient is killed or seriously injured.
# 0.1686 		 Patient is killed or seriously injured.
# 0.1639 		 Loss of life or serious injury to patient.
#
#
# Sentence:             Patient’s cancer advances due to under-radiation.
# Fault type detected:  condition
# Probabilities:
# 0.0000 		 rewrite
# 0.0010 		 not
# 0.9988 		 condition
# 0.0002 		 accident
# Similar Valid Sentences:
# 0.2241 		 Patient’s pain is not relieved.
# 0.1968 		 Patient suffers physical, non-radiological injury.
# 0.1652 		 Loss/damage to aircraft and its equipment.
# 0.1611 		 Damage to airport infra-structure and/or proximities.
# 0.1530 		 Patient injury or death.
#
#
# Sentence:             People die or get injured from road crashes.
# Fault type detected:  condition
# Probabilities:
# 0.0003 		 rewrite
# 0.0000 		 not
# 0.9990 		 condition
# 0.0006 		 accident
# Similar Valid Sentences:
# 0.5335 		 People injured or killed.
# 0.3872 		 Loss of life or injury to people.
# 0.3667 		 Loss of human life or injured people.
# 0.3274 		 Fatalities or injury to persons.
# 0.3263 		 Death or injury to persons.
#
#
# Sentence:             People exposed to chemicals.
# Fault type detected:  condition
# Probabilities:
# 0.0255 		 rewrite
# 0.2695 		 not
# 0.6988 		 condition
# 0.0062 		 accident
# Similar Valid Sentences:
# 0.9342 		 People exposed to chemicals.
# 0.4971 		 Loss of life or injury to people.
# 0.4878 		 People injured or killed.
# 0.4827 		 Death or injury to persons.
# 0.4771 		 Fatalities or injury to persons.
#
#
# Sentence:             Physical damage to patient or non‐patient during treatment (not from radiation).
# Fault type detected:  condition
# Probabilities:
# 0.0002 		 rewrite
# 0.0002 		 not
# 0.9996 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.5743 		 Patient suffers physical, non-radiological injury.
# 0.3527 		 Staff suffers injury (radiological or physical).
# 0.3403 		 Patient’s pain is not relieved.
# 0.3312 		 Loss to non-patient quality of life (esp. personnel).
# 0.2748 		 Loss of life or injury to patient or personnel.
#
#
# Sentence:             Physical injury to patient or non-patient during treatment.
# Fault type detected:  condition
# Probabilities:
# 0.0006 		 rewrite
# 0.0001 		 not
# 0.9993 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.5996 		 Patient suffers physical, non-radiological injury.
# 0.4534 		 Loss to non-patient quality of life (esp. personnel).
# 0.3353 		 Loss of life or injury to patient or personnel.
# 0.3177 		 Mission Non-Compliance.
# 0.3115 		 Patient injury or death.
#
#
# Sentence:             Physical injury to patient or staff during treatment (not from RT).
# Fault type detected:  condition
# Probabilities:
# 0.0120 		 rewrite
# 0.0036 		 not
# 0.9843 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.4823 		 Staff suffers injury (radiological or physical).
# 0.3635 		 Patient suffers physical, non-radiological injury.
# 0.3270 		 Loss of life or injury to patient or personnel.
# 0.2706 		 Damage to patient or staff satisfaction, or hospital reputation.
# 0.2675 		 Patient’s pain is not relieved.
#
#
# Sentence:             Poor safety performance.
# Fault type detected:  not
# Probabilities:
# 0.0041 		 rewrite
# 0.9954 		 not
# 0.0002 		 condition
# 0.0003 		 accident
# Similar Valid Sentences:
# 0.3696 		 Loss of mission (or performance degradation).
# 0.3623 		 Loss of life/serious injury.
# 0.3583 		 Serious injury or fatality to personnel.
# 0.2937 		 Death or serious injury to rider or operator.
# 0.2932 		 Human serious injury or loss of life.
#
#
# Sentence:             Power shortages.
# Fault type detected:  not
# Probabilities:
# 0.0002 		 rewrite
# 0.9989 		 not
# 0.0001 		 condition
# 0.0008 		 accident
# Similar Valid Sentences:
# 0.3629 		 Loss of electrical power generation.
# 0.1794 		 Loss of economic stability (e.g. closure of business / increases in unemployment, decrease in purchasing power).
# 0.1563 		 Damage to patient or staff satisfaction, or hospital reputation.
# 0.1561 		 Staff suffers injury (radiological or physical).
# 0.1548 		 Loss of mission (or performance degradation).
#
#
# Sentence:             Product integrity compromised.
# Fault type detected:  not
# Probabilities:
# 0.0000 		 rewrite
# 0.9998 		 not
# 0.0001 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.4619 		 Product loss.
# 0.4447 		 Loss or damage of product.
# 0.4224 		 Loss of product certification.
# 0.3489 		 Loss of Intellectual Property.
# 0.3483 		 Loss of environmental integrity.
#
#
# Sentence:             Property damage from road crashes.
# Fault type detected:  accident
# Probabilities:
# 0.0000 		 rewrite
# 0.0005 		 not
# 0.0002 		 condition
# 0.9993 		 accident
# Similar Valid Sentences:
# 0.3317 		 Loss of Human Life, Human Injury, Properties Damage or Environmental Losses.
# 0.3198 		 Loss or damage to public or private properties.
# 0.3174 		 Loss of human live or severe human injury or property damage.
# 0.2717 		 Loss of Intellectual Property.
# 0.2390 		 Injury or property damage occurring within the vehicle, without a collision.
#
#
# Sentence:             Radiation Exposure.
# Fault type detected:  not
# Probabilities:
# 0.0001 		 rewrite
# 0.9996 		 not
# 0.0002 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.2512 		 Staff suffers injury (radiological or physical).
# 0.1993 		 People exposed to chemicals.
# 0.1898 		 Patient suffers physical, non-radiological injury.
# 0.1895 		 Environmental Damage.
# 0.1808 		 Environmental loss.
#
#
# Sentence:             Ready For Operation Target Date not achieved.
# Fault type detected:  not
# Probabilities:
# 0.0000 		 rewrite
# 1.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2320 		 Scientific mission is not performed (mission loss).
# 0.1758 		 Patient’s pain is not relieved.
# 0.1414 		 Loss of time (inefficient operation).
# 0.1400 		 Loss of mission (or performance degradation).
# 0.1317 		 Passengers not able to escape train during emergency.
#
#
# Sentence:             Rework and project schedule timeline losses.
# Fault type detected:  rewrite
# Probabilities:
# 0.9996 		 rewrite
# 0.0003 		 not
# 0.0001 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.2338 		 Economic loss.
# 0.2260 		 Indirect monetary losses.
# 0.2238 		 Product loss.
# 0.2199 		 Production loss.
# 0.2158 		 Financial losses.
#
#
# Sentence:             Scheduled work is not completed on time.
# Fault type detected:  not
# Probabilities:
# 0.0002 		 rewrite
# 0.9990 		 not
# 0.0005 		 condition
# 0.0003 		 accident
# Similar Valid Sentences:
# 0.3218 		 Scientific mission is not performed (mission loss).
# 0.2609 		 Patient’s pain is not relieved.
# 0.2396 		 Loss of time (inefficient operation).
# 0.1432 		 Personnel on the ground are injured or killed.
# 0.1249 		 Passengers not able to escape train during emergency.
#
#
# Sentence:             Significant environmental release (possibly only minor for this application).
# Fault type detected:  not
# Probabilities:
# 0.0007 		 rewrite
# 0.9991 		 not
# 0.0002 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.4420 		 Environmental loss (release).
# 0.3045 		 Environmental Damage.
# 0.2901 		 Environmental loss.
# 0.2841 		 One or more fatalities or significant injuries.
# 0.2724 		 Significant damage to the port system infrastructure.
#
#
# Sentence:             Staff injured or killed from radiation exposure.
# Fault type detected:  condition
# Probabilities:
# 0.0000 		 rewrite
# 0.0000 		 not
# 1.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.4179 		 Staff suffers injury (radiological or physical).
# 0.2735 		 Humans and/or human assets off of the earth are killed/damaged.
# 0.2606 		 Personnel on the ground are injured or killed.
# 0.2165 		 People injured or killed.
# 0.1847 		 Damage to equipment.
#
#
# Sentence:             Testing or flight operations are unable to be conducted.
# Fault type detected:  not
# Probabilities:
# 0.0011 		 rewrite
# 0.9972 		 not
# 0.0013 		 condition
# 0.0005 		 accident
# Similar Valid Sentences:
# 0.3055 		 Loss of flight test productivity.
# 0.2577 		 Scientific mission is not performed (mission loss).
# 0.1771 		 Personnel on the ground are injured or killed.
# 0.1710 		 Loss of or damage to aircraft.
# 0.1638 		 Loss or damage to aircraft.
#
#
# Sentence:             The ACC vehicle crashes with a vehicle in front when the ACC system is in active mode (Forward Collision vehicle to vehicle).
# Fault type detected:  accident
# Probabilities:
# 0.0002 		 rewrite
# 0.0005 		 not
# 0.0000 		 condition
# 0.9992 		 accident
# Similar Valid Sentences:
# 0.3731 		 AV gets damaged.
# 0.2494 		 Damage to the vehicle.
# 0.2474 		 Damage to the vehicle or objects outside the vehicle.
# 0.2412 		 Loss or damage to the vehicle.
# 0.2020 		 Loss or damage to ego vehicle.
#
#
# Sentence:             The patient is injured or killed from subsequent treatment due to inaccurate MRI simulation.
# Fault type detected:  condition
# Probabilities:
# 0.0000 		 rewrite
# 0.0004 		 not
# 0.9996 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2549 		 Indirect monetary losses.
# 0.2272 		 patient is killed or seriously injured.
# 0.2272 		 Patient is killed or seriously injured.
# 0.1702 		 Staff suffers injury (radiological or physical).
# 0.1688 		 Patient injury or death.
#
#
# Sentence:             The patient is injured or killed in the process of MRI simulation.
# Fault type detected:  condition
# Probabilities:
# 0.0001 		 rewrite
# 0.0003 		 not
# 0.9996 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2948 		 Patient is killed or seriously injured.
# 0.2948 		 patient is killed or seriously injured.
# 0.2630 		 Patient injury or death.
# 0.2481 		 Loss of mission (or performance degradation).
# 0.2451 		 Personnel on the ground are injured or killed.
#
#
# Sentence:             The scientific data corresponding to the mission goals are not collected.
# Fault type detected:  not
# Probabilities:
# 0.0002 		 rewrite
# 0.9991 		 not
# 0.0003 		 condition
# 0.0004 		 accident
# Similar Valid Sentences:
# 0.6933 		 Scientific mission is not performed (mission loss).
# 0.3501 		 Mission loss or degradation.
# 0.3232 		 Loss of Mission.
# 0.3232 		 Loss of mission.
# 0.3192 		 Mission Non-Compliance.
#
#
# Sentence:             The scientific data is rendered unusable (e.g., deleted, corrupted, not returned at required time) before it can be fully investigated.
# Fault type detected:  not
# Probabilities:
# 0.0007 		 rewrite
# 0.9979 		 not
# 0.0012 		 condition
# 0.0002 		 accident
# Similar Valid Sentences:
# 0.3394 		 Scientific mission is not performed (mission loss).
# 0.1777 		 Unplanned damage or disruption of the satellite (LOV).
# 0.1772 		 Loss of Critical Protected Data.
# 0.1731 		 People physically injured (e.g. explosion).
# 0.1573 		 Patient’s pain is not relieved.
#
#
# Sentence:             The train derails.
# Fault type detected:  accident
# Probabilities:
# 0.0000 		 rewrite
# 0.0006 		 not
# 0.0001 		 condition
# 0.9994 		 accident
# Similar Valid Sentences:
# 0.2829 		 Passengers not able to escape train during emergency.
# 0.2000 		 Damage to the vehicle.
# 0.1908 		 Death or injury.
# 0.1898 		 Injury of passenger and crew.
# 0.1658 		 Loss or damage to the vehicle.
#
#
# Sentence:             The train hits obstacles that violated the limit.
# Fault type detected:  accident
# Probabilities:
# 0.0022 		 rewrite
# 0.3042 		 not
# 0.0093 		 condition
# 0.6843 		 accident
# Similar Valid Sentences:
# 0.2850 		 Passengers not able to escape train during emergency.
# 0.1867 		 Damage to the vehicle.
# 0.1681 		 Damage to the vehicle or objects outside the vehicle.
# 0.1621 		 Loss or damage to the vehicle.
# 0.1497 		 Damage to the ship or objects outside the ship.
#
#
# Sentence:             The train hits personnel.
# Fault type detected:  accident
# Probabilities:
# 0.0001 		 rewrite
# 0.0009 		 not
# 0.0000 		 condition
# 0.9990 		 accident
# Similar Valid Sentences:
# 0.4189 		 Personnel on the ground are injured or killed.
# 0.3929 		 Loss of life or injury to personnel.
# 0.3717 		 Loss of life or injury to patient or personnel.
# 0.3625 		 Staff suffers injury (radiological or physical).
# 0.3577 		 Serious injury or fatality to personnel.
#
#
# Sentence:             The train squeezes at switch.
# Fault type detected:  accident
# Probabilities:
# 0.0016 		 rewrite
# 0.0250 		 not
# 0.0032 		 condition
# 0.9701 		 accident
# Similar Valid Sentences:
# 0.2512 		 Passengers not able to escape train during emergency.
# 0.2171 		 Disruption on processing or transport.
# 0.1883 		 Staff suffers injury (radiological or physical).
# 0.1215 		 Injury of passenger and crew.
# 0.1152 		 People physically injured (e.g. explosion).
#
#
# Sentence:             The vehicle behind crashes the ACC vehicle when the ACC system detects an object in the vehicle path (Backward Collision vehicle to vehicle).
# Fault type detected:  accident
# Probabilities:
# 0.0002 		 rewrite
# 0.0001 		 not
# 0.0000 		 condition
# 0.9997 		 accident
# Similar Valid Sentences:
# 0.3944 		 Damage to the vehicle or objects outside the vehicle.
# 0.3052 		 Damage to the vehicle.
# 0.3037 		 AV gets damaged.
# 0.2988 		 Loss or damage to the vehicle.
# 0.2332 		 Damage to the aircraft or objects outside the aircraft.
#
#
# Sentence:             Two aircraft collide.
# Fault type detected:  accident
# Probabilities:
# 0.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.9999 		 accident
# Similar Valid Sentences:
# 0.3664 		 Loss of aircraft.
# 0.3249 		 Damage to or loss of aircraft.
# 0.3217 		 Damage to the aircraft.
# 0.3213 		 Loss or damage to aircraft.
# 0.3163 		 Loss of or damage to aircraft.
#
#
# Sentence:             Two or more vehicles collide.
# Fault type detected:  accident
# Probabilities:
# 0.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.9999 		 accident
# Similar Valid Sentences:
# 0.3660 		 One or more fatalities or significant injuries.
# 0.2499 		 Damage to the vehicle.
# 0.2401 		 Vehicle Occupant Injury.
# 0.2287 		 Damage to the vehicle or objects outside the vehicle.
# 0.2283 		 Loss or damage to the vehicle.
#
#
# Sentence:             Two or more vehicles collide.
# Fault type detected:  accident
# Probabilities:
# 0.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.9999 		 accident
# Similar Valid Sentences:
# 0.3660 		 One or more fatalities or significant injuries.
# 0.2499 		 Damage to the vehicle.
# 0.2401 		 Vehicle Occupant Injury.
# 0.2287 		 Damage to the vehicle or objects outside the vehicle.
# 0.2283 		 Loss or damage to the vehicle.
#
#
# Sentence:             Two or more vehicles collide.
# Fault type detected:  accident
# Probabilities:
# 0.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.9999 		 accident
# Similar Valid Sentences:
# 0.3660 		 One or more fatalities or significant injuries.
# 0.2499 		 Damage to the vehicle.
# 0.2401 		 Vehicle Occupant Injury.
# 0.2287 		 Damage to the vehicle or objects outside the vehicle.
# 0.2283 		 Loss or damage to the vehicle.
#
#
# Sentence:             Two or more Vehicles Collide.
# Fault type detected:  accident
# Probabilities:
# 0.0000 		 rewrite
# 0.0001 		 not
# 0.0000 		 condition
# 0.9999 		 accident
# Similar Valid Sentences:
# 0.3660 		 One or more fatalities or significant injuries.
# 0.2499 		 Damage to the vehicle.
# 0.2401 		 Vehicle Occupant Injury.
# 0.2287 		 Damage to the vehicle or objects outside the vehicle.
# 0.2283 		 Loss or damage to the vehicle.
#
#
# Sentence:             Two or more vehicles collide.
# Fault type detected:  accident
# Probabilities:
# 0.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.9999 		 accident
# Similar Valid Sentences:
# 0.3660 		 One or more fatalities or significant injuries.
# 0.2499 		 Damage to the vehicle.
# 0.2401 		 Vehicle Occupant Injury.
# 0.2287 		 Damage to the vehicle or objects outside the vehicle.
# 0.2283 		 Loss or damage to the vehicle.
#
#
# Sentence:             Unable to Complete Mission.
# Fault type detected:  rewrite
# Probabilities:
# 0.9998 		 rewrite
# 0.0002 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.4703 		 Loss of Mission.
# 0.4703 		 Loss of mission.
# 0.4031 		 Mission loss or degradation.
# 0.3984 		 Mission loss (Unable to perform mission to design standards) (LOM).
# 0.3598 		 Mission Non-Compliance.
#
#
# Sentence:             Vehicle collides with a moving body.
# Fault type detected:  accident
# Probabilities:
# 0.0000 		 rewrite
# 0.0001 		 not
# 0.0000 		 condition
# 0.9999 		 accident
# Similar Valid Sentences:
# 0.2835 		 Vehicle Occupant Injury.
# 0.2825 		 Injury or property damage occurring within the vehicle, without a collision.
# 0.2253 		 Damage to the vehicle.
# 0.2115 		 Damage to the vehicle or objects outside the vehicle.
# 0.1788 		 Disruption on processing or transport.
#
#
# Sentence:             Vehicle collides with a non-moving body.
# Fault type detected:  accident
# Probabilities:
# 0.0000 		 rewrite
# 0.0001 		 not
# 0.0000 		 condition
# 0.9999 		 accident
# Similar Valid Sentences:
# 0.4036 		 Injury or property damage occurring within the vehicle, without a collision.
# 0.3341 		 Mission Non-Compliance.
# 0.2878 		 Patient suffers physical, non-radiological injury.
# 0.2779 		 Vehicle Occupant Injury.
# 0.2411 		 Damage to the vehicle or objects outside the vehicle.
#
#
# Sentence:             Vehicle collides with non-fixed obstacle.
# Fault type detected:  accident
# Probabilities:
# 0.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.9999 		 accident
# Similar Valid Sentences:
# 0.3194 		 Injury or property damage occurring within the vehicle, without a collision.
# 0.2958 		 Mission Non-Compliance.
# 0.2176 		 Vehicle Occupant Injury.
# 0.2160 		 Patient suffers physical, non-radiological injury.
# 0.2069 		 Loss of customer satisfaction with automated parking, without injury or property damage.
#
#
# Sentence:             Vehicle collides with non-fixed obstacle.
# Fault type detected:  accident
# Probabilities:
# 0.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.9999 		 accident
# Similar Valid Sentences:
# 0.3194 		 Injury or property damage occurring within the vehicle, without a collision.
# 0.2958 		 Mission Non-Compliance.
# 0.2176 		 Vehicle Occupant Injury.
# 0.2160 		 Patient suffers physical, non-radiological injury.
# 0.2069 		 Loss of customer satisfaction with automated parking, without injury or property damage.
#
#
# Sentence:             Vehicle collides with non-fixed obstacle.
# Fault type detected:  accident
# Probabilities:
# 0.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.9999 		 accident
# Similar Valid Sentences:
# 0.3194 		 Injury or property damage occurring within the vehicle, without a collision.
# 0.2958 		 Mission Non-Compliance.
# 0.2176 		 Vehicle Occupant Injury.
# 0.2160 		 Patient suffers physical, non-radiological injury.
# 0.2069 		 Loss of customer satisfaction with automated parking, without injury or property damage.
#
#
# Sentence:             Vehicle Collides with Pedestrian(s).
# Fault type detected:  accident
# Probabilities:
# 0.0001 		 rewrite
# 0.0006 		 not
# 0.0000 		 condition
# 0.9993 		 accident
# Similar Valid Sentences:
# 0.2322 		 Vehicle is damaged (economic loss).
# 0.1991 		 Injury or property damage occurring within the vehicle, without a collision.
# 0.1790 		 Damage to the vehicle or objects outside the vehicle.
# 0.1680 		 Significant damage to other people's property.
# 0.1653 		 Fatalities or injury to persons.
#
#
# Sentence:             Vehicle crashes into terrain.
# Fault type detected:  accident
# Probabilities:
# 0.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 1.0000 		 accident
# Similar Valid Sentences:
# 0.2568 		 Damage to the vehicle.
# 0.2390 		 Loss or damage to the vehicle.
# 0.2020 		 Damage to the vehicle or objects outside the vehicle.
# 0.1793 		 Vehicle Occupant Injury.
# 0.1602 		 Vehicle is damaged (economic loss).
#
#
# Sentence:             Vehicle crashes into terrain.
# Fault type detected:  accident
# Probabilities:
# 0.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 1.0000 		 accident
# Similar Valid Sentences:
# 0.2568 		 Damage to the vehicle.
# 0.2390 		 Loss or damage to the vehicle.
# 0.2020 		 Damage to the vehicle or objects outside the vehicle.
# 0.1793 		 Vehicle Occupant Injury.
# 0.1602 		 Vehicle is damaged (economic loss).
#
#
# Sentence:             Vehicle crashes into terrain.
# Fault type detected:  accident
# Probabilities:
# 0.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 1.0000 		 accident
# Similar Valid Sentences:
# 0.2568 		 Damage to the vehicle.
# 0.2390 		 Loss or damage to the vehicle.
# 0.2020 		 Damage to the vehicle or objects outside the vehicle.
# 0.1793 		 Vehicle Occupant Injury.
# 0.1602 		 Vehicle is damaged (economic loss).
#
#
# Sentence:             Vehicle crashes when Autopilot is active.
# Fault type detected:  accident
# Probabilities:
# 0.0000 		 rewrite
# 0.0003 		 not
# 0.0000 		 condition
# 0.9996 		 accident
# Similar Valid Sentences:
# 0.2778 		 AV gets damaged.
# 0.2143 		 Vehicle is damaged (economic loss).
# 0.1769 		 Vehicle Occupant Injury.
# 0.1448 		 Loss or damage to ego vehicle.
# 0.1103 		 Loss of Acme Intellectual Property.
#
#
# Sentence:             Vehicle occupants are injured during operation.
# Fault type detected:  condition
# Probabilities:
# 0.0014 		 rewrite
# 0.0002 		 not
# 0.9983 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.4300 		 Vehicle Occupant Injury.
# 0.3030 		 Passengers not able to escape train during emergency.
# 0.2605 		 Damage to the vehicle or objects outside the vehicle.
# 0.2401 		 Injury of passenger and crew.
# 0.2361 		 Personnel on the ground are injured or killed.
#
#
# Sentence:             vehicle occupants are injured while ACC is engaged.
# Fault type detected:  condition
# Probabilities:
# 0.0001 		 rewrite
# 0.0000 		 not
# 0.9998 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.3590 		 Vehicle Occupant Injury.
# 0.3348 		 AV gets damaged.
# 0.2035 		 Injury or property damage occurring within the vehicle, without a collision.
# 0.1839 		 Vehicle is damaged (economic loss).
# 0.1639 		 Loss of Acme Intellectual Property.
#
#
# Sentence:             Vehicle occupants are injured while ACC is engaged.
# Fault type detected:  condition
# Probabilities:
# 0.0001 		 rewrite
# 0.0000 		 not
# 0.9998 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.3590 		 Vehicle Occupant Injury.
# 0.3348 		 AV gets damaged.
# 0.2035 		 Injury or property damage occurring within the vehicle, without a collision.
# 0.1839 		 Vehicle is damaged (economic loss).
# 0.1639 		 Loss of Acme Intellectual Property.
#
#
# Sentence:             Vehicle occupants injured without vehicle collision.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.6148 		 Injury or property damage occurring within the vehicle, without a collision.
# 0.3773 		 Loss of customer satisfaction with automated parking, without injury or property damage.
# 0.3416 		 Vehicle Occupant Injury.
# 0.2827 		 Damage to the vehicle or objects outside the vehicle.
# 0.2387 		 Passengers not able to escape train during emergency.
#
#
# Sentence:             Vehicle occupants injured without vehicle collision.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.6148 		 Injury or property damage occurring within the vehicle, without a collision.
# 0.3773 		 Loss of customer satisfaction with automated parking, without injury or property damage.
# 0.3416 		 Vehicle Occupant Injury.
# 0.2827 		 Damage to the vehicle or objects outside the vehicle.
# 0.2387 		 Passengers not able to escape train during emergency.
#
#
# Sentence:             Vehicle occupants injured without vehicle collision.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.6148 		 Injury or property damage occurring within the vehicle, without a collision.
# 0.3773 		 Loss of customer satisfaction with automated parking, without injury or property damage.
# 0.3416 		 Vehicle Occupant Injury.
# 0.2827 		 Damage to the vehicle or objects outside the vehicle.
# 0.2387 		 Passengers not able to escape train during emergency.

# %%
# print Hazard results

print('########### HAZARD')
print('Valid Sentences:')
print(list_valid_hazard)
print('\n')
print('Invalid Sentences:')
print_invalid(list_dict_faults_hazard, list_similar_hazard)
# Out:
# ########### HAZARD
# Valid Sentences:
# ['A pair of controlled aircraft violates minimum separation standards.', 'A/C not compliant with airworthiness requirements.', 'ACC did not illuminate brake light to warn vehicle in the behind.', 'ACC does not maintain a safe distance from the object in the front (resulting in a collision).', 'ACC estimates wrong values of distance and speed of vehicle ahead.', 'ACC slows down the vehicle too abruptly (and vehicle is rear-ended).', 'ACC slows down the vehicle too abruptly, and vehicle is rear-ended.', 'ACC violates the safe distance between ACC vehicle and vehicle in front.', 'Aircraft airframe integrity is degraded.', 'Aircraft does not stop before the runway end.', 'Aircraft enters a prohibited area.', 'Aircraft enters a runway with no clearance.', 'Aircraft enters an unsafe atmospheric region.', 'Aircraft enters prohibited area.', 'Aircraft enters prohibited area.', 'Aircraft enters uncontrolled state.', 'Aircraft enters uncontrolled state.', 'Aircraft enters uncontrolled state.', 'Aircraft enters unsafe atmospheric region.', 'Aircraft enters unsafe atmospheric region.', 'Aircraft enters unsafe attitude (excessive turbulence or pitch/roll/yaw that causes passenger injury but not necessarily aircraft loss).', 'Aircraft enters unsafe attitude.', 'Aircraft enters unsafe attitude.', 'Aircraft environment is harmful to human health.', 'Aircraft flying off the route specified at flight plan.', 'Aircraft loses its control or loses airframe integrity.', 'Aircraft on the ground comes too close to other objects or leaves the paved area.', 'Aircraft placed on trajectory or position that intersects with a physical obstruction (e.g., loss of separation, controlled flight into terrain).', 'Aircraft placed on trajectory that intersects with dangerous atmospheric conditions (e.g., storms, volcanic ash).', 'Aircraft veers to a runway side.', 'Aircraft violate minimum separation standards in flight.', 'Aircraft violate minimum separation with other aircraft.', 'Aircraft violates criteria for stable approaches.', 'Aircraft violates minimum separation from airspace or other aircraft.', 'ASTRO-H unable to collect scientific data.', 'ASTRO-H unable to communicate scientific data.', 'Autopilot does not react to other road crossing vehicles/obstacles.', 'AV activates without request during autonomous maneuver.', 'AV behavior is uncomfortable for the passengers.', 'AV does not maintain a safe distance from vulnerable road users (VRUs) or other stationary or moving objects in the surroundings.', 'AV does not maintain safe distance to another AV.', 'AV does not maintain safe distance to structure.', 'AV does not maintain safe distance to VRU.', 'AV leaves designated path.', 'AV leaves the designated demo zone.', 'AV loses control.', 'AV violates allowed operating conditions.', 'Cabin parameters incompatible with human survival.', 'Catching fire inside the ship.', 'Certification Process implemented is not adequate to identify critical flaws or loss scenarios.', "Commands for dosage exceeding the patient's tolerance are sent to the pump.", 'Company doesn’t complete the certification processes.', 'Company takes actions inconsistent with stated values.', 'Consumer (rider) PII exposed to unauthorized individuals.', "Customer's data misused by authorized 3rd parties.", "Customer's data misused by JID.", "Customer's data released to public.", "Customer's data released to unauthorized 3rd parties.", 'Design, Product, Quality Management System or Manufacturing Process certified with safety or mission related requirements not verified or not specified.', 'Doors open when not aligned to platform.', 'Doors open when the train is moving or not at platform.', 'Doors open while train is in motion or not aligned with station platform.', 'Doors stuck closed during emergency.', 'Doors stuck open.', 'Driver does not provide required attention to driving tasks and environment.', 'Ego vehicle applies hard acceleration.', 'Ego vehicle applies hard braking.', 'Ego vehicle  ...
#
#
# Invalid Sentences:
# Sentence:             A person or worker is standing/working under or passing through the excavators’ range cycle.
# Fault type detected:  rewrite
# Probabilities:
# 0.9998 		 rewrite
# 0.0001 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.4481 		 Excavator within the vicinity of overhead electric lines.
# 0.2808 		 Robot makes contact with a person (directly or indirectly).
# 0.2661 		 Person is exposed to harm during testing process.
# 0.2471 		 Equipment Operated Beyond Limits.
# 0.2471 		 Equipment operated beyond limits.
#
#
# Sentence:             Absence of warning when vehicle moves out of lane, resulting in a collision.
# Fault type detected:  condition
# Probabilities:
# 0.0003 		 rewrite
# 0.0006 		 not
# 0.9990 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.3696 		 Vehicle or payload out of flight route.
# 0.3252 		 Vehicle (driven by human, automation or in cooperation) leaves the roadway.
# 0.2914 		 Violating a minimum of separation between vehicles and between vehicles and objects.
# 0.2800 		 Vehicle does not maintain safe distance from nearby vehicles.
# 0.2765 		 Ego vehicle leaves its lane.
#
#
# Sentence:             ACC did not maintain a safe distance from the object in the front, resultng in collision.
# Fault type detected:  condition
# Probabilities:
# 0.2453 		 rewrite
# 0.0273 		 not
# 0.7005 		 condition
# 0.0268 		 accident
# Similar Valid Sentences:
# 0.8977 		 ACC does not maintain a safe distance from the object in the front (resulting in a collision).
# 0.6072 		 ACC violates the safe distance between ACC vehicle and vehicle in front.
# 0.5183 		 ACC did not illuminate brake light to warn vehicle in the behind.
# 0.4168 		 AV does not maintain safe distance to structure.
# 0.4073 		 Vehicle does not maintain safe distance from nearby objects.
#
#
# Sentence:             ACC does not reduce throttle and apply the braking force to maintain safe distance as preset by driver when vehicle catches up with a slower preceding vehicle.
# Fault type detected:  rewrite
# Probabilities:
# 0.9997 		 rewrite
# 0.0003 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.5663 		 ACC slows down the vehicle too abruptly, and vehicle is rear-ended.
# 0.5633 		 ACC slows down the vehicle too abruptly (and vehicle is rear-ended).
# 0.4992 		 ACC violates the safe distance between ACC vehicle and vehicle in front.
# 0.4826 		 ACC estimates wrong values of distance and speed of vehicle ahead.
# 0.4729 		 ACC does not maintain a safe distance from the object in the front (resulting in a collision).
#
#
# Sentence:             Aircraft comes too close to airport infrastructure components during operations on the ground.
# Fault type detected:  condition
# Probabilities:
# 0.0001 		 rewrite
# 0.0002 		 not
# 0.9995 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.5315 		 Aircraft on the ground comes too close to other objects or leaves the paved area.
# 0.3159 		 UAV too close to ground/building/person.
# 0.2516 		 Aircraft does not stop before the runway end.
# 0.2467 		 Aircraft veers to a runway side.
# 0.2350 		 Unable to dispatch aircraft.
#
#
# Sentence:             Aircraft comes too close to service equipment components during operations on the ground.
# Fault type detected:  condition
# Probabilities:
# 0.0000 		 rewrite
# 0.0002 		 not
# 0.9997 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.4645 		 Aircraft on the ground comes too close to other objects or leaves the paved area.
# 0.2596 		 The aircraft violates the minimum safety distance.
# 0.2592 		 UAV too close to ground/building/person.
# 0.2200 		 TCAS interferes with other safety-related aircraft systems (for example, ground proximity warning).
# 0.2126 		 The ship is very close to another ship or object.
#
#
# Sentence:             Aircraft component is powered up when hazardous FLS is installed
# Fault type detected:  condition
# Probabilities:
# 0.0002 		 rewrite
# 0.0003 		 not
# 0.9993 		 condition
# 0.0002 		 accident
# Similar Valid Sentences:
# 0.2791 		 Aircraft violates criteria for stable approaches.
# 0.2692 		 Aircraft airframe integrity is degraded.
# 0.2479 		 TCAS interferes with other safety-related aircraft systems (for example, ground proximity warning).
# 0.2432 		 Aircraft enters unsafe attitude.
# 0.2279 		 Flight crew is overworked.
#
#
# Sentence:             Aircraft is operated when hazardous FLS is installed.
# Fault type detected:  condition
# Probabilities:
# 0.1594 		 rewrite
# 0.0011 		 not
# 0.8395 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.3075 		 Aircraft violates criteria for stable approaches.
# 0.2710 		 The aircraft violates the minimum safety distance.
# 0.2643 		 AV violates allowed operating conditions.
# 0.2642 		 Aircraft airframe integrity is degraded.
# 0.2549 		 Navigation software with feta defects is integrated into navigation system.
#
#
# Sentence:             Aircraft performs controlled maneuver into ground or into obstacles on ground.
# Fault type detected:  rewrite
# Probabilities:
# 0.9998 		 rewrite
# 0.0002 		 not
# 0.0001 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.4248 		 Aircraft placed on trajectory or position that intersects with a physical obstruction (e.g., loss of separation, controlled flight into terrain).
# 0.3775 		 Aircraft enters prohibited area.
# 0.3568 		 Aircraft enters a prohibited area.
# 0.3094 		 Aircraft enters uncontrolled state.
# 0.2974 		 Aircraft on the ground comes too close to other objects or leaves the paved area.
#
#
# Sentence:             Aircraft violates the minimum separation from other aircrafts during operations on the ground.
# Fault type detected:  condition
# Probabilities:
# 0.0006 		 rewrite
# 0.0001 		 not
# 0.9990 		 condition
# 0.0003 		 accident
# Similar Valid Sentences:
# 0.7324 		 Aircraft violates minimum separation from airspace or other aircraft.
# 0.6916 		 Aircraft violate minimum separation with other aircraft.
# 0.5321 		 Aircraft on the ground comes too close to other objects or leaves the paved area.
# 0.4828 		 Ship violates minimum separation from other ship.
# 0.4202 		 The aircraft violates the minimum safety distance.
#
#
# Sentence:             Aircraft violates the minimum separation from service vehicles during operations on the ground.
# Fault type detected:  condition
# Probabilities:
# 0.0002 		 rewrite
# 0.0001 		 not
# 0.9997 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.4667 		 Violating a minimum of separation between vehicles and between vehicles and objects.
# 0.4254 		 The aircraft violates the minimum safety distance.
# 0.3723 		 Aircraft violate minimum separation standards in flight.
# 0.3403 		 Aircraft violates minimum separation from airspace or other aircraft.
# 0.3362 		 Vehicle (driven by human, automation or in cooperation) violates minimum safety distance to objects, road users, vehicles, etc.
#
#
# Sentence:             Airframe integrity is lost during operations on the ground.
# Fault type detected:  condition
# Probabilities:
# 0.0000 		 rewrite
# 0.0000 		 not
# 0.9999 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.5726 		 Aircraft airframe integrity is degraded.
# 0.5590 		 Loss of airframe integrity.
# 0.3937 		 Human physical integrity is lost during operations.
# 0.3445 		 Loss of UAV airframe integrity.
# 0.3216 		 Aircraft loses its control or loses airframe integrity.
#
#
# Sentence:             Airport infrastructure component integrity is lost during operations.
# Fault type detected:  condition
# Probabilities:
# 0.0004 		 rewrite
# 0.0005 		 not
# 0.9991 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.4201 		 Human physical integrity is lost during operations.
# 0.3903 		 Workplace ventilation integrity is lost.
# 0.3692 		 Aircraft airframe integrity is degraded.
# 0.2874 		 Mission efficiency is compromised by interference.
# 0.2248 		 Materials, tools, infrastructure, or equipment damaged or unavailable to the operator proceed with the laboratory activities.
#
#
# Sentence:             Authorities do not award permits to the Project when required for start of related Project construction activities.
# Fault type detected:  condition
# Probabilities:
# 0.0052 		 rewrite
# 0.0353 		 not
# 0.9592 		 condition
# 0.0003 		 accident
# Similar Valid Sentences:
# 0.3403 		 Laboratory facilities not appropriated for the current activities.
# 0.3189 		 Company doesn’t complete the certification processes.
# 0.2576 		 Certification Process temporally interrupted due to budgetary constraints to the project.
# 0.2569 		 Leaking of project or production documentation.
# 0.2538 		 Nuclear power plant radioactive materials are not contained.
#
#
# Sentence:             AV activates due to incorrect request during autonomous maneuver.
# Fault type detected:  condition
# Probabilities:
# 0.0000 		 rewrite
# 0.0000 		 not
# 0.9999 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.6805 		 AV activates without request during autonomous maneuver.
# 0.4097 		 ACC estimates wrong values of distance and speed of vehicle ahead.
# 0.3479 		 AV violates allowed operating conditions.
# 0.3458 		 AV behavior is uncomfortable for the passengers.
# 0.3347 		 AV loses control.
#
#
# Sentence:             AV does not respond to requests during autonomous maneuver.
# Fault type detected:  condition
# Probabilities:
# 0.0003 		 rewrite
# 0.0000 		 not
# 0.9994 		 condition
# 0.0002 		 accident
# Similar Valid Sentences:
# 0.7056 		 AV activates without request during autonomous maneuver.
# 0.4412 		 AV does not maintain safe distance to another AV.
# 0.3744 		 AV does not maintain safe distance to structure.
# 0.3641 		 Autopilot does not react to other road crossing vehicles/obstacles.
# 0.3482 		 ACC did not illuminate brake light to warn vehicle in the behind.
#
#
# Sentence:             Blown tire procedure not followed.
# Fault type detected:  rewrite
# Probabilities:
# 0.9991 		 rewrite
# 0.0007 		 not
# 0.0001 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.3486 		 Certification Tests not performed as scheduled.
# 0.3360 		 Patient does not receive treatment.
# 0.3119 		 Landing gear retraction with blown tire.
# 0.2393 		 Mission science data not gathered, returned, or stored.
# 0.2242 		 Driver does not provide required attention to driving tasks and environment.
#
#
# Sentence:             Certification Authority personal, including Organization Designation Authorization (ODA), unqualified to the product in analyse or at the certification process.
# Fault type detected:  rewrite
# Probabilities:
# 0.7346 		 rewrite
# 0.0213 		 not
# 0.2440 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.9835 		 Certification Authority personal, including Organization Designation Authorization (ODA), unqualified to the product in analyse or at the certification process.
# 0.3407 		 Company doesn’t complete the certification processes.
# 0.3259 		 Products accepted in non-conformance with the specification.
# 0.3100 		 Inability to confirm product integrity.
# 0.3080 		 Inability of companies / organizations to operate normally.
#
#
# Sentence:             Certification Process temporally interrupted due to budgetary constraints to the project.
# Fault type detected:  condition
# Probabilities:
# 0.0000 		 rewrite
# 0.0003 		 not
# 0.9997 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.9752 		 Certification Process temporally interrupted due to budgetary constraints to the project.
# 0.2922 		 Company doesn’t complete the certification processes.
# 0.2861 		 Leaking of project or production documentation.
# 0.2179 		 Certification Process implemented is not adequate to identify critical flaws or loss scenarios.
# 0.2035 		 Certification Tests not performed as scheduled.
#
#
# Sentence:             Certification Tests not performed as scheduled.
# Fault type detected:  condition
# Probabilities:
# 0.3097 		 rewrite
# 0.1721 		 not
# 0.5178 		 condition
# 0.0004 		 accident
# Similar Valid Sentences:
# 0.9662 		 Certification Tests not performed as scheduled.
# 0.4013 		 Certification Process implemented is not adequate to identify critical flaws or loss scenarios.
# 0.3811 		 Company doesn’t complete the certification processes.
# 0.2903 		 Design, Product, Quality Management System or Manufacturing Process certified with safety or mission related requirements not verified or not specified.
# 0.2718 		 Mission science data not gathered, returned, or stored.
#
#
# Sentence:             Collision between the ACROBOTER robotic platform and an unknown object (both human or material).
# Fault type detected:  rewrite
# Probabilities:
# 0.7020 		 rewrite
# 0.0159 		 not
# 0.0337 		 condition
# 0.2484 		 accident
# Similar Valid Sentences:
# 0.3519 		 Robot makes contact with a person (directly or indirectly).
# 0.2185 		 Robot makes unintended contact with rocket motor (non-initiation) (e.g. zone A may have lower threshold for “damaging contact”, etc.).
# 0.2071 		 Staff is unexpectedly exposed to radiation.
# 0.1929 		 Doors open when not aligned to platform.
# 0.1849 		 Vehicle (driven by human, automation or in cooperation) leaves the roadway.
#
#
# Sentence:             Collision of a manned and unmanned aircraft.
# Fault type detected:  accident
# Probabilities:
# 0.0119 		 rewrite
# 0.0002 		 not
# 0.0023 		 condition
# 0.9856 		 accident
# Similar Valid Sentences:
# 0.4624 		 Unmanned aircraft testing unnecessarily interferes with flight operations.
# 0.4319 		 Unmanned aircraft loses controlled flight capability.
# 0.4307 		 Loss of UAV airframe integrity.
# 0.3549 		 Uncontrolled aircraft.
# 0.3455 		 UAV departs controlled flight.
#
#
# Sentence:             Collision of an unmanned aircraft with a person on the ground.
# Fault type detected:  accident
# Probabilities:
# 0.0001 		 rewrite
# 0.0000 		 not
# 0.0002 		 condition
# 0.9997 		 accident
# Similar Valid Sentences:
# 0.4786 		 UAV too close to ground/building/person.
# 0.3219 		 Loss of UAV airframe integrity.
# 0.3169 		 Aircraft on the ground comes too close to other objects or leaves the paved area.
# 0.3039 		 Aircraft placed on trajectory or position that intersects with a physical obstruction (e.g., loss of separation, controlled flight into terrain).
# 0.2966 		 Unmanned aircraft testing unnecessarily interferes with flight operations.
#
#
# Sentence:             Collision of an unmanned aircraft with a structure on the ground.
# Fault type detected:  accident
# Probabilities:
# 0.0001 		 rewrite
# 0.0000 		 not
# 0.0005 		 condition
# 0.9994 		 accident
# Similar Valid Sentences:
# 0.3742 		 UAV too close to ground/building/person.
# 0.3491 		 Loss of UAV airframe integrity.
# 0.3474 		 Aircraft placed on trajectory or position that intersects with a physical obstruction (e.g., loss of separation, controlled flight into terrain).
# 0.3230 		 The aircraft loss the communication with base.
# 0.3165 		 Aircraft on the ground comes too close to other objects or leaves the paved area.
#
#
# Sentence:             Collision of two unmanned aircraft.
# Fault type detected:  accident
# Probabilities:
# 0.0018 		 rewrite
# 0.0000 		 not
# 0.0003 		 condition
# 0.9979 		 accident
# Similar Valid Sentences:
# 0.5005 		 Two aircraft violate minimum separation.
# 0.4749 		 Unmanned aircraft testing unnecessarily interferes with flight operations.
# 0.4212 		 Unmanned aircraft loses controlled flight capability.
# 0.3970 		 Loss of UAV airframe integrity.
# 0.3532 		 UAV departs controlled flight.
#
#
# Sentence:             Commitments or obligations are not in line with USCG financial policy.
# Fault type detected:  rewrite
# Probabilities:
# 0.9861 		 rewrite
# 0.0045 		 not
# 0.0093 		 condition
# 0.0002 		 accident
# Similar Valid Sentences:
# 0.3113 		 Production, delivery and/or maintenance commitments are missed.
# 0.2714 		 SMS is not designed according to standards.
# 0.2705 		 SMS is not implemented according to standards.
# 0.2637 		 Nuclear power plant radioactive materials are not contained.
# 0.2527 		 Certification Tests not performed as scheduled.
#
#
# Sentence:             Commitments or obligations are recorded in excess of funding limitations.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.3215 		 Exceeding structure load limits.
# 0.3174 		 Production, delivery and/or maintenance commitments are missed.
# 0.3110 		 System operational limits are exceeded.
# 0.3110 		 Reactor Exceeds Limits.
# 0.2977 		 Equipment Operated Beyond Limits.
#
#
# Sentence:             Contamination of Outer Planet Moon with biological agents of Earth origin on mission hardware.
# Fault type detected:  accident
# Probabilities:
# 0.0002 		 rewrite
# 0.0006 		 not
# 0.0004 		 condition
# 0.9988 		 accident
# Similar Valid Sentences:
# 0.5211 		 Exposure of Earth life or human assets off Earth to toxic, radioactive, or energetic elements of mission hardware.
# 0.5159 		 Exposure of Earth life or human assets on Earth to toxic, radioactive, or energetic elements of mission hardware.
# 0.3967 		 Humans exposed to radiated energy or to toxic, radioactive, or energetic elements of mission hardware.
# 0.3037 		 Non-human, non-system (the satellite) elements exposed to radiated energy or to toxic, radioactive, or energetic elements of mission hardware.
# 0.2815 		 Spacecraft destroyed while landing on planet.
#
#
# Sentence:             Controlled Flight Into Terrain (CFIT).
# Fault type detected:  rewrite
# Probabilities:
# 1.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.3069 		 Aircraft placed on trajectory or position that intersects with a physical obstruction (e.g., loss of separation, controlled flight into terrain).
# 0.2574 		 Flight controls misuse during takeoff run.
# 0.2508 		 Navigation software with feta defects is integrated into navigation system.
# 0.2456 		 Loss of Aircraft Control.
# 0.2368 		 UAV departs controlled flight.
#
#
# Sentence:             Controlled Flight into Terrain.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0001 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.4591 		 Aircraft placed on trajectory or position that intersects with a physical obstruction (e.g., loss of separation, controlled flight into terrain).
# 0.2981 		 Aircraft enters uncontrolled state.
# 0.2938 		 Aircraft enters prohibited area.
# 0.2650 		 Inability of control for intended flight.
# 0.2609 		 Aircraft enters a prohibited area.
#
#
# Sentence:             Controlled flight of aircraft into terrain.
# Fault type detected:  rewrite
# Probabilities:
# 1.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.4928 		 Aircraft placed on trajectory or position that intersects with a physical obstruction (e.g., loss of separation, controlled flight into terrain).
# 0.4609 		 Loss of Aircraft Control.
# 0.4458 		 Lack of aircraft control.
# 0.4367 		 Reduction in control of aircraft.
# 0.3780 		 Inability of control for intended flight.
#
#
# Sentence:             Controlled maneuver into ground.
# Fault type detected:  rewrite
# Probabilities:
# 0.9972 		 rewrite
# 0.0028 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2592 		 Aircraft enters uncontrolled state.
# 0.2524 		 TCAS interferes with the ground-based air traffic control system (e.g., transponder transmissions to the ground or radar or radio services).
# 0.2508 		 Aircraft placed on trajectory or position that intersects with a physical obstruction (e.g., loss of separation, controlled flight into terrain).
# 0.2253 		 Aircraft enters prohibited area.
# 0.2107 		 Inability of control for intended flight.
#
#
# Sentence:             Corrective action (torque to the steering) provided in the wrongdirection, causing a collision.
# Fault type detected:  condition
# Probabilities:
# 0.0006 		 rewrite
# 0.0010 		 not
# 0.9981 		 condition
# 0.0003 		 accident
# Similar Valid Sentences:
# 0.2477 		 WRONG DOSE: Dose delivered to patient is wrong in either amount, location, or timing.
# 0.2008 		 Mistaken flight controls use during rotation.
# 0.1906 		 ACC estimates wrong values of distance and speed of vehicle ahead.
# 0.1795 		 Customer's data misused by JID.
# 0.1736 		 ACC violates the safe distance between ACC vehicle and vehicle in front.
#
#
# Sentence:             Corrective action provided when it isn’t required, resulting in a collision.
# Fault type detected:  condition
# Probabilities:
# 0.0001 		 rewrite
# 0.0001 		 not
# 0.9998 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2426 		 Patient does not receive treatment.
# 0.2420 		 Company doesn’t complete the certification processes.
# 0.2232 		 Certification Tests not performed as scheduled.
# 0.2191 		 A/C not compliant with airworthiness requirements.
# 0.2186 		 Laboratory facilities not appropriated for the current activities.
#
#
# Sentence:             CSCP provides send impedance values command when ITMS is not connected.
# Fault type detected:  condition
# Probabilities:
# 0.0005 		 rewrite
# 0.0003 		 not
# 0.9992 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2951 		 HTV provides unintended attitude control in proximity to SSRMS.
# 0.2136 		 SMS is not designed according to standards.
# 0.2020 		 SMS is not implemented according to standards.
# 0.1990 		 SMS is not effective.
# 0.1959 		 Design, Product, Quality Management System or Manufacturing Process certified with safety or mission related requirements not verified or not specified.
#
#
# Sentence:             Damage to adjacent local infrastructure during Project construction activities.
# Fault type detected:  not
# Probabilities:
# 0.0004 		 rewrite
# 0.9986 		 not
# 0.0010 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2895 		 Materials, tools, infrastructure, or equipment damaged or unavailable to the operator proceed with the laboratory activities.
# 0.2673 		 Certification Process temporally interrupted due to budgetary constraints to the project.
# 0.2313 		 Worker in close proximity to track or car while ride in motion.
# 0.2200 		 Laboratory facilities not appropriated for the current activities.
# 0.2077 		 Inability of other space exploration missions to use shared space exploration infrastructure to collect, return, or use data.
#
#
# Sentence:             Debris from an aircraft impacts another aircraft.
# Fault type detected:  accident
# Probabilities:
# 0.0011 		 rewrite
# 0.0001 		 not
# 0.0006 		 condition
# 0.9982 		 accident
# Similar Valid Sentences:
# 0.5738 		 Aircraft violate minimum separation with other aircraft.
# 0.5398 		 Aircraft violates minimum separation from airspace or other aircraft.
# 0.4167 		 Two aircraft violate minimum separation.
# 0.4083 		 Aircraft on the ground comes too close to other objects or leaves the paved area.
# 0.3267 		 Ship violates minimum separation from other ship.
#
#
# Sentence:             Debris from an unmanned aircraft strikes a person on the ground.
# Fault type detected:  accident
# Probabilities:
# 0.0002 		 rewrite
# 0.0000 		 not
# 0.0001 		 condition
# 0.9997 		 accident
# Similar Valid Sentences:
# 0.3864 		 UAV too close to ground/building/person.
# 0.3030 		 Aircraft on the ground comes too close to other objects or leaves the paved area.
# 0.3024 		 Unmanned aircraft testing unnecessarily interferes with flight operations.
# 0.2825 		 Aircraft placed on trajectory or position that intersects with a physical obstruction (e.g., loss of separation, controlled flight into terrain).
# 0.2793 		 Loss of UAV airframe integrity.
#
#
# Sentence:             Debris from an unmanned aircraft strikes a structure on the ground.
# Fault type detected:  accident
# Probabilities:
# 0.0002 		 rewrite
# 0.0000 		 not
# 0.0003 		 condition
# 0.9995 		 accident
# Similar Valid Sentences:
# 0.3334 		 Unmanned aircraft testing unnecessarily interferes with flight operations.
# 0.3235 		 Aircraft on the ground comes too close to other objects or leaves the paved area.
# 0.3158 		 Aircraft placed on trajectory or position that intersects with a physical obstruction (e.g., loss of separation, controlled flight into terrain).
# 0.3080 		 Loss of UAV airframe integrity.
# 0.2881 		 UAV too close to ground/building/person.
#
#
# Sentence:             Discriminations in the nation.
# Fault type detected:  not
# Probabilities:
# 0.0008 		 rewrite
# 0.9986 		 not
# 0.0001 		 condition
# 0.0004 		 accident
# Similar Valid Sentences:
# 0.4106 		 Social unrest in the nation.
# 0.3977 		 Overwhelming health system in the nation.
# 0.3817 		 Lack of essential supply in the nation.
# 0.2522 		 UAV violates minimum separation requirements.
# 0.2310 		 Food products for sale contain pathogens.
#
#
# Sentence:             Door closes on a person.
# Fault type detected:  accident
# Probabilities:
# 0.1242 		 rewrite
# 0.0191 		 not
# 0.0032 		 condition
# 0.8535 		 accident
# Similar Valid Sentences:
# 0.3829 		 Robot makes contact with a person (directly or indirectly).
# 0.3088 		 Doors stuck open.
# 0.2796 		 UAV too close to ground/building/person.
# 0.2760 		 Person is exposed to harm during testing process.
# 0.2427 		 Doors stuck closed during emergency.
#
#
# Sentence:             Doors close on a person in the doorway.
# Fault type detected:  accident
# Probabilities:
# 0.0059 		 rewrite
# 0.0009 		 not
# 0.0021 		 condition
# 0.9911 		 accident
# Similar Valid Sentences:
# 0.3381 		 Doors stuck open.
# 0.3208 		 Robot makes contact with a person (directly or indirectly).
# 0.2679 		 Doors stuck closed during emergency.
# 0.2491 		 Person is exposed to harm during testing process.
# 0.2347 		 UAV too close to ground/building/person.
#
#
# Sentence:             Doors close while person in the doorway.
# Fault type detected:  accident
# Probabilities:
# 0.0002 		 rewrite
# 0.0002 		 not
# 0.0002 		 condition
# 0.9994 		 accident
# Similar Valid Sentences:
# 0.4023 		 Person is exposed to harm during testing process.
# 0.3859 		 Doors stuck closed during emergency.
# 0.3512 		 Doors stuck open.
# 0.2994 		 Doors open while train is in motion or not aligned with station platform.
# 0.2795 		 Robot makes contact with a person (directly or indirectly).
#
#
# Sentence:             Doors open when the train is moving.
# Fault type detected:  condition
# Probabilities:
# 0.0002 		 rewrite
# 0.0001 		 not
# 0.9976 		 condition
# 0.0021 		 accident
# Similar Valid Sentences:
# 0.6560 		 Doors open when the train is moving or not at platform.
# 0.5173 		 Doors open while train is in motion or not aligned with station platform.
# 0.2872 		 Two trains are on the same “Occlusive Section” travelling at different speed.
# 0.2803 		 Train start with people between train door and PSD.
# 0.2725 		 Doors open when not aligned to platform.
#
#
# Sentence:             Fire spread.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0001 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.3492 		 Uncontrolled fire on board.
# 0.2731 		 Catching fire inside the ship.
# 0.1822 		 Flight controls misuse during takeoff run.
# 0.1579 		 Food products for sale contain pathogens.
# 0.1366 		 Navigation software with feta defects is integrated into navigation system.
#
#
# Sentence:             Flight parameters fall outside of performance limits.
# Fault type detected:  rewrite
# Probabilities:
# 0.9996 		 rewrite
# 0.0003 		 not
# 0.0001 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2491 		 Aircraft violate minimum separation standards in flight.
# 0.2406 		 Vehicle or payload out of flight route.
# 0.2386 		 The aircraft loss the flight capability.
# 0.2320 		 Smart Coaster operated outside of established parameters.
# 0.2229 		 Leaking of project or production documentation.
#
#
# Sentence:             Flooding of contiguous watertight compartments.
# Fault type detected:  rewrite
# Probabilities:
# 1.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2258 		 Cabin parameters incompatible with human survival.
# 0.2130 		 The ship is approaching shallow water.
# 0.1974 		 Catching fire inside the ship.
# 0.1964 		 Ship enters into an unsafe area (low water-depth or stormy area).
# 0.1850 		 Ship violates minimum separation from any stationary object or underwater object.
#
#
# Sentence:             Flying to Close to other aircraft/out of position.
# Fault type detected:  rewrite
# Probabilities:
# 1.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.6080 		 Aircraft violate minimum separation with other aircraft.
# 0.5585 		 Aircraft violates minimum separation from airspace or other aircraft.
# 0.4821 		 Aircraft on the ground comes too close to other objects or leaves the paved area.
# 0.3585 		 Ship violates minimum separation from other ship.
# 0.3315 		 The ship is very close to another ship or object.
#
#
# Sentence:             Gear for wrong direction.
# Fault type detected:  not
# Probabilities:
# 0.0002 		 rewrite
# 0.9996 		 not
# 0.0001 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.3251 		 WRONG DOSE: Dose delivered to patient is wrong in either amount, location, or timing.
# 0.2770 		 ACC estimates wrong values of distance and speed of vehicle ahead.
# 0.2495 		 Simulation acquired is wrong patient, wrong location, wrong iso, or with poor immobilization.
# 0.1709 		 Mistaken flight controls use during rotation.
# 0.1622 		 Operation with degraded equipment (intentional or natural).
#
#
# Sentence:             H2O/Ice (other) Accumulation.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2643 		 Aircraft violate minimum separation with other aircraft.
# 0.2528 		 Ship violates minimum separation from other ship.
# 0.2513 		 Inability of other space exploration missions to use shared space exploration infrastructure to collect, return, or use data.
# 0.2378 		 Human or equipment exposure to cryogen or quench gas.
# 0.2344 		 Aircraft on the ground comes too close to other objects or leaves the paved area.
#
#
# Sentence:             Heat removal and fission clean up fail when the three events—LOCA, S/WP-Ex, or the SIAS—occur.
# Fault type detected:  rewrite
# Probabilities:
# 0.9617 		 rewrite
# 0.0304 		 not
# 0.0076 		 condition
# 0.0003 		 accident
# Similar Valid Sentences:
# 0.3035 		 TCAS interferes with an ATC advisory that is safety-related (e.g., avoiding a restricted area or adverse weather conditions).
# 0.2583 		 TCAS interferes with other safety-related aircraft systems (for example, ground proximity warning).
# 0.2075 		 Reactor Shutdown.
# 0.1954 		 Reactor shut down.
# 0.1914 		 The system process variables violate the minimum safety acceptable standards conditions for energetic materials.
#
#
# Sentence:             High pressure water not contained.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.5010 		 Pressure too high.
# 0.3956 		 Workplace methane levels are not suitable (too high).
# 0.3758 		 Nuclear power plant radioactive materials are not contained.
# 0.3111 		 The ship is approaching shallow water.
# 0.3000 		 Workplace oxygen levels are not suitable (too low).
#
#
# Sentence:             High/Low Air Pressure.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0001 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.4912 		 Pressure too high.
# 0.2949 		 Workplace methane levels are not suitable (too high).
# 0.2940 		 Low fuel level after missed approaches.
# 0.2931 		 Ship enters into an unsafe area (low water-depth or stormy area).
# 0.2928 		 Workplace oxygen levels are not suitable (too low).
#
#
# Sentence:             High/Low Air Temperature.
# Fault type detected:  rewrite
# Probabilities:
# 1.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.3941 		 Reactor temperature too high.
# 0.3216 		 Workplace methane levels are not suitable (too high).
# 0.3118 		 Low fuel level after missed approaches.
# 0.3070 		 Workplace oxygen levels are not suitable (too low).
# 0.2959 		 Pressure too high.
#
#
# Sentence:             Inability of Mission to collect data.
# Fault type detected:  rewrite
# Probabilities:
# 0.9998 		 rewrite
# 0.0001 		 not
# 0.0000 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.5624 		 Inability of Mission scientific investigators to use returned data.
# 0.4254 		 Inability of other space exploration missions to use shared space exploration infrastructure to collect, return, or use data.
# 0.4051 		 ASTRO-H unable to collect scientific data.
# 0.3961 		 Lack of ability of aircraft to receive and transmit the proper data.
# 0.3732 		 Mission science data not gathered, returned, or stored.
#
#
# Sentence:             Inability of Mission to return collected data.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0001 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.7238 		 Inability of Mission scientific investigators to use returned data.
# 0.5545 		 Mission science data not gathered, returned, or stored.
# 0.4864 		 Inability of other space exploration missions to use shared space exploration infrastructure to collect, return, or use data.
# 0.3145 		 ASTRO-H unable to collect scientific data.
# 0.2688 		 Lack of ability of aircraft to receive and transmit the proper data.
#
#
# Sentence:             Inability to pay correctly.
# Fault type detected:  rewrite
# Probabilities:
# 0.9998 		 rewrite
# 0.0001 		 not
# 0.0001 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2840 		 Lack of ability of aircraft to receive and transmit the proper data.
# 0.2587 		 Inability to confirm product integrity.
# 0.2514 		 Inability of companies / organizations to operate normally.
# 0.2505 		 Inability to control the aircraft.
# 0.2319 		 WRONG DOSE: Dose delivered to patient is wrong in either amount, location, or timing.
#
#
# Sentence:             Inability to produce a usable maneuver.
# Fault type detected:  rewrite
# Probabilities:
# 0.9997 		 rewrite
# 0.0002 		 not
# 0.0001 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.1965 		 Plant is unable to produce chemical X.
# 0.1875 		 Engine remains stuck at high thrust during a rejected takeoff.
# 0.1695 		 Unable to dispatch aircraft.
# 0.1556 		 Vehicle is difficult to operate.
# 0.1538 		 Robot makes unintended contact with rocket motor (non-initiation) (e.g. zone A may have lower threshold for “damaging contact”, etc.).
#
#
# Sentence:             Inablity to initiate procurement process.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0001 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.3711 		 Intellectual Property exposed to unauthorized individuals.
# 0.2831 		 Inability to confirm product integrity.
# 0.2582 		 Unauthorized individuals accessing port system infrastructure.
# 0.2449 		 Certification Authority personal, including Organization Designation Authorization (ODA), unqualified to the product in analyse or at the certification process.
# 0.2269 		 Aircraft enters unsafe attitude.
#
#
# Sentence:             Inadequate or unrealized launch facilities maintenance.
# Fault type detected:  rewrite
# Probabilities:
# 1.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2807 		 Uncontrolled aircraft.
# 0.2727 		 Spacecraft has inadequate heat and power.
# 0.2609 		 Staff is unnecessarily exposed to radiation.
# 0.2499 		 Uncontrolled fire on board.
# 0.2343 		 Uncontrolled flight over congested area.
#
#
# Sentence:             Inadvertent Equip. Operation During Maintenance.
# Fault type detected:  condition
# Probabilities:
# 0.0002 		 rewrite
# 0.0002 		 not
# 0.9995 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.3152 		 Doors stuck closed during emergency.
# 0.2973 		 Operation with degraded equipment (intentional or natural).
# 0.2861 		 Rider unsecure during ride operations.
# 0.2532 		 AV activates without request during autonomous maneuver.
# 0.2494 		 Excavator within the vicinity of overhead electric lines.
#
#
# Sentence:             Inappropriate Air Transport (bleed and distribution).
# Fault type detected:  rewrite
# Probabilities:
# 0.9995 		 rewrite
# 0.0005 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.3133 		 Patient receives inappropriate treatment.
# 0.2748 		 Lack of ability of aircraft to receive and transmit the proper data.
# 0.2405 		 Unable to dispatch aircraft.
# 0.2347 		 Aircraft airframe integrity is degraded.
# 0.2241 		 Loss of airframe integrity.
#
#
# Sentence:             Interference with ATC safety-related advisory.
# Fault type detected:  rewrite
# Probabilities:
# 0.9938 		 rewrite
# 0.0061 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.5113 		 TCAS interferes with an ATC advisory that is safety-related (e.g., avoiding a restricted area or adverse weather conditions).
# 0.4277 		 SGC system operates under abnormal conditions.
# 0.2629 		 TCAS interferes with other safety-related aircraft systems (for example, ground proximity warning).
# 0.2417 		 SGC system continues to supply gas when gas leaks to the environment.
# 0.1973 		 SGC system cannot produce gas with maximum capacity.
#
#
# Sentence:             Interference with other safety-related aircraft systems.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0001 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.6211 		 TCAS interferes with other safety-related aircraft systems (for example, ground proximity warning).
# 0.5631 		 Aircraft violate minimum separation with other aircraft.
# 0.4338 		 Aircraft violates minimum separation from airspace or other aircraft.
# 0.3399 		 Aircraft on the ground comes too close to other objects or leaves the paved area.
# 0.3195 		 Ship violates minimum separation from other ship.
#
#
# Sentence:             Interference with the ground-based ATC system.
# Fault type detected:  rewrite
# Probabilities:
# 0.9998 		 rewrite
# 0.0001 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.5007 		 SGC system operates under abnormal conditions.
# 0.3827 		 SGC system continues to supply gas when gas leaks to the environment.
# 0.3579 		 TCAS interferes with the ground-based air traffic control system (e.g., transponder transmissions to the ground or radar or radio services).
# 0.3018 		 TCAS interferes with an ATC advisory that is safety-related (e.g., avoiding a restricted area or adverse weather conditions).
# 0.2964 		 SGC system cannot produce gas with maximum capacity.
#
#
# Sentence:             Laboratory ecosystem stakeholders including patients (the public) lose trust in data being collected, shared, analyzed, and reported.
# Fault type detected:  not
# Probabilities:
# 0.0015 		 rewrite
# 0.9981 		 not
# 0.0003 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.3197 		 Customer's data released to public.
# 0.2977 		 System reports fake patient’s results to the user.
# 0.2965 		 Patient info disclosed to unauthorized parties.
# 0.2866 		 Inability of Mission scientific investigators to use returned data.
# 0.2862 		 Inability of other space exploration missions to use shared space exploration infrastructure to collect, return, or use data.
#
#
# Sentence:             Land acquisition is not completed when required to be handed over to construction contractors for start of Project construction activities.
# Fault type detected:  condition
# Probabilities:
# 0.0107 		 rewrite
# 0.0044 		 not
# 0.9848 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.3053 		 Laboratory facilities not appropriated for the current activities.
# 0.2884 		 System is not ready to fulfill designited mission.
# 0.2799 		 Leaking of project or production documentation.
# 0.2783 		 Certification Process temporally interrupted due to budgetary constraints to the project.
# 0.2612 		 Company doesn’t complete the certification processes.
#
#
# Sentence:             Late or no decision to abort.
# Fault type detected:  rewrite
# Probabilities:
# 0.9827 		 rewrite
# 0.0023 		 not
# 0.0136 		 condition
# 0.0014 		 accident
# Similar Valid Sentences:
# 0.1602 		 Aircraft does not stop before the runway end.
# 0.1446 		 Engine remains stuck at high thrust during a rejected takeoff.
# 0.1418 		 AV activates without request during autonomous maneuver.
# 0.1297 		 Passengers evacuate when no emergency.
# 0.1282 		 Doors open when not aligned to platform.
#
#
# Sentence:             Level too high.
# Fault type detected:  rewrite
# Probabilities:
# 0.9949 		 rewrite
# 0.0046 		 not
# 0.0001 		 condition
# 0.0004 		 accident
# Similar Valid Sentences:
# 0.5378 		 Pressure too high.
# 0.5299 		 Workplace methane levels are not suitable (too high).
# 0.4907 		 Reactor temperature too high.
# 0.4564 		 Workplace oxygen levels are not suitable (too low).
# 0.3138 		 Systems or equipment are exposed to excessive levels of hazardous energy.
#
#
# Sentence:             LLIs are not available when required to be used by construction contractors in the Project construction activities.
# Fault type detected:  condition
# Probabilities:
# 0.0005 		 rewrite
# 0.0004 		 not
# 0.9990 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.3422 		 Laboratory facilities not appropriated for the current activities.
# 0.2839 		 Nuclear power plant radioactive materials are not contained.
# 0.2674 		 Leaking of project or production documentation.
# 0.2504 		 Materials, tools, infrastructure, or equipment damaged or unavailable to the operator proceed with the laboratory activities.
# 0.2501 		 Laboratorial Equipment or Energetic Materials are not adequately identified and stored.
#
#
# Sentence:             Loss of control or communications.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.5616 		 Loss of Aircraft Control.
# 0.5234 		 Lack of aircraft control.
# 0.3981 		 Reduction in control of aircraft.
# 0.3881 		 AV loses control.
# 0.3840 		 Inability of control for intended flight.
#
#
# Sentence:             Low fuel level after missed approaches.
# Fault type detected:  rewrite
# Probabilities:
# 0.9996 		 rewrite
# 0.0002 		 not
# 0.0001 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.9610 		 Low fuel level after missed approaches.
# 0.2401 		 Engine remains stuck at high thrust during a rejected takeoff.
# 0.2092 		 Workplace oxygen levels are not suitable (too low).
# 0.2052 		 Violating a minimum of separation between vehicles and between vehicles and objects.
# 0.1978 		 The ship is approaching shallow water.
#
#
# Sentence:             Maintenance of pressure in a main control room fails when the two events—High-level radioactive at air intakes of MCR or the SIAS—occur.
# Fault type detected:  not
# Probabilities:
# 0.0004 		 rewrite
# 0.9989 		 not
# 0.0007 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2286 		 TCAS interferes with an ATC advisory that is safety-related (e.g., avoiding a restricted area or adverse weather conditions).
# 0.2275 		 TCAS interferes with the ground-based air traffic control system (e.g., transponder transmissions to the ground or radar or radio services).
# 0.2271 		 Plant releases radioactive material.
# 0.2206 		 Engine remains stuck at high thrust during a rejected takeoff.
# 0.2054 		 TCAS interferes with other safety-related aircraft systems (for example, ground proximity warning).
#
#
# Sentence:             Major Fire and/ or Explosion during Project commissioning activities.
# Fault type detected:  condition
# Probabilities:
# 0.0001 		 rewrite
# 0.0003 		 not
# 0.9996 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2464 		 Leaking of project or production documentation.
# 0.2364 		 Certification Process temporally interrupted due to budgetary constraints to the project.
# 0.2060 		 Robot creates conditions that are not suitable for segment (e.g. ignites segment, high heat, fire, sparking, etc.).
# 0.1974 		 Catching fire inside the ship.
# 0.1950 		 Exceeding structure load limits.
#
#
# Sentence:             Msn critical systems not functional when required.
# Fault type detected:  condition
# Probabilities:
# 0.0846 		 rewrite
# 0.0024 		 not
# 0.9129 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.3400 		 Design, Product, Quality Management System or Manufacturing Process certified with safety or mission related requirements not verified or not specified.
# 0.3289 		 Certification Process implemented is not adequate to identify critical flaws or loss scenarios.
# 0.2837 		 System is not ready to fulfill designited mission.
# 0.2768 		 SMS is not implemented according to standards.
# 0.2734 		 SMS is not designed according to standards.
#
#
# Sentence:             Near mid-air collision (NMAC): Two controlled aircraft violate minimum separation standards).
# Fault type detected:  rewrite
# Probabilities:
# 0.9996 		 rewrite
# ...
# 0.2802 		 The train exceeds speed limit on tie line.
# 0.2744 		 Doors open when the train is moving or not at platform.
# 0.2594 		 The train exceeds speed limit of switch P10.
#
#
# Sentence:             UAV does not complete mission.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.4628 		 UAV departs controlled flight.
# 0.4594 		 UAV violates minimum separation requirements.
# 0.4206 		 Loss of UAV airframe integrity.
# 0.3841 		 Unmanned aircraft loses controlled flight capability.
# 0.3425 		 UAV too close to ground/building/person.
#
#
# Sentence:             Unable to evade enemy threats.
# Fault type detected:  rewrite
# Probabilities:
# 0.9997 		 rewrite
# 0.0002 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.1998 		 Equipment subject to unnecessary stress.
# 0.1930 		 Equipment is subject to unexpected stress.
# 0.1845 		 Human exposure to loud noise.
# 0.1775 		 Intellectual Property exposed to unauthorized individuals.
# 0.1756 		 Smartgrid has an inability to meet unexpected demands.
#
#
# Sentence:             Unacceptable Air Contamination.
# Fault type detected:  rewrite
# Probabilities:
# 0.9998 		 rewrite
# 0.0002 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.3318 		 Aircraft enters unsafe atmospheric region.
# 0.3293 		 Loss of airframe integrity.
# 0.3266 		 Aircraft airframe integrity is degraded.
# 0.3187 		 Aircraft enters an unsafe atmospheric region.
# 0.2867 		 Plant releases toxic chemicals (e.g. to air, ground, etc.).
#
#
# Sentence:             Unauthorized access to hospital/patient information.
# Fault type detected:  rewrite
# Probabilities:
# 0.9955 		 rewrite
# 0.0040 		 not
# 0.0005 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.9391 		 Unauthorized access to hospital/patient information.
# 0.6647 		 Patient info disclosed to unauthorized parties.
# 0.3509 		 Unauthorized individuals accessing port system infrastructure.
# 0.3239 		 Intellectual Property exposed to unauthorized individuals.
# 0.3024 		 System reports fake patient’s results to the user.
#
#
# Sentence:             Unauthorized user is allowed through.
# Fault type detected:  rewrite
# Probabilities:
# 0.9998 		 rewrite
# 0.0002 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.3426 		 Mission critical information is exposed to unauthorized person.
# 0.3190 		 Customer's data misused by authorized 3rd parties.
# 0.3182 		 Patient info disclosed to unauthorized parties.
# 0.2995 		 Unauthorized individuals accessing port system infrastructure.
# 0.2886 		 Unauthorized access to hospital/patient information.
#
#
# Sentence:             Unauthorized/unconsented disclosure/release of PII/PD.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0001 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.5260 		 Consumer (rider) PII exposed to unauthorized individuals.
# 0.4230 		 Patient info disclosed to unauthorized parties.
# 0.3008 		 Uncontrolled aircraft.
# 0.2952 		 Customer's data released to unauthorized 3rd parties.
# 0.2852 		 Leak of sensitive information.
#
#
# Sentence:             Uncontrolled aircraft.
# Fault type detected:  rewrite
# Probabilities:
# 1.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.9484 		 Uncontrolled aircraft.
# 0.7529 		 Aircraft enters uncontrolled state.
# 0.6561 		 Uncontrolled flight over congested area.
# 0.6065 		 Uncontrolled fire on board.
# 0.5025 		 Unmanned aircraft loses controlled flight capability.
#
#
# Sentence:             Uncontrolled release of toxic chemicals.
# Fault type detected:  rewrite
# Probabilities:
# 0.9997 		 rewrite
# 0.0003 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.5614 		 Uncontrolled aircraft.
# 0.4856 		 Uncontrolled fire on board.
# 0.4251 		 Uncontrolled flight over congested area.
# 0.4114 		 Aircraft enters uncontrolled state.
# 0.3964 		 Vehicle enters uncontrollable or unrecoverable state.
#
#
# Sentence:             Uncoordinated implementation of inspection procedures.
# Fault type detected:  rewrite
# Probabilities:
# 0.9995 		 rewrite
# 0.0002 		 not
# 0.0003 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.3628 		 Uncontrolled aircraft.
# 0.3440 		 Uncontrolled fire on board.
# 0.3373 		 Unmanned aircraft testing unnecessarily interferes with flight operations.
# 0.3188 		 Uncontrolled flight over congested area.
# 0.2989 		 Non-patient (esp. personnel) is unnecessarily exposed to radiation.
#
#
# Sentence:             Unintended Change of Direction.
# Fault type detected:  rewrite
# Probabilities:
# 1.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2826 		 Uncontrolled fire on board.
# 0.2762 		 Uncontrolled aircraft.
# 0.2631 		 Maneuvering the aircraft outside the safety envelope (undesired aircraft state).
# 0.2568 		 Unmanned aircraft testing unnecessarily interferes with flight operations.
# 0.2552 		 HTV provides unintended attitude control in proximity to SSRMS.
#
#
# Sentence:             Unintended Park Disengagement.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0001 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.3328 		 The vehicle parks inappropriately, either in an unsuitable space (e.g. blocking a fire hydrant) or in violation of parking guidelines (e.g. excessively far from the curb).
# 0.3230 		 Unmanned aircraft testing unnecessarily interferes with flight operations.
# 0.2735 		 HTV is drifting to ISS while uncontrolled (deactivated).
# 0.2731 		 Uncontrolled flight over congested area.
# 0.2691 		 Robot makes unintended contact with rocket motor (non-initiation) (e.g. zone A may have lower threshold for “damaging contact”, etc.).
#
#
# Sentence:             Unintended Propulsion.
# Fault type detected:  rewrite
# Probabilities:
# 1.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.4037 		 Unmanned aircraft testing unnecessarily interferes with flight operations.
# 0.3817 		 Uncontrolled aircraft.
# 0.3475 		 Uncontrolled fire on board.
# 0.3071 		 Vehicle enters uncontrollable or unrecoverable state.
# 0.3012 		 Robot makes unintended contact with rocket motor (non-initiation) (e.g. zone A may have lower threshold for “damaging contact”, etc.).
#
#
# Sentence:             Unsafe separation from other flying objects during controlled flight.
# Fault type detected:  rewrite
# Probabilities:
# 0.9996 		 rewrite
# 0.0000 		 not
# 0.0002 		 condition
# 0.0002 		 accident
# Similar Valid Sentences:
# 0.4909 		 Aircraft violate minimum separation with other aircraft.
# 0.4443 		 Aircraft violates minimum separation from airspace or other aircraft.
# 0.3999 		 Ship violates minimum separation from other ship.
# 0.3715 		 Flight controls misuse during takeoff run.
# 0.3589 		 Aircraft on the ground comes too close to other objects or leaves the paved area.
#
#
# Sentence:             Unsafe separation from terrain / objects on ground during controlled flight.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.4097 		 Aircraft placed on trajectory or position that intersects with a physical obstruction (e.g., loss of separation, controlled flight into terrain).
# 0.3224 		 Aircraft on the ground comes too close to other objects or leaves the paved area.
# 0.2986 		 Flight controls misuse during takeoff run.
# 0.2815 		 Vehicle does not maintain safe distance from terrain and other obstacles.
# 0.2604 		 Vehicle does not maintain safe distance from nearby objects.
#
#
# Sentence:             Unwanted or Excessive Lateral Motion.
# Fault type detected:  rewrite
# Probabilities:
# 1.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.3758 		 Vehicle exceeds safe operating envelope for environment (speed, lateral/longitudinal forces).
# 0.3154 		 Vehicle equipment operated beyond limits (experience excessive wear and tear).
# 0.2534 		 Satellite hardware exposed to excessive radiation, or caustic or energetic materials.
# 0.2514 		 Equipment subject to unnecessary stress.
# 0.2435 		 Equipment under unnecessary stress.
#
#
# Sentence:             Unwanted or Excessive Negative Longitudinal Motion.
# Fault type detected:  rewrite
# Probabilities:
# 0.9996 		 rewrite
# 0.0004 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2751 		 Vehicle equipment operated beyond limits (experience excessive wear and tear).
# 0.2427 		 Vehicle exceeds safe operating envelope for environment (speed, lateral/longitudinal forces).
# 0.1875 		 Oil well without control over liquid flows.
# 0.1787 		 Satellite hardware exposed to excessive radiation, or caustic or energetic materials.
# 0.1677 		 Equipment Operated Beyond Limits.
#
#
# Sentence:             Unwanted or Excessive Positive Longitudinal Motion.
# Fault type detected:  rewrite
# Probabilities:
# 0.9974 		 rewrite
# 0.0026 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2877 		 Vehicle equipment operated beyond limits (experience excessive wear and tear).
# 0.2732 		 Vehicle exceeds safe operating envelope for environment (speed, lateral/longitudinal forces).
# 0.1939 		 Satellite hardware exposed to excessive radiation, or caustic or energetic materials.
# 0.1848 		 The vehicle parks inappropriately, either in an unsuitable space (e.g. blocking a fire hydrant) or in violation of parking guidelines (e.g. excessively far from the curb).
# 0.1732 		 Pressure too high.
#
#
# Sentence:             USCG contracts are executed prior to sufficient funds being appropriated or committed.
# Fault type detected:  rewrite
# Probabilities:
# 0.9998 		 rewrite
# 0.0002 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2467 		 Production, delivery and/or maintenance commitments are missed.
# 0.2229 		 Patient tissues receive more dose than clinically desirable.
# 0.2181 		 Certification Process temporally interrupted due to budgetary constraints to the project.
# 0.2058 		 Patient tumor receives less dose than clinically desirable.
# 0.2049 		 Laboratory facilities not appropriated for the current activities.
#
#
# Sentence:             Vehicle Roll Away from Not Engaging Park.
# Fault type detected:  not
# Probabilities:
# 0.0003 		 rewrite
# 0.9995 		 not
# 0.0002 		 condition
# 0.0001 		 accident
# Similar Valid Sentences:
# 0.4502 		 Vehicle does not maintain safe distance from nearby vehicles.
# 0.4093 		 Vehicle does not maintain safe distance from nearby objects.
# 0.3767 		 Vehicles do not maintain safe distance from each other.
# 0.3545 		 The vehicle parks inappropriately, either in an unsuitable space (e.g. blocking a fire hydrant) or in violation of parking guidelines (e.g. excessively far from the curb).
# 0.3471 		 Vehicle does not maintain safe distance from terrain and other obstacles.
#
#
# Sentence:             Violating separation from other aircraft, terrain, obstacles.
# Fault type detected:  rewrite
# Probabilities:
# 0.9997 		 rewrite
# 0.0000 		 not
# 0.0003 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.6308 		 Aircraft violates minimum separation from airspace or other aircraft.
# 0.6191 		 Aircraft violate minimum separation with other aircraft.
# 0.5901 		 Vehicle does not maintain safe distance from terrain and other obstacles.
# 0.4834 		 Ship violates minimum separation from other ship.
# 0.4158 		 Aircraft on the ground comes too close to other objects or leaves the paved area.
#
#
# Sentence:             Violation of Altitude/clear ance from terrain.
# Fault type detected:  rewrite
# Probabilities:
# 1.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2481 		 Aircraft placed on trajectory or position that intersects with a physical obstruction (e.g., loss of separation, controlled flight into terrain).
# 0.2104 		 Vehicle does not maintain safe distance from terrain and other obstacles.
# 0.1573 		 Aircraft placed on trajectory that intersects with dangerous atmospheric conditions (e.g., storms, volcanic ash).
# 0.1353 		 Rider unsecure during ride operations.
# 0.1302 		 Excavator within the vicinity of overhead electric lines.
#
#
# Sentence:             Violation of minimum distance to other aircraft.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0000 		 not
# 0.0001 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.7596 		 Aircraft violate minimum separation with other aircraft.
# 0.6808 		 Aircraft violates minimum separation from airspace or other aircraft.
# 0.5087 		 Ship violates minimum separation from other ship.
# 0.4392 		 Aircraft on the ground comes too close to other objects or leaves the paved area.
# 0.4145 		 The aircraft violates the minimum safety distance.
#
#
# Sentence:             Violation of minimum separation requirements.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0000 		 not
# 0.0001 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.4990 		 UAV violates minimum separation requirements.
# 0.4327 		 Violating a minimum of separation between vehicles and between vehicles and objects.
# 0.3997 		 Aircraft violate minimum separation standards in flight.
# 0.3359 		 Two aircraft violate minimum separation.
# 0.3153 		 Ship violates minimum separation from any stationary object or underwater object.
#
#
# Sentence:             Violation of minimum separation standards.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0000 		 not
# 0.0001 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.5868 		 Aircraft violate minimum separation standards in flight.
# 0.4575 		 Violating a minimum of separation between vehicles and between vehicles and objects.
# 0.4206 		 Patients receive less than the acceptable standard of care.
# 0.3708 		 The aircraft violates the minimum safety distance.
# 0.3562 		 The system process variables violate the minimum safety acceptable standards conditions for energetic materials.
#
#
# Sentence:             Violation of minimum/maximum altitude.
# Fault type detected:  rewrite
# Probabilities:
# 1.0000 		 rewrite
# 0.0000 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.2767 		 UAV violates minimum separation requirements.
# 0.2698 		 The aircraft violates the minimum safety distance.
# 0.2610 		 Ship violates minimum separation from any stationary object or underwater object.
# 0.2547 		 Violating a minimum of separation between vehicles and between vehicles and objects.
# 0.2268 		 Aircraft violates minimum separation from airspace or other aircraft.
#
#
# Sentence:             When passengers get on or off, the door is closed.
# Fault type detected:  accident
# Probabilities:
# 0.0010 		 rewrite
# 0.0001 		 not
# 0.0005 		 condition
# 0.9984 		 accident
# Similar Valid Sentences:
# 0.4125 		 Passengers evacuate when no emergency.
# 0.3571 		 Passengers fail to evacuate when emergency.
# 0.2796 		 Doors stuck open.
# 0.2652 		 Doors open when the train is moving or not at platform.
# 0.2468 		 Plant is shut down.
#
#
# Sentence:             Wrong dose, location, or patient.
# Fault type detected:  rewrite
# Probabilities:
# 0.9994 		 rewrite
# 0.0002 		 not
# 0.0004 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.7650 		 WRONG DOSE: Dose delivered to patient is wrong in either amount, location, or timing.
# 0.4828 		 Simulation acquired is wrong patient, wrong location, wrong iso, or with poor immobilization.
# 0.3910 		 Patient receives inappropriate treatment.
# 0.3408 		 Unauthorized access to hospital/patient information.
# 0.3402 		 Patient tumor receives less dose than clinically desirable.
#
#
# Sentence:             Wrong radiation delivered.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0001 		 not
# 0.0000 		 condition
# 0.0000 		 accident
# Similar Valid Sentences:
# 0.4206 		 WRONG DOSE: Dose delivered to patient is wrong in either amount, location, or timing.
# 0.3905 		 Staff is unexpectedly exposed to radiation.
# 0.3347 		 Non-patient receives radiation.
# 0.3340 		 Staff is unnecessarily exposed to radiation.
# 0.3154 		 NON-PATIENT IS UNNECESSARILY EXPOSED TO RADIATION.

# %%
# print Constraint results

print('########### CONSTRAINT')
print('Valid Sentences:')
print(list_valid_constraint)
print('\n')
print('Invalid Sentences:')
print_invalid(list_dict_faults_constraint, list_similar_constraint)
# Out:
# ########### CONSTRAINT
# Valid Sentences:
# ['A collision between the ACROBOTER robotic platform and an unknown object must be avoided at all times.', 'A/C must maintain minimum safe altitude limits.', 'A/C must maintain minimum safe separation distance.', 'ACC must not brake too abruptly.', 'ACC must not violate separation requirements with object ahead.', 'ACC should not brake too abruptly.', 'ACC should not let the vehicle gets in contact with the object ahead.', 'ACS must not continue providing attitude maneuver commands too long after attitude has stabilized.', 'ACS must not provide attitude maneuver commands in the same direction as rotation.', 'ACS must not provide attitude maneuver commands too early to achieve desired attitude.', 'ACS must not provide attitude maneuver commands too late after ASTRO-H has rotated too far.', 'ACS must not provide attitude maneuver commands when ASTRO-H is not rotating.', 'ACS must not stop providing attitude commands too soon before attitude has stabilized.', 'ACS must provide attitude maneuver commands that are sufficient to slow ASTRO-H quickly.', 'ACS must provide attitude maneuver commands when ASTRO-H is rotating.', 'Actuator (Throttle, Spark, Fuel, etc.) Control shall be synchronized with axle torque request.', 'After rotation, the skid angle must be reduced to keep wings leveled.', 'Aircraft component must not be powered up when hazardous FLS is installed.', 'Aircraft must maintain criteria for stable approaches.', 'Aircraft must maintain its control and maintain airframe integrity.', 'Aircraft must maintain separation with ground or obstacles on ground.', 'Aircraft must maintain separation with other aircraft.', 'Aircraft must not be operated when hazardous FLS is installed.', 'Aircraft must not enter a runway without clearance.', 'Aircraft on ground must maintain separation with other objects and must not leave the paved area.', 'Aircraft shall be capable of remaining airborn in a controlled manner throughout the operation.', 'Aircraft shall not enter a controlled airspace without broadcasting their location through Mode C, ADS-B, or IFF.', 'Aircraft shall not enter a controlled airspace without verbal confirmation from the controller.', 'Aircraft should maintain a safe distance from obstacles and notify the operator when reaching the minimum distance.', 'Airframe integrity must not be lost during flight.', 'All inspection procedures must be coordinated between implementers.', 'All the safety/mission critical military aerospace designs and products shall be Certified to allow use or operation.', 'An abnormal termination instruction must be given immediately if an abort is required.', 'An abnormal termination instruction must be given when continuing the ITP would be unsafe.', 'An abnormal termination instruction must not be given when it is not required to maintain safety and would result in a loss of separation.', 'An emergency shall stop the train, Doors shall open in an emergency after the train has stopped.', 'Approval must be given to the requesting aircraft only.', 'Approval must not be given too early or too late (needs to be clarified as to the actual time limits).', 'Approval of an ITP request must be given only when the ITP criteria are met.', 'At the launch rail, vehicle stages must be prevented from igniting before planned, even when subjected to commands or electric discharges.', 'Autopilot must send objects to Autopilot HMI when required.', 'Autopilot must send road signs to Autopilot HMI when required.', 'AV must adhere to the allowed operating limits advised by the traffic rules and ODD limitations.', 'AV must adhere to the designated path.', 'AV must maintain a safe distance from VRUs and other stationary and moving objects in the surroundings.', 'AV must never lose control.', 'AV must provide a comfortable experience to the passengers when driving or stationary.', 'Brake light command must illuminate early within X-seconds before stopping vehicle.', 'Chemical plant must not release toxic chemicals into  ...
#
#
# Invalid Sentences:
# Sentence:             A storage method for using chemicals, such as FIFO (First-In, First-Out), should be adopted.
# Fault type detected:  rewrite
# Probabilities:
# 0.9997 		 rewrite
# 0.0003 		 not
# Similar Valid Sentences:
# 0.2345 		 The FI must assist the trainee in enforcing these safety constraints.
# 0.2112 		 Follow-up must be provided to ensure that recommendations have been implemented and are effective.
# 0.2049 		 Path panning must include the ability to pass through an intersection in movement calculation before moving forward into an intersection.
# 0.1986 		 The certification process shall be continuously updated, allowing improvement of the procedures and regulations.
# 0.1970 		 Energetic materials must be used as prescribed.
#
#
# Sentence:             Aircraft must be dispatched.
# Fault type detected:  rewrite
# Probabilities:
# 0.9994 		 rewrite
# 0.0006 		 not
# Similar Valid Sentences:
# 0.4210 		 Approval must be given to the requesting aircraft only.
# 0.3727 		 Aircraft must maintain separation with other aircraft.
# 0.3604 		 The aircraft must be maneuvered within the safety envelope.
# 0.3549 		 Aircraft must not be operated when hazardous FLS is installed.
# 0.3521 		 Aircraft component must not be powered up when hazardous FLS is installed.
#
#
# Sentence:             Avoid operation beyond the permissible limits (emergency cases are excluded).
# Fault type detected:  not
# Probabilities:
# 0.0000 		 rewrite
# 1.0000 		 not
# Similar Valid Sentences:
# 0.2709 		 Pilots must not stop maneuver before reaching designated altitude (except in emergency temination).
# 0.2251 		 ACC must not violate separation requirements with object ahead.
# 0.2238 		 An emergency shall stop the train, Doors shall open in an emergency after the train has stopped.
# 0.1919 		 IPMS must not sent STOP command unless an emergency condition is indicated.
# 0.1898 		 In case of budget restriction is unavoidable, the company management shall prioritize the activities without compromising safety or performance aspects.
#
#
# Sentence:             Avoiding the concurrence of flammable substances, oxidizer and ignition source.
# Fault type detected:  not
# Probabilities:
# 0.0001 		 rewrite
# 0.9999 		 not
# Similar Valid Sentences:
# 0.2243 		 Heat and smoke detectors should trigger an alarm and extinguishing systems.
# 0.2007 		 Operational laboratory trainings must approach the safety constraints and guidelines on handling Energetic Materials.
# 0.1941 		 The owner of a certificate product shall maintain the system safety and the manufacturing according to the design approved to avoid the certificate to be cancelled.
# 0.1816 		 The owner of a certificate product shall be aware of the expiration date, if applicable, and provide the necessary documentation to avoid its expiration.
# 0.1755 		 Operators must conclude operational laboratory training for handling Energetic Materials.
#
#
# Sentence:             Avoiding the interaction of flammable substances, oxidizer and ignition source.
# Fault type detected:  not
# Probabilities:
# 0.0001 		 rewrite
# 0.9999 		 not
# Similar Valid Sentences:
# 0.2684 		 Operational laboratory trainings must approach the safety constraints and guidelines on handling Energetic Materials.
# 0.2645 		 Heat and smoke detectors should trigger an alarm and extinguishing systems.
# 0.2266 		 Operators must conclude operational laboratory training for handling Energetic Materials.
# 0.2116 		 Satellite must not operate in an environment that poses the risk of excessive radiation or impact from energetic materials.
# 0.1974 		 System shall be able to control the actuator (Throttle, Spark, Fuel, etc.), when required.
#
#
# Sentence:             Brakes cannot be applied severely when aborting with strong crosswind.
# Fault type detected:  not
# Probabilities:
# 0.0002 		 rewrite
# 0.9998 		 not
# Similar Valid Sentences:
# 0.2783 		 Yawing at brakes release must be counteracted quickly.
# 0.2238 		 ACC must not brake too abruptly.
# 0.2234 		 Side stick command should be applied to the side of the wind after releasing the brakes.
# 0.2051 		 When the bursting of a tire at high speed is suspected and the pilot decides to continue, the landing gear must not be retracted.
# 0.1937 		 ACC should not brake too abruptly.
#
#
# Sentence:             Crossing runways only when runway is not used for take off / landing.
# Fault type detected:  not
# Probabilities:
# 0.0002 		 rewrite
# 0.9998 		 not
# Similar Valid Sentences:
# 0.4176 		 Aircraft must not enter a runway without clearance.
# 0.2572 		 Controller shall not open Door while train is moving, only when stopped.
# 0.2386 		 Pilot must not perform ITP when criteria are not met or request has been refused.
# 0.2301 		 The aircraft must never fly off the route specified at the flight plan.
# 0.2244 		 Aircraft on ground must maintain separation with other objects and must not leave the paved area.
#
#
# Sentence:             Ensure the correct communication with the IS to activate the pre-flight event.
# Fault type detected:  not
# Probabilities:
# 0.0004 		 rewrite
# 0.9996 		 not
# Similar Valid Sentences:
# 0.3313 		 The aircraft must maintain constant communication with the base throughout the operation.
# 0.2861 		 Pilot must execute maneuver once it is approved.
# 0.2733 		 The flight crew must execute the ITP immediately when approved unless it would be dangerous to do so.
# 0.2722 		 The flight crew must never violate predetermined minimum/maximum altitude.
# 0.2708 		 The flight crew must execute the ITP with correct climb rate, flight levels, Mach number, and other associated performance criteria.
#
#
# Sentence:             Maintenance and construction of infrastructure only when infrastructure is blocked.
# Fault type detected:  not
# Probabilities:
# 0.0001 		 rewrite
# 0.9999 		 not
# Similar Valid Sentences:
# 0.2699 		 Controller shall not open Door while train is moving, only when stopped.
# 0.2612 		 Approval of an ITP request must be given only when the ITP criteria are met.
# 0.2586 		 Doors shall open at station when train is completely stopped and aligned with platform.
# 0.2497 		 Doors must not be opened until train is stopped and aligned with platform.
# 0.2298 		 Controller shall open Door when Train is stopped in Station.
#
#
# Sentence:             Must have minimum mission critical safety systems functional for terrain flight.
# Fault type detected:  rewrite
# Probabilities:
# 1.0000 		 rewrite
# 0.0000 		 not
# Similar Valid Sentences:
# 0.3744 		 Msn critical systems must be available when required to perform primary msn.
# 0.3650 		 A/C must maintain minimum safe altitude limits.
# 0.3569 		 The certification process shall allow verification of all safety critical or performance requirements and also the system functions.
# 0.3397 		 Satellite must maintain means of transmitting science data to supporting systems.
# 0.3298 		 Satellite must maintain means of communication with supporting systems.
#
#
# Sentence:             Must have minimum mission critical safety systems functional to attempt AR.
# Fault type detected:  rewrite
# Probabilities:
# 1.0000 		 rewrite
# 0.0000 		 not
# Similar Valid Sentences:
# 0.3635 		 Msn critical systems must be available when required to perform primary msn.
# 0.3461 		 A/C must maintain minimum safe altitude limits.
# 0.3287 		 The certification process shall allow verification of all safety critical or performance requirements and also the system functions.
# 0.3018 		 All the safety/mission critical military aerospace designs and products shall be Certified to allow use or operation.
# 0.2842 		 Satellite must maintain means of transmitting science data to supporting systems.
#
#
# Sentence:             Must maintain integrity of mission critical warning and deterrence systems.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0001 		 not
# Similar Valid Sentences:
# 0.4713 		 Satellite must maintain means of communication with supporting systems.
# 0.4660 		 Msn critical systems must be available when required to perform primary msn.
# 0.4355 		 Satellite must maintain means of transmitting science data to supporting systems.
# 0.4037 		 The certification process shall allow verification of all safety critical or performance requirements and also the system functions.
# 0.3820 		 Aircraft must maintain criteria for stable approaches.
#
#
# Sentence:             No relevant function shall be lost when not required.
# Fault type detected:  rewrite
# Probabilities:
# 0.9981 		 rewrite
# 0.0019 		 not
# Similar Valid Sentences:
# 0.3233 		 An abnormal termination instruction must not be given when it is not required to maintain safety and would result in a loss of separation.
# 0.2873 		 The products shall be in conformity with the design. If it’s not, it shall not be used or operated.
# 0.2759 		 In case of budget restriction is unavoidable, the company management shall prioritize the activities without compromising safety or performance aspects.
# 0.2366 		 When the Train is stopped and not in a station and no emergency exists the Controller shall not open the door.
# 0.2158 		 Food products with pathogens must not be sold.
#
#
# Sentence:             Take off / landing executed only when runway is empty.
# Fault type detected:  not
# Probabilities:
# 0.0002 		 rewrite
# 0.9998 		 not
# Similar Valid Sentences:
# 0.3753 		 Aircraft must not enter a runway without clearance.
# 0.2429 		 Controller shall not open Door while train is moving, only when stopped.
# 0.2331 		 The aircraft must never fly off the route specified at the flight plan.
# 0.2119 		 If ventilation turned off, the workplace must be abandoned immediately.
# 0.2014 		 The takeoff must be aborted at the first sign of loss of directional control.
#
#
# Sentence:             Verify if the channels are actuated.
# Fault type detected:  not
# Probabilities:
# 0.0009 		 rewrite
# 0.9991 		 not
# Similar Valid Sentences:
# 0.2947 		 The LKA system must not perform corrective action if the correct turn-indicator is actuated (if the direction of deviation is the same as the turn-indicator).
# 0.2792 		 The train shall remain stopped and a door open command issued if an object is detected in the doorway when doors are closed.
# 0.2339 		 The LKA system must verify that corrective action has beenperformed either from its inputs or feedback from the electrical steering system.
# 0.2049 		 Controllers shall confirm that there are no rocket tests ongoing.
# 0.2005 		 Doors must not be closed if someone is in the doorway.
#
#
# Sentence:             Verify the conformity of the products to respective certified design.
# Fault type detected:  not
# Probabilities:
# 0.0005 		 rewrite
# 0.9995 		 not
# Similar Valid Sentences:
# 0.4521 		 The products shall be in conformity with the design. If it’s not, it shall not be used or operated.
# 0.4499 		 The reports, procedures and documents not approved by Certification Authority shall be revised and the revisions shall be submitted to the Certification Authority for approval. It might be necessary to repeat test or simulations in order to verify design changes.
# 0.3387 		 The certification process shall allow identification of critical flaws and loss scenarios.
# 0.3276 		 The certification process shall be continuously updated, allowing improvement of the procedures and regulations.
# 0.3271 		 The Certification Authority personnel shall be qualified according to project/production area they are analysing.
#
#
# Sentence:             When a track section is occupied by a train, the TCC transmits control parameters representing track occupancy to other trains and issues warning signals (red) to the signal device in front of this section.
# Fault type detected:  not
# Probabilities:
# 0.0006 		 rewrite
# 0.9994 		 not
# Similar Valid Sentences:
# 0.5520 		 The failures in the Train Control System must be identified and provided as feedback to the dispatcher of CTC in time.
# 0.4961 		 The dispatcher in the CTC and the watch keeper should identify the potential danger in the railway line and command the train to slow down or stop in emergency situations.
# 0.3781 		 Controller shall open Door when Train is stopped in Station.
# 0.3584 		 The Controller shall warn passengers when the door is about to open or close.
# 0.3274 		 Controller shall not open Door while train is moving, only when stopped.
#
#
# Sentence:             When the aircraft is on the ground during takeoff or landing, and fuel flow is stuck high, when the pilot moves Throttle (TLA) to the idle, then automatically command an engine shutdown.
# Fault type detected:  not
# Probabilities:
# 0.0006 		 rewrite
# 0.9994 		 not
# Similar Valid Sentences:
# 0.2536 		 System shall be able to control the actuator (Throttle, Spark, Fuel, etc.), when required.
# 0.2456 		 Actuator (Throttle, Spark, Fuel, etc.) Control shall be synchronized with axle torque request.
# 0.2327 		 Control system shall control the actuator (Throttle, Spark, Fuel, etc.) correctly in response to axle torque request.
# 0.2321 		 If ventilation does not maintain methane level below 3%, this must be detected, electricity must be cut off, and workers must abandon the workplace immediately.
# 0.2309 		 Aircraft must maintain separation with ground or obstacles on ground.
#
#
# Sentence:             Must keep the system safe.
# Fault type detected:  rewrite
# Probabilities:
# 0.9998 		 rewrite
# 0.0002 		 not
# Similar Valid Sentences:
# 0.4677 		 The aircraft must be able to generate enough power to keep the systems running properly.
# 0.4571 		 Satellite must maintain means of communication with supporting systems.
# 0.3964 		 Satellite must maintain means of transmitting science data to supporting systems.
# 0.3583 		 SGC system must always produce gas with maximum capacity.
# 0.3432 		 The certification process shall allow verification of all safety critical or performance requirements and also the system functions.
#
#
# Sentence:             Security must be active.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0001 		 not
# Similar Valid Sentences:
# 0.3596 		 Msn critical systems must be available when required to perform primary msn.
# 0.3464 		 Procedures must be in place to identify and investigate thoroughly all serious or potentially serious incidents.
# 0.3303 		 Safe distance should always be kept and the crew must be aware when it is violated.
# 0.3010 		 Aircraft must maintain criteria for stable approaches.
# 0.2973 		 Smartgrid must be able to keep customers comfortable as desired.
#
#
# Sentence:             Must have minimum mission critical safety systems functional for landing.
# Fault type detected:  rewrite
# Probabilities:
# 1.0000 		 rewrite
# 0.0000 		 not
# Similar Valid Sentences:
# 0.4158 		 Msn critical systems must be available when required to perform primary msn.
# 0.3758 		 Satellite must maintain means of communication with supporting systems.
# 0.3639 		 Satellite must maintain means of transmitting science data to supporting systems.
# 0.3628 		 The certification process shall allow verification of all safety critical or performance requirements and also the system functions.
# 0.3066 		 All the safety/mission critical military aerospace designs and products shall be Certified to allow use or operation.
#
#
# Sentence:             Aircraft must fly.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0001 		 not
# Similar Valid Sentences:
# 0.4359 		 Aircraft must maintain separation with other aircraft.
# 0.4083 		 Airframe integrity must not be lost during flight.
# 0.3969 		 Aircraft must maintain its control and maintain airframe integrity.
# 0.3836 		 The flight crew must have control of the aircraft all the time.
# 0.3657 		 The flight crew must never violate the minimum distance to other aircraft.
#
#
# Sentence:             Must have all systems functional when driving.
# Fault type detected:  rewrite
# Probabilities:
# 1.0000 		 rewrite
# 0.0000 		 not
# Similar Valid Sentences:
# 0.4447 		 Driver must brake Model S when required.
# 0.4130 		 The certification process shall allow verification of all safety critical or performance requirements and also the system functions.
# 0.3509 		 Vehicles must always maintain safe distances from each other.
# 0.3333 		 The aircraft must be controllable by the pilot or piloting function in an OPV (optionally piloted vehicle) at all times.
# 0.3273 		 The flight crew must have control of the aircraft all the time.
#
#
# Sentence:             Must comply to all regulations.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0001 		 not
# Similar Valid Sentences:
# 0.4384 		 All inspection procedures must be coordinated between implementers.
# 0.3743 		 The flight crew must have control of the aircraft all the time.
# 0.2954 		 Recommendations must be implemented to eliminate or mitigate all identified factors contributing to the adverse events.
# 0.2918 		 The aircraft must be controllable by the pilot or piloting function in an OPV (optionally piloted vehicle) at all times.
# 0.2845 		 The FI must take over the control to enforce these safety constraints if necessary.
#
#
# Sentence:             Must calculate all processes in time.
# Fault type detected:  rewrite
# Probabilities:
# 0.9992 		 rewrite
# 0.0008 		 not
# Similar Valid Sentences:
# 0.4164 		 Software must complete calculations within 2 minutes.
# 0.3303 		 The flight crew must have control of the aircraft all the time.
# 0.3195 		 All inspection procedures must be coordinated between implementers.
# 0.3188 		 The certification process shall allow verification of all safety critical or performance requirements and also the system functions.
# 0.3116 		 Procedures must be in place to identify and investigate thoroughly all serious or potentially serious incidents.
#
#
# Sentence:             No relevant function shall be lost during flight.
# Fault type detected:  rewrite
# Probabilities:
# 0.9949 		 rewrite
# 0.0051 		 not
# Similar Valid Sentences:
# 0.3894 		 Airframe integrity must not be lost during flight.
# 0.2879 		 The aircraft must never fly off the route specified at the flight plan.
# 0.2742 		 Aircraft shall be capable of remaining airborn in a controlled manner throughout the operation.
# 0.2629 		 The flight crew must never violate the minimum distance to other aircraft.
# 0.2376 		 The system must not disrupt the pilot and ATC operations during critical phases of flight nor disrupt aircraft operation.
#
#
# Sentence:             Must fly through a safe area.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0001 		 not
# Similar Valid Sentences:
# 0.3710 		 The aircraft must be maneuvered within the safety envelope.
# 0.3356 		 Ship must not enter into an unsafe area (low water-depth or stormy area).
# 0.3314 		 Aircraft must not enter a runway without clearance.
# 0.2788 		 Airframe integrity must not be lost during flight.
# 0.2782 		 In areas where terrain masking may occur, the controller shall maintain awareness of aircraft that have requested access to the airspace.
#
#
# Sentence:             System must be functional.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0001 		 not
# Similar Valid Sentences:
# 0.4166 		 Satellite must maintain means of communication with supporting systems.
# 0.3853 		 The aircraft must be able to generate enough power to keep the systems running properly.
# 0.3619 		 Msn critical systems must be available when required to perform primary msn.
# 0.3354 		 SGC system must always produce gas with maximum capacity.
# 0.3336 		 Satellite must maintain means of transmitting science data to supporting systems.
#
#
# Sentence:             Passanger must be alive.
# Fault type detected:  rewrite
# Probabilities:
# 1.0000 		 rewrite
# 0.0000 		 not
# Similar Valid Sentences:
# 0.2472 		 Satellite must be able to operate for the design life.
# 0.2442 		 Follow-up must be provided to ensure that recommendations have been implemented and are effective.
# 0.2116 		 Smartgrid must be able to meet local energy demands.
# 0.2039 		 Vehicles must always maintain safe distances from each other.
# 0.2035 		 AV must never lose control.
#
#
# Sentence:             Verifying the system conditions is a must.
# Fault type detected:  rewrite
# Probabilities:
# 0.9998 		 rewrite
# 0.0002 		 not
# Similar Valid Sentences:
# 0.4581 		 The certification process shall allow verification of all safety critical or performance requirements and also the system functions.
# 0.3754 		 System shall be made aware of the Axle Torque Command determination status.
# 0.3241 		 The LKA system must verify that corrective action has beenperformed either from its inputs or feedback from the electrical steering system.
# 0.3241 		 Laboratory Operators must verify the safety acceptable environmental conditions and the restrictions for handling energetic materials.
# 0.2977 		 NSI should ensure NS accept from NSS is conform to the its requirements.
#
#
# Sentence:             An inspection must be done in the system.
# Fault type detected:  rewrite
# Probabilities:
# 0.9998 		 rewrite
# 0.0002 		 not
# Similar Valid Sentences:
# 0.3699 		 The certification process shall allow verification of all safety critical or performance requirements and also the system functions.
# 0.3346 		 Procedures must be in place to identify and investigate thoroughly all serious or potentially serious incidents.
# 0.3300 		 System shall be made aware of the Axle Torque Command determination status.
# 0.3020 		 Depth should be continuously monitored.
# 0.2975 		 The laboratory supervisor must supervise the laboratory activities to verify the safety standards for handling energetic materials.
#
#
# Sentence:             Must have minimum number of passangers in flight.
# Fault type detected:  rewrite
# Probabilities:
# 0.9997 		 rewrite
# 0.0003 		 not
# Similar Valid Sentences:
# 0.3470 		 The flight crew must never violate the minimum distance to other aircraft.
# 0.3416 		 The aircraft must maintain minimum separation from potential sources of collision.
# 0.2962 		 The flight crew must never violate predetermined minimum/maximum altitude.
# 0.2654 		 Airframe integrity must not be lost during flight.
# 0.2463 		 A/C must maintain minimum safe altitude limits.
#
#
# Sentence:             Must have all systems functional for flight.
# Fault type detected:  rewrite
# Probabilities:
# 1.0000 		 rewrite
# 0.0000 		 not
# Similar Valid Sentences:
# 0.4685 		 The flight crew must have control of the aircraft all the time.
# 0.4498 		 The aircraft must be able to generate enough power to keep the systems running properly.
# 0.4092 		 The certification process shall allow verification of all safety critical or performance requirements and also the system functions.
# 0.3535 		 The aircraft must be controllable by the pilot or piloting function in an OPV (optionally piloted vehicle) at all times.
# 0.3249 		 The operator should always be able to control the attitude and flight path during the whole flight.
#
#
# Sentence:             No component shall be active when vehicle is turned off.
# Fault type detected:  rewrite
# Probabilities:
# 0.9996 		 rewrite
# 0.0004 		 not
# Similar Valid Sentences:
# 0.3182 		 Ego vehicle must not leave the lane unless desired by the driver.
# 0.3039 		 Vehicle must not leave the roadway.
# 0.2950 		 The LKA system must not allow the vehicle switch to lanes without the correct turn-indicator being actuated.
# 0.2589 		 Vehicle stages and interfaces must be designed so that, in the event of an unintended ignition, they do not result in the vehicle explosion.
# 0.2408 		 Satellite must not radiate energy until on orbit, separated from, and clear of launch vehicle and debris.
#
#
# Sentence:             Must have cabin pressurization system active.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0001 		 not
# Similar Valid Sentences:
# 0.2910 		 SGC system must always produce gas with maximum capacity.
# 0.2866 		 Msn critical systems must be available when required to perform primary msn.
# 0.2674 		 The aircraft must be able to generate enough power to keep the systems running properly.
# 0.2608 		 System shall be able to control the actuator (Throttle, Spark, Fuel, etc.), when required.
# 0.2317 		 The certification process shall allow verification of all safety critical or performance requirements and also the system functions.
#
#
# Sentence:             Should allow multiple users in software.
# Fault type detected:  rewrite
# Probabilities:
# 0.9996 		 rewrite
# 0.0004 		 not
# Similar Valid Sentences:
# 0.2520 		 Software must complete calculations within 2 minutes.
# 0.2183 		 Radio communication should be in the disposal of the spotter and the operators.
# 0.2090 		 All the safety/mission critical military aerospace designs and products shall be Certified to allow use or operation.
# 0.1966 		 Toxic chemicals must be contained within plant equipment.
# 0.1877 		 The test planning shall consider the financial restrictions and the management risks of the project.
#
#
# Sentence:             Must have all necessary weather information for flight.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0001 		 not
# Similar Valid Sentences:
# 0.4513 		 The flight crew must have control of the aircraft all the time.
# 0.3692 		 The operator should always be able to control the attitude and flight path during the whole flight.
# 0.3511 		 The aircraft must be controllable by the pilot or piloting function in an OPV (optionally piloted vehicle) at all times.
# 0.2941 		 Approval must be given to the requesting aircraft only.
# 0.2769 		 Data Fusion and Assessment must provide assessed environment model to Autopilot when required.
#
#
# Sentence:             Must detect all system threats.
# Fault type detected:  rewrite
# Probabilities:
# 0.9999 		 rewrite
# 0.0001 		 not
# Similar Valid Sentences:
# 0.4761 		 The certification process shall allow verification of all safety critical or performance requirements and also the system functions.
# 0.3605 		 Procedures must be in place to identify and investigate thoroughly all serious or potentially serious incidents.
# 0.3458 		 All inspection procedures must be coordinated between implementers.
# 0.3261 		 Heat and smoke detectors should trigger an alarm and extinguishing systems.
# 0.3038 		 Recommendations must be implemented to eliminate or mitigate all identified factors contributing to the adverse events.
#
#
# Sentence:             Should an accident occur, the airbags are activated.
# Fault type detected:  rewrite
# Probabilities:
# 0.9995 		 rewrite
# 0.0005 		 not
# Similar Valid Sentences:
# 0.2874 		 ACS must provide attitude maneuver commands when ASTRO-H is rotating.
# 0.2750 		 The train shall remain stopped and a door open command issued if an object is detected in the doorway when doors are closed.
# 0.2637 		 The CREVAS must operate when the two events—High-level radioactive at air intakes of MCR or the SIAS—occur.
# 0.2606 		 An emergency shall stop the train, Doors shall open in an emergency after the train has stopped.
# 0.2572 		 The CSAS must operate when the three events—LOCA, S/WP-Ex, or the SIAS—occur.
#
#
# Sentence:             Must maintain integrity of mission critical components.
# Fault type detected:  rewrite
# Probabilities:
# 1.0000 		 rewrite
# 0.0000 		 not
# Similar Valid Sentences:
# 0.4243 		 Satellite must maintain means of communication with supporting systems.
# 0.4107 		 Satellite must maintain means of transmitting science data to supporting systems.
# 0.3968 		 Satellite must maintain means of control.
# 0.3922 		 Msn critical systems must be available when required to perform primary msn.
# 0.3329 		 Aircraft must maintain criteria for stable approaches.
#
#
# Sentence:             Must be able to operate the system.
# Fault type detected:  rewrite
# Probabilities:
# 1.0000 		 rewrite
# 0.0000 		 not
# Similar Valid Sentences:
# 0.4525 		 The aircraft must be able to generate enough power to keep the systems running properly.
# 0.3549 		 System shall be able to control the actuator (Throttle, Spark, Fuel, etc.), when required.
# 0.3531 		 Satellite must be able to operate for the design life.
# 0.3406 		 Msn critical systems must be available when required to perform primary msn.
# 0.3340 		 Satellite must maintain means of communication with supporting systems.
#
#
# Sentence:             Drune must be dispatched.
# Fault type detected:  rewrite
# Probabilities:
# 0.9991 		 rewrite
# 0.0009 		 not
# Similar Valid Sentences:
# 0.3316 		 Lessons learned must be documented and disseminated.
# 0.2871 		 Radioactive materials must note be released.
# 0.2742 		 Yawing at brakes release must be counteracted quickly.
# 0.2541 		 AV must adhere to the designated path.
# 0.2424 		 Satellite must be launched into correct orbit, or means to correct for different orbits must exist.
#
#
# Sentence:             Avoid hazardous state.
# Fault type detected:  not
# Probabilities:
# 0.0001 		 rewrite
# 0.9999 		 not
# Similar Valid Sentences:
# 0.3442 		 The energetic material state must not differ from the safety acceptable conditions to be handled.
# 0.3025 		 Laboratory Operators must be able to stop the synthesis once it is detected that the process variables conditions are out of the safety acceptable states for handling.
# 0.2848 		 Workers shall not be exposed to hazardous energy.
# 0.2658 		 Public health measures must reduce risk of public exposure to unsafe water during incidents.
# 0.2437 		 The owner of a certificate product shall maintain the system safety and the manufacturing according to the design approved to avoid the certificate to be cancelled.
#
#
# Sentence:             Comply to all regulations.
# Fault type detected:  not
# Probabilities:
# 0.0213 		 rewrite
# 0.9787 		 not
# Similar Valid Sentences:
# 0.4279 		 All inspection procedures must be coordinated between implementers.
# 0.3108 		 The flight crew must have control of the aircraft all the time.
# 0.2817 		 The certification process shall allow verification of all safety critical or performance requirements and also the system functions.
# 0.2759 		 Recommendations must be implemented to eliminate or mitigate all identified factors contributing to the adverse events.
# 0.2678 		 All the safety/mission critical military aerospace designs and products shall be Certified to allow use or operation.
#
#
# Sentence:             Aircraft flies safely.
# Fault type detected:  not
# Probabilities:
# 0.0003 		 rewrite
# 0.9997 		 not
# Similar Valid Sentences:
# 0.3110 		 Aircraft must maintain criteria for stable approaches.
# 0.2773 		 The aircraft must be maneuvered within the safety envelope.
# 0.2755 		 Aircraft must maintain separation with other aircraft.
# 0.2709 		 The transition of primary flight controls in the rotation should be performed smoothly and continuously.
# 0.2551 		 The aircraft must be able to generate enough power to keep the systems running properly.
#
#
# Sentence:             Avoid machine overload.
# Fault type detected:  not
# Probabilities:
# 0.0001 		 rewrite
# 0.9999 		 not
# Similar Valid Sentences:
# 0.3807 		 The app must command the pump to stop if the patient's vital signs indicate over-infusion.
# 0.1762 		 In case of budget restriction is unavoidable, the company management shall prioritize the activities without compromising safety or performance aspects.
# 0.1680 		 IPMS must send STOP command to PCA when patient has been given too much opiod.
# 0.1668 		 The AMS must avoid H2O/Ice accumulation.
# 0.1501 		 Ego vehicle must not accelerate at rates greater than 1 m/s^2.
#
#
# Sentence:             Verify if all components are working.
# Fault type detected:  not
# Probabilities:
# 0.0006 		 rewrite
# 0.9994 		 not
# Similar Valid Sentences:
# 0.2694 		 All inspection procedures must be coordinated between implementers.
# 0.2286 		 The certification process shall allow verification of all safety critical or performance requirements and also the system functions.
# 0.2251 		 All the safety/mission critical military aerospace designs and products shall be Certified to allow use or operation.
# 0.2145 		 The flight crew must have control of the aircraft all the time.
# 0.2048 		 Procedures must be in place to identify and investigate thoroughly all serious or potentially serious incidents.
#
#
# Sentence:             When encountering a dangerous situation, vehicle performs emergency maneuver.
# Fault type detected:  not
# Probabilities:
# 0.0004 		 rewrite
# 0.9996 		 not
# Similar Valid Sentences:
# 0.2535 		 Vehicle must illuminate the brake light to warn vehicle in the back.
# 0.2339 		 The dispatcher in the CTC and the watch keeper should identify the potential danger in the railway line and command the train to slow down or stop in emergency situations.
# 0.2210 		 An emergency shall stop the train, Doors shall open in an emergency after the train has stopped.
# 0.2144 		 Laboratory Supervisors must verify if the Operators have concluded the training for safely handling Energetic Materials before authorizing the activities.
# 0.2134 		 Brake light command must illuminate early within X-seconds before stopping vehicle.
#
#
# Sentence:             Avoiding the contact of toxic substances.
# Fault type detected:  not
# Probabilities:
# 0.0000 		 rewrite
# 1.0000 		 not
# Similar Valid Sentences:
# 0.2976 		 Toxic chemicals must not be released.
# 0.2735 		 Chemical plant must not release toxic chemicals into the atmosphere.
# 0.2590 		 Toxic chemicals must be contained within plant equipment.
# 0.2486 		 If toxic chemicals are not contained, damage must be mitigated.
# 0.2457 		 Toxic plant chemicals must not be released into the atmosphere.
#
#
# Sentence:             Contact ATC when in emergency.
# Fault type detected:  not
# Probabilities:
# 0.0044 		 rewrite
# 0.9956 		 not
# Similar Valid Sentences:
# 0.4420 		 The dispatcher in the CTC and the watch keeper should identify the potential danger in the railway line and command the train to slow down or stop in emergency situations.
# 0.3237 		 The failures in the Train Control System must be identified and provided as feedback to the dispatcher of CTC in time.
# 0.3081 		 SGC system must stop compressing gas when gas leaks to the environment.
# 0.2887 		 The system must not disrupt the pilot and ATC operations during critical phases of flight nor disrupt aircraft operation.
# 0.2366 		 Controller shall open Door in an emergency.
#
#
# Sentence:             Aircraft keeps a safe altitude.
# Fault type detected:  not
# Probabilities:
# 0.0000 		 rewrite
# 1.0000 		 not
# Similar Valid Sentences:
# 0.3357 		 A/C must maintain minimum safe altitude limits.
# 0.3140 		 Aircraft must maintain criteria for stable approaches.
# 0.2818 		 Aircraft must maintain separation with other aircraft.
# 0.2781 		 Aircraft should maintain a safe distance from obstacles and notify the operator when reaching the minimum distance.
# 0.2487 		 Aircraft must maintain separation with ground or obstacles on ground.
#
#
# Sentence:             Maintenance of the highway only when highway is blocked.
# Fault type detected:  not
# Probabilities:
# 0.0000 		 rewrite
# 1.0000 		 not
# Similar Valid Sentences:
# 0.3140 		 Vehicle must not leave the roadway.
# 0.3067 		 Controller shall not open Door while train is moving, only when stopped.
# 0.2357 		 Doors shall remain closed when train is moving.
# 0.2303 		 Doors must not be opened until train is stopped and aligned with platform.
# 0.2235 		 Doors shall open at station when train is completely stopped and aligned with platform.
#
#
# Sentence:             Verify if the door is properly closed.
# Fault type detected:  not
# Probabilities:
# 0.0000 		 rewrite
# 1.0000 		 not
# Similar Valid Sentences:
# 0.4369 		 Doors must not be closed if someone is in the doorway.
# 0.3968 		 If a person is detected in doorway during door closing, door closing must be stopped and reversed.
# 0.3399 		 The train shall remain stopped and a door open command issued if an object is detected in the doorway when doors are closed.
# 0.3134 		 The ship must be maintained properly so that the occurrence of fire is prevented.
# 0.3041 		 Doors shall remain closed when train is moving.
#
#
# Sentence:             During a trip to the destination, if there are people inside vehicle, remind to fasten the seatbelt.
# Fault type detected:  not
# Probabilities:
# 0.0124 		 rewrite
# 0.9876 		 not
# Similar Valid Sentences:
# 0.3226 		 The vehicle should keep adequate distance and height against the people and properties on the ground.
# 0.2771 		 Vehicle must illuminate the brake light to warn vehicle in the back.
# 0.2719 		 AV must provide a comfortable experience to the passengers when driving or stationary.
# 0.2359 		 Doors shall remain open when someone is in the doorway, the train shall not move until the doors close.
# 0.2095 		 Doors must not be closed if someone is in the doorway.
#
#
# Sentence:             When the ground is clear, the pilot contacts ATC for permission, and performs landing.
# Fault type detected:  not
# Probabilities:
# 0.0002 		 rewrite
# 0.9998 		 not
# Similar Valid Sentences:
# 0.3828 		 The flight crew must not execute the ITP when it has not been approved by ATC.
# 0.3472 		 The flight crew must not execute the ITP before approval by ATC.
# 0.3204 		 The system must not disrupt the pilot and ATC operations during critical phases of flight nor disrupt aircraft operation.
# 0.2766 		 Aircraft must maintain separation with ground or obstacles on ground.
# 0.2658 		 In areas where terrain masking may occur, the controller shall maintain awareness of aircraft that have requested access to the airspace.
#
#
# Sentence:             Extension of landing gear only approaching ground.
# Fault type detected:  not
# Probabilities:
# 0.0001 		 rewrite
# 0.9999 		 not
# Similar Valid Sentences:
# 0.2323 		 When the bursting of a tire at high speed is suspected and the pilot decides to continue, the landing gear must not be retracted.
# 0.2130 		 Aircraft must maintain separation with ground or obstacles on ground.
# 0.1846 		 Aircraft on ground must maintain separation with other objects and must not leave the paved area.
# 0.1705 		 In the event of an unintended ignition, the vehicle must remain fixed to the launching rail, avoiding an unplanned route.
# 0.1630 		 Approval must be given to the requesting aircraft only.
#
#
# Sentence:             User is allowed to override commands in case of emergency.
# Fault type detected:  not
# Probabilities:
# 0.0001 		 rewrite
# 0.9999 		 not
# Similar Valid Sentences:
# 0.3672 		 The app must command the pump to stop if the patient's vital signs indicate over-infusion.
# 0.2842 		 Controller shall open Door in an emergency.
# 0.2572 		 IPMS must sent STOP command within TBD seconds of emergency.
# 0.2172 		 The Laboratory Supervisors must be a part of the scale of the energetic material manipulated, if the authorizations are correct, and if the work is conducted at the appropriate time with people to provide first aid or trigger emergency mode if necessary.
# 0.2113 		 The FI must take over the control to enforce these safety constraints if necessary.
#
#
# Sentence:             Avoid sudden braking when moving.
# Fault type detected:  not
# Probabilities:
# 0.0000 		 rewrite
# 1.0000 		 not
# Similar Valid Sentences:
# 0.3558 		 Yawing at brakes release must be counteracted quickly.
# 0.3146 		 Brake light command must illuminate early within X-seconds before stopping vehicle.
# 0.3118 		 Controller shall not open Door while train is moving, only when stopped.
# 0.3108 		 Vehicle must brake when vehicle detected slowed or stopped object (at a few X-meters within the preset value of the safety distance) in its path.
# 0.2923 		 ACC should not brake too abruptly.
#
#
# Sentence:             Ensure the vehicle has enough fuel before departing.
# Fault type detected:  not
# Probabilities:
# 0.0001 		 rewrite
# 0.9999 		 not
# Similar Valid Sentences:
# 0.4096 		 Brake light command must illuminate early within X-seconds before stopping vehicle.
# 0.3180 		 At the launch rail, vehicle stages must be prevented from igniting before planned, even when subjected to commands or electric discharges.
# 0.3015 		 Laboratory Supervisors must verify if the Operators have concluded the training for safely handling Energetic Materials before authorizing the activities.
# 0.3001 		 Vehicle must brake when vehicle detected slowed or stopped object (at a few X-meters within the preset value of the safety distance) in its path.
# 0.2788 		 Controller shall allow time for passengers to exit & enter before attempting to close the door.
#
#
# Sentence:             Always make sure to check if equipment is working as intended.
# Fault type detected:  not
# Probabilities:
# 0.1908 		 rewrite
# 0.8092 		 not
# Similar Valid Sentences:
# 0.3149 		 Safe distance should always be kept and the crew must be aware when it is violated.
# 0.2869 		 Deck crew must be well trained, and equipment properly maintained and inspected.
# 0.2732 		 The train shall remain stopped and a door open command issued if an object is detected in the doorway when doors are closed.
# 0.2461 		 Follow-up must be provided to ensure that recommendations have been implemented and are effective.
# 0.2428 		 Laboratory Supervisors must verify if the Operators have concluded the training for safely handling Energetic Materials before authorizing the activities.
#
#
# Sentence:             Verify if the landing gear is retracted after takeoff.
# Fault type detected:  not
# Probabilities:
# 0.0001 		 rewrite
# 0.9999 		 not
# Similar Valid Sentences:
# 0.4116 		 When the bursting of a tire at high speed is suspected and the pilot decides to continue, the landing gear must not be retracted.
# 0.2671 		 If a person is detected in doorway during door closing, door closing must be stopped and reversed.
# 0.2215 		 Pilot must start maneuver within X minutes of re-verifying ITP criteria.
# 0.2209 		 The train shall remain stopped and a door open command issued if an object is detected in the doorway when doors are closed.
# 0.2132 		 Controllers shall confirm that there are no rocket tests ongoing.
#
#
# Sentence:             Verify the equipment state before performing maintenance.
# Fault type detected:  not
# Probabilities:
# 0.0001 		 rewrite
# 0.9999 		 not
# Similar Valid Sentences:
# 0.4111 		 Laboratory Supervisors must verify if the Operators have concluded the training for safely handling Energetic Materials before authorizing the activities.
# 0.2914 		 Laboratory Operators must be able to stop the synthesis once it is detected that the process variables conditions are out of the safety acceptable states for handling.
# 0.2870 		 The laboratory supervisor must supervise the laboratory activities to verify the safety standards for handling energetic materials.
# 0.2617 		 Brake light command must illuminate early within X-seconds before stopping vehicle.
# 0.2364 		 Expired materials must be revalidated before use.
#
#
# Sentence:             Changing lanes only when lane is empty.
# Fault type detected:  not
# Probabilities:
# 0.0000 		 rewrite
# 1.0000 		 not
# Similar Valid Sentences:
# 0.3952 		 Ego vehicle must not leave the lane unless desired by the driver.
# 0.2937 		 The LKA system must not allow the vehicle switch to lanes without the correct turn-indicator being actuated.
# 0.2572 		 Controller shall not open Door while train is moving, only when stopped.
# 0.2343 		 Vehicle must not leave the roadway.
# 0.2322 		 Doors shall remain closed when train is moving.
#
#
# Sentence:             Avoid flight in altitude below permitted limit.
# Fault type detected:  not
# Probabilities:
# 0.0000 		 rewrite
# 1.0000 		 not
# Similar Valid Sentences:
# 0.4027 		 Pilots must not climb/descent beyond designated altitude.
# 0.3356 		 The flight crew must never violate predetermined minimum/maximum altitude.
# 0.3058 		 A/C must maintain minimum safe altitude limits.
# 0.3054 		 Pilots must not stop maneuver before reaching designated altitude (except in emergency temination).
# 0.2747 		 The flight crew must never violate the minimum distance to other aircraft.
#
#
# Sentence:             System is capable of defending threats.
# Fault type detected:  not
# Probabilities:
# 0.0001 		 rewrite
# 0.9999 		 not
# Similar Valid Sentences:
# 0.3144 		 The certification process shall allow verification of all safety critical or performance requirements and also the system functions.
# 0.3077 		 Satellite must maintain means of communication with supporting systems.
# 0.2783 		 System shall be made aware of the Axle Torque Command determination status.
# 0.2508 		 The owner of a certificate product shall maintain the system safety and the manufacturing according to the design approved to avoid the certificate to be cancelled.
# 0.2501 		 Satellite must maintain means of transmitting science data to supporting systems.
#
#
# Sentence:             Verify if the runway is empty.
# Fault type detected:  not
# Probabilities:
# 0.0000 		 rewrite
# 1.0000 		 not
# Similar Valid Sentences:
# 0.4108 		 Aircraft must not enter a runway without clearance.
# 0.3097 		 Controllers shall confirm that there are no rocket tests ongoing.
# 0.2851 		 Doors must not be closed if someone is in the doorway.
# 0.2440 		 The train shall remain stopped and a door open command issued if an object is detected in the doorway when doors are closed.
# 0.2288 		 Pilots must not execute maneuver when ITP criteria are not satisfied.
#
#
# Sentence:             Sudden braking olny in emergency situations.
# Fault type detected:  not
# Probabilities:
# 0.0008 		 rewrite
# 0.9992 		 not
# Similar Valid Sentences:
# 0.2411 		 Brake light command must illuminate early within X-seconds before stopping vehicle.
# 0.2269 		 Yawing at brakes release must be counteracted quickly.
# 0.2241 		 An emergency shall stop the train, Doors shall open in an emergency after the train has stopped.
# 0.2000 		 Smartgrid must be able to meet unexpected demands.
# 0.1968 		 ACC should not brake too abruptly.
#
#
# Sentence:             Vehicle overtaking only when road is empty.
# Fault type detected:  not
# Probabilities:
# 0.0000 		 rewrite
# 1.0000 		 not
# Similar Valid Sentences:
# 0.3351 		 Vehicle must not leave the roadway.
# 0.3201 		 Ego vehicle must not leave the lane unless desired by the driver.
# 0.2702 		 The app must command the pump to stop if the patient's vital signs indicate over-infusion.
# 0.2291 		 Driver must not perform other tasks when not allowed.
# 0.2246 		 Brake light command must illuminate early within X-seconds before stopping vehicle.
